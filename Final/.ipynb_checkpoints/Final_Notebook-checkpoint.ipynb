# %% [markdown]
# # Dataset 1: FOUNDATION LEARNING SKILLS

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import pandas as pd

from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation 
from sklearn.preprocessing import StandardScaler  # For scaling dataset
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor

from sklearn import preprocessing 
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy
from sklearn.feature_selection import RFECV

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping

from tensorflow.keras.utils import to_categorical
from iteration_utilities import deepflatten

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data collection

# %% [markdown]
# ### Foundational-learning_2021-1.xlsx

# %%
xl_file = pd.ExcelFile('Foundational-learning_2021-1.xlsx')

# %%
df = xl_file.parse('Foundational learning', header=[0, 1])

for i in range(0,7):
    df.rename({df.columns[i][1]:""}, axis="columns", inplace=True)
    
df.drop(df.index[100:], inplace=True)

# %%
df
# Out:
#          Countries and areas Region Sub-region Development regions  \
#
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 95              Turkmenistan    ECA       EECA      Less Developed
# 96                  Zimbabwe    SSA        ESA      Less Developed
# 97                  Zimbabwe    SSA        ESA      Less Developed
# 98                  Zimbabwe    SSA        ESA      Less Developed
# 99                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject      Total        Sex             Residence  \
#                                           Girls       Boys      Rural
# 0   Age 7 to 14   Reading  48.814716  52.392544  45.074005  46.981983
# 1   Age 7 to 14  Numeracy  27.866051  28.959688  26.722622  26.574785
# 2     Grade 2/3   Reading  24.599609  26.002825  23.178070  21.751852
# 3     Grade 2/3  Numeracy  12.550222  12.392838  12.709662  11.408230
# 4   Age 7 to 14   Reading   4.693856   4.560828   4.809788   2.057838
# ..          ...       ...        ...        ...        ...        ...
# 95    Grade 2/3  Numeracy  53.200000  64.800000  58.500000        NaN
# 96  Age 7 to 14   Reading  44.365719  48.368660  40.518608  36.768028
# 97  Age 7 to 14  Numeracy  24.620714  26.782095  22.543474  19.146442
# 98    Grade 2/3   Reading  19.576178  21.219332  17.992134  12.351241
# 99    Grade 2/3  Numeracy   5.108691   4.419424   5.773163   2.455187
#
#               Wealth quintile                                              \
#         Urban         Poorest     Second     Middle     Fourth    Richest
# 0   55.805260       35.360210  43.906765  50.639637  54.517452  63.611889
# 1   32.791283       19.557022  25.148443  27.337364  31.040785  38.721001
# 2   35.798244       16.602999  18.201494  22.767086  28.660402  42.274563
# 3   17.041044        8.673656  10.437841  11.085612  12.559054  22.395241
# 4    9.213395        0.486284   3.040068   1.691019   4.024787  13.331376
# ..        ...             ...        ...        ...        ...        ...
# 95        NaN             NaN        NaN        NaN        NaN        NaN
# 96  67.629013       25.323767  34.230465  44.128292  56.616516  76.777069
# 97  41.382336       12.622963  21.344015  20.532696  31.470972  47.066925
# 98  41.673153        6.278276  10.377341  16.939035  27.667347  50.681393
# 99  13.224252        0.395979   2.538109   2.018403   8.800878  17.066843
#
#      Data
#    Source       Year
# 0   MICS6       2019
# 1   MICS6       2019
# 2   MICS6       2019
# 3   MICS6       2019
# 4   MICS6  2018-2019
# ..    ...        ...
# 95  MICS6       2019
# 96  MICS6       2019
# 97  MICS6       2019
# 98  MICS6       2019
# 99  MICS6       2019
#
# [100 rows x 18 columns]

# %% [markdown]
# **Combine the column header**

# %%
col = []
for i in range(len(df.columns)):
    if i < 7:
        col.append(df.columns[i][0])
    else:
        col.append(df.columns[i][0] + '-' + df.columns[i][1])

# %%
df.columns = col
df
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 95              Turkmenistan    ECA       EECA      Less Developed
# 96                  Zimbabwe    SSA        ESA      Less Developed
# 97                  Zimbabwe    SSA        ESA      Less Developed
# 98                  Zimbabwe    SSA        ESA      Less Developed
# 99                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1   Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2     Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3     Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4   Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
# ..          ...       ...        ...        ...        ...              ...
# 95    Grade 2/3  Numeracy  53.200000  64.800000  58.500000              NaN
# 96  Age 7 to 14   Reading  44.365719  48.368660  40.518608        36.768028
# 97  Age 7 to 14  Numeracy  24.620714  26.782095  22.543474        19.146442
# 98    Grade 2/3   Reading  19.576178  21.219332  17.992134        12.351241
# 99    Grade 2/3  Numeracy   5.108691   4.419424   5.773163         2.455187
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0         55.805260                35.360210               43.906765
# 1         32.791283                19.557022               25.148443
# 2         35.798244                16.602999               18.201494
# 3         17.041044                 8.673656               10.437841
# 4          9.213395                 0.486284                3.040068
# ..              ...                      ...                     ...
# 95              NaN                      NaN                     NaN
# 96        67.629013                25.323767               34.230465
# 97        41.382336                12.622963               21.344015
# 98        41.673153                 6.278276               10.377341
# 99        13.224252                 0.395979                2.538109
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                50.639637               54.517452                63.611889
# 1                27.337364               31.040785                38.721001
# 2                22.767086               28.660402                42.274563
# 3                11.085612               12.559054                22.395241
# 4                 1.691019                4.024787                13.331376
# ..                     ...                     ...                      ...
# 95                     NaN                     NaN                      NaN
# 96               44.128292               56.616516                76.777069
# 97               20.532696               31.470972                47.066925
# 98               16.939035               27.667347                50.681393
# 99                2.018403                8.800878                17.066843
#
#    Data-Source  Data-Year
# 0        MICS6       2019
# 1        MICS6       2019
# 2        MICS6       2019
# 3        MICS6       2019
# 4        MICS6  2018-2019
# ..         ...        ...
# 95       MICS6       2019
# 96       MICS6       2019
# 97       MICS6       2019
# 98       MICS6       2019
# 99       MICS6       2019
#
# [100 rows x 18 columns]

# %%
df.dtypes
# Out:
# Countries and areas         object
# Region                      object
# Sub-region                  object
# Development regions         object
# Age group                   object
# Subject                     object
# Total                      float64
# Sex-Girls                  float64
# Sex-Boys                   float64
# Residence-Rural            float64
# Residence-Urban            float64
# Wealth quintile-Poorest    float64
# Wealth quintile-Second     float64
# Wealth quintile-Middle     float64
# Wealth quintile-Fourth     float64
# Wealth quintile-Richest    float64
# Data-Source                 object
# Data-Year                   object
# dtype: object

# %%
df.describe()
# Out:
#             Total   Sex-Girls    Sex-Boys  Residence-Rural  Residence-Urban  \
# count  100.000000  100.000000  100.000000        94.000000        94.000000
# mean    26.198632   27.131777   25.470714        22.350986        29.768563
# std     21.036023   22.361859   20.346177        21.112209        21.387091
# min      0.394631    0.051010    0.473044         0.022533         0.000000
# 25%      7.432622    7.059242    7.625648         4.550694        12.301420
# 50%     21.480844   21.059666   20.877780        13.027112        24.972675
# 75%     43.923937   45.792249   38.673675        36.599011        44.219891
# max     81.800000   84.400000   82.000000        83.400000        79.000000
#
#        Wealth quintile-Poorest  Wealth quintile-Second  \
# count                94.000000               94.000000
# mean                 17.371929               21.387640
# std                  19.048739               20.722063
# min                   0.000000                0.000000
# 25%                   2.479506                3.636985
# 50%                   8.001463               12.608856
# 75%                  27.821079               33.977889
# max                  76.100000               89.800000
#
#        Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest
# count               94.000000               94.000000                94.000000
# mean                24.266147               28.115457                37.684759
# std                 22.238528               22.135513                23.564574
# min                  0.000000                0.000000                 0.000000
# 25%                  4.610935                8.740612                17.095623
# 50%                 16.606810               24.916075                37.256182
# 75%                 42.645542               44.460066                58.154563
# max                 78.600000               79.900000                84.800000

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Step 1: Handling missing data

# %% [markdown]
# **Are there any missing values?**

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# Countries and areas        0.0
# Region                     0.0
# Sub-region                 0.0
# Development regions        0.0
# Age group                  0.0
# Subject                    0.0
# Total                      0.0
# Sex-Girls                  0.0
# Sex-Boys                   0.0
# Residence-Rural            6.0
# Residence-Urban            6.0
# Wealth quintile-Poorest    6.0
# Wealth quintile-Second     6.0
# Wealth quintile-Middle     6.0
# Wealth quintile-Fourth     6.0
# Wealth quintile-Richest    6.0
# Data-Source                0.0
# Data-Year                  0.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Countries and areas        0
# Region                     0
# Sub-region                 0
# Development regions        0
# Age group                  0
# Subject                    0
# Total                      0
# Sex-Girls                  0
# Sex-Boys                   0
# Residence-Rural            6
# Residence-Urban            6
# Wealth quintile-Poorest    6
# Wealth quintile-Second     6
# Wealth quintile-Middle     6
# Wealth quintile-Fourth     6
# Wealth quintile-Richest    6
# Data-Source                0
# Data-Year                  0
# dtype: int64

# %%
df.shape
# Out:
# (100, 18)

# %%
null_rows = df.isnull()  # this does not work. Append .any(axis=1) to make it work
null_rows  # boolean indexing
# Out:
#     Countries and areas  Region  Sub-region  Development regions  Age group  \
# 0                 False   False       False                False      False
# 1                 False   False       False                False      False
# 2                 False   False       False                False      False
# 3                 False   False       False                False      False
# 4                 False   False       False                False      False
# ..                  ...     ...         ...                  ...        ...
# 95                False   False       False                False      False
# 96                False   False       False                False      False
# 97                False   False       False                False      False
# 98                False   False       False                False      False
# 99                False   False       False                False      False
#
#     Subject  Total  Sex-Girls  Sex-Boys  Residence-Rural  Residence-Urban  \
# 0     False  False      False     False            False            False
# 1     False  False      False     False            False            False
# 2     False  False      False     False            False            False
# 3     False  False      False     False            False            False
# 4     False  False      False     False            False            False
# ..      ...    ...        ...       ...              ...              ...
# 95    False  False      False     False             True             True
# 96    False  False      False     False            False            False
# 97    False  False      False     False            False            False
# 98    False  False      False     False            False            False
# 99    False  False      False     False            False            False
#
#     Wealth quintile-Poorest  Wealth quintile-Second  Wealth quintile-Middle  \
# 0                     False                   False                   False
# 1                     False                   False                   False
# 2                     False                   False                   False
# 3                     False                   False                   False
# 4                     False                   False                   False
# ..                      ...                     ...                     ...
# 95                     True                    True                    True
# 96                    False                   False                   False
# 97                    False                   False                   False
# 98                    False                   False                   False
# 99                    False                   False                   False
#
#     Wealth quintile-Fourth  Wealth quintile-Richest  Data-Source  Data-Year
# 0                    False                    False        False      False
# 1                    False                    False        False      False
# 2                    False                    False        False      False
# 3                    False                    False        False      False
# 4                    False                    False        False      False
# ..                     ...                      ...          ...        ...
# 95                    True                     True        False      False
# 96                   False                    False        False      False
# 97                   False                    False        False      False
# 98                   False                    False        False      False
# 99                   False                    False        False      False
#
# [100 rows x 18 columns]

# %% [markdown]
# `isnull()` applied on the whole dataframe does not produce the intended behaviour. This function needs to be applied to check for *any* NaN values along the column side (*axis=1*).

# %% [markdown]
# **Any data that can be cleaned or transformed?**

# %%
df.head(7)
# Out:
#         Countries and areas Region Sub-region Development regions  \
# 0                Bangladesh     SA         SA     Least Developed
# 1                Bangladesh     SA         SA     Least Developed
# 2                Bangladesh     SA         SA     Least Developed
# 3                Bangladesh     SA         SA     Least Developed
# 4  Central African Republic    SSA        WCA     Least Developed
# 5  Central African Republic    SSA        WCA     Least Developed
# 6  Central African Republic    SSA        WCA     Least Developed
#
#      Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0  Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1  Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2    Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3    Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4  Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
# 5  Age 7 to 14  Numeracy   1.527805   1.202405   1.811385         0.870304
# 6    Grade 2/3   Reading   1.775748   1.798235   1.758916         1.379215
#
#    Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0        55.805260                35.360210               43.906765
# 1        32.791283                19.557022               25.148443
# 2        35.798244                16.602999               18.201494
# 3        17.041044                 8.673656               10.437841
# 4         9.213395                 0.486284                3.040068
# 5         2.655113                 0.150043                0.833223
# 6         2.422417                 0.000000                2.188316
#
#    Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0               50.639637               54.517452                63.611889
# 1               27.337364               31.040785                38.721001
# 2               22.767086               28.660402                42.274563
# 3               11.085612               12.559054                22.395241
# 4                1.691019                4.024787                13.331376
# 5                1.646962                1.321195                 3.428246
# 6                1.472594                1.221289                 3.482309
#
#   Data-Source  Data-Year
# 0       MICS6       2019
# 1       MICS6       2019
# 2       MICS6       2019
# 3       MICS6       2019
# 4       MICS6  2018-2019
# 5       MICS6  2018-2019
# 6       MICS6  2018-2019

# %% [markdown]
# ### Step 2: Remove the irrelevant observations

# %% [markdown]
# **Drop the data with missing data 'NaN'**

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#         Countries and areas Region Sub-region Development regions  \
# 0                Bangladesh     SA         SA     Least Developed
# 1                Bangladesh     SA         SA     Least Developed
# 2                Bangladesh     SA         SA     Least Developed
# 3                Bangladesh     SA         SA     Least Developed
# 4  Central African Republic    SSA        WCA     Least Developed
#
#      Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0  Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1  Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2    Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3    Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4  Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
#
#    Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0        55.805260                35.360210               43.906765
# 1        32.791283                19.557022               25.148443
# 2        35.798244                16.602999               18.201494
# 3        17.041044                 8.673656               10.437841
# 4         9.213395                 0.486284                3.040068
#
#    Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0               50.639637               54.517452                63.611889
# 1               27.337364               31.040785                38.721001
# 2               22.767086               28.660402                42.274563
# 3               11.085612               12.559054                22.395241
# 4                1.691019                4.024787                13.331376
#
#   Data-Source  Data-Year
# 0       MICS6       2019
# 1       MICS6       2019
# 2       MICS6       2019
# 3       MICS6       2019
# 4       MICS6  2018-2019

# %%
df.shape
# Out:
# (94, 18)

# %% [markdown]
# **Drop the unnecessary data column**

# %%
df = df.drop(('Data-Source'), axis=1)

# %%
df.head()
# Out:
#         Countries and areas Region Sub-region Development regions  \
# 0                Bangladesh     SA         SA     Least Developed
# 1                Bangladesh     SA         SA     Least Developed
# 2                Bangladesh     SA         SA     Least Developed
# 3                Bangladesh     SA         SA     Least Developed
# 4  Central African Republic    SSA        WCA     Least Developed
#
#      Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0  Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1  Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2    Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3    Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4  Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
#
#    Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0        55.805260                35.360210               43.906765
# 1        32.791283                19.557022               25.148443
# 2        35.798244                16.602999               18.201494
# 3        17.041044                 8.673656               10.437841
# 4         9.213395                 0.486284                3.040068
#
#    Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0               50.639637               54.517452                63.611889
# 1               27.337364               31.040785                38.721001
# 2               22.767086               28.660402                42.274563
# 3               11.085612               12.559054                22.395241
# 4                1.691019                4.024787                13.331376
#
#    Data-Year
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4  2018-2019

# %% [markdown]
# ## Describing the Data

# %%
df.dtypes
# Out:
# Countries and areas         object
# Region                      object
# Sub-region                  object
# Development regions         object
# Age group                   object
# Subject                     object
# Total                      float64
# Sex-Girls                  float64
# Sex-Boys                   float64
# Residence-Rural            float64
# Residence-Urban            float64
# Wealth quintile-Poorest    float64
# Wealth quintile-Second     float64
# Wealth quintile-Middle     float64
# Wealth quintile-Fourth     float64
# Wealth quintile-Richest    float64
# Data-Year                   object
# dtype: object

# %%
df.describe()
# Out:
#            Total  Sex-Girls   Sex-Boys  Residence-Rural  Residence-Urban  \
# count  94.000000  94.000000  94.000000        94.000000        94.000000
# mean   25.024077  25.861465  24.228419        22.350986        29.768563
# std    20.770505  21.860690  20.015429        21.112209        21.387091
# min     0.394631   0.051010   0.473044         0.022533         0.000000
# 25%     7.234411   6.782024   7.440390         4.550694        12.301420
# 50%    19.756634  19.898628  20.007759        13.027112        24.972675
# 75%    39.055473  41.669121  37.287081        36.599011        44.219891
# max    81.800000  84.400000  82.000000        83.400000        79.000000
#
#        Wealth quintile-Poorest  Wealth quintile-Second  \
# count                94.000000               94.000000
# mean                 17.371929               21.387640
# std                  19.048739               20.722063
# min                   0.000000                0.000000
# 25%                   2.479506                3.636985
# 50%                   8.001463               12.608856
# 75%                  27.821079               33.977889
# max                  76.100000               89.800000
#
#        Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest
# count               94.000000               94.000000                94.000000
# mean                24.266147               28.115457                37.684759
# std                 22.238528               22.135513                23.564574
# min                  0.000000                0.000000                 0.000000
# 25%                  4.610935                8.740612                17.095623
# 50%                 16.606810               24.916075                37.256182
# 75%                 42.645542               44.460066                58.154563
# max                 78.600000               79.900000                84.800000

# %% [markdown]
# **Is the data entered by a human?**

# %%
df['Age group'].unique()
# Out:
# array(['Age 7 to 14', 'Grade 2/3'], dtype=object)

# %%
df['Development regions'].unique()
# Out:
# array(['Least Developed', 'Less Developed', 'More Developed'],
#       dtype=object)

# %%
df['Subject'].unique()
# Out:
# array(['Reading', 'Numeracy'], dtype=object)

# %% [markdown]
# ### Box Plot

# %%
df_total = df[['Total']]
df_total
# Out:
#         Total
# 0   48.814716
# 1   27.866051
# 2   24.599609
# 3   12.550222
# 4    4.693856
# ..        ...
# 93  70.000000
# 96  44.365719
# 97  24.620714
# 98  19.576178
# 99   5.108691
#
# [94 rows x 1 columns]

# %%
sns.boxplot(y='Total', width=0.15, data=df_total)
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
sns.boxplot(x='Subject', y='Total', width=0.3, data=df)
# Out:
# <AxesSubplot:xlabel='Subject', ylabel='Total'>

# %%
sns.set_style('whitegrid')  # with lines
sns.boxplot(x='Subject', y='Total', width=0.3, data=df)
# Out:
# <AxesSubplot:xlabel='Subject', ylabel='Total'>

# %% [markdown]
# ## Additional Dataset

# %% [markdown]
# ### Literacy-rate_2021-1.xlsx

# %%
xl_file = pd.ExcelFile('Literacy-rate_2021-1.xlsx')

literacy = xl_file.parse('Youth literacy rate, aged 15-24', header=[0, 1])
    
literacy
# Out:
#                   ISO3        Countries and areas             Region  \
#     Unnamed: 0_level_1         Unnamed: 1_level_1 Unnamed: 2_level_1
# 0                  AFG                Afghanistan                 SA
# 1                  ALB                    Albania                ECA
# 2                  DZA                    Algeria               MENA
# 3                  AND                    Andorra                ECA
# 4                  AGO                     Angola                SSA
# ..                 ...                        ...                ...
# 214                NaN                 South Asia                 SA
# 215                NaN         Sub-Saharan Africa                SSA
# 216                NaN  Eastern & Southern Africa                NaN
# 217                NaN      West & Central Africa                NaN
# 218                NaN                      World                NaN
#
#              Sub-region Development Regions              Total     Gender  \
#     UNICEF Sub-region 1  Unnamed: 4_level_1 Unnamed: 5_level_1     Female
# 0                    SA     Least Developed          65.420547  56.254749
# 1                  EECA      More Developed          99.330002  99.629997
# 2                  MENA      Less Developed          97.426521  97.252159
# 3                    WE      More Developed                NaN        NaN
# 4                   ESA     Least Developed                NaN        NaN
# ..                  ...                 ...                ...        ...
# 214                 NaN            89.95697                NaN        NaN
# 215                 NaN           76.328102                NaN        NaN
# 216                 ESA           79.924637                NaN        NaN
# 217                 WCA           72.341187                NaN        NaN
# 218                 NaN           91.725731                NaN        NaN
#
#                     Source
#           Male Data source Time period
# 0    74.084801         UIS      2018.0
# 1    99.050003         UIS      2018.0
# 2    97.594063         UIS      2018.0
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# ..         ...         ...         ...
# 214        NaN         NaN         NaN
# 215        NaN         NaN         NaN
# 216        NaN         NaN         NaN
# 217        NaN         NaN         NaN
# 218        NaN         NaN         NaN
#
# [219 rows x 10 columns]

# %% [markdown]
# **Combine the column header**

# %%
col = []
for i in range(len(literacy.columns)):
    if i < 6:
        col.append(literacy.columns[i][0])
    else:
        col.append(literacy.columns[i][0] + '-' + literacy.columns[i][1])    
#literacy.drop(literacy.index[100:], inplace=True)
literacy.columns = col
literacy
# Out:
#     ISO3        Countries and areas Region Sub-region Development Regions  \
# 0    AFG                Afghanistan     SA         SA     Least Developed
# 1    ALB                    Albania    ECA       EECA      More Developed
# 2    DZA                    Algeria   MENA       MENA      Less Developed
# 3    AND                    Andorra    ECA         WE      More Developed
# 4    AGO                     Angola    SSA        ESA     Least Developed
# ..   ...                        ...    ...        ...                 ...
# 214  NaN                 South Asia     SA        NaN            89.95697
# 215  NaN         Sub-Saharan Africa    SSA        NaN           76.328102
# 216  NaN  Eastern & Southern Africa    NaN        ESA           79.924637
# 217  NaN      West & Central Africa    NaN        WCA           72.341187
# 218  NaN                      World    NaN        NaN           91.725731
#
#          Total  Gender-Female  Gender-Male Source-Data source  \
# 0    65.420547      56.254749    74.084801                UIS
# 1    99.330002      99.629997    99.050003                UIS
# 2    97.426521      97.252159    97.594063                UIS
# 3          NaN            NaN          NaN                NaN
# 4          NaN            NaN          NaN                NaN
# ..         ...            ...          ...                ...
# 214        NaN            NaN          NaN                NaN
# 215        NaN            NaN          NaN                NaN
# 216        NaN            NaN          NaN                NaN
# 217        NaN            NaN          NaN                NaN
# 218        NaN            NaN          NaN                NaN
#
#      Source-Time period
# 0                2018.0
# 1                2018.0
# 2                2018.0
# 3                   NaN
# 4                   NaN
# ..                  ...
# 214                 NaN
# 215                 NaN
# 216                 NaN
# 217                 NaN
# 218                 NaN
#
# [219 rows x 10 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Step 1: Handling missing data

# %% [markdown]
# **Are there any missing values?**

# %%
literacy.isnull().sum() * 100 / len(literacy)
# Out:
# ISO3                    7.762557
# Countries and areas     1.826484
# Region                  5.936073
# Sub-region              6.849315
# Development Regions     2.283105
# Total                  64.383562
# Gender-Female          64.383562
# Gender-Male            64.383562
# Source-Data source     64.383562
# Source-Time period     64.383562
# dtype: float64

# %%
literacy.isnull().sum()
# Out:
# ISO3                    17
# Countries and areas      4
# Region                  13
# Sub-region              15
# Development Regions      5
# Total                  141
# Gender-Female          141
# Gender-Male            141
# Source-Data source     141
# Source-Time period     141
# dtype: int64

# %%
literacy.shape
# Out:
# (219, 10)

# %% [markdown]
# ### Step 2: Remove the irrelevant observations

# %% [markdown]
# **Drop the data columns with missing data 'NaN'**

# %%
literacy.dropna(inplace=True)
literacy
# Out:
#     ISO3 Countries and areas Region Sub-region Development Regions      Total  \
# 0    AFG         Afghanistan     SA         SA     Least Developed  65.420547
# 1    ALB             Albania    ECA       EECA      More Developed  99.330002
# 2    DZA             Algeria   MENA       MENA      Less Developed  97.426521
# 7    ARG           Argentina    LAC        LAC      Less Developed  99.505524
# 13   BHR             Bahrain   MENA       MENA      Less Developed  99.687202
# ..   ...                 ...    ...        ...                 ...        ...
# 194  URY             Uruguay    LAC        LAC      Less Developed  98.880272
# 195  UZB          Uzbekistan    ECA       EECA      Less Developed  99.999939
# 196  VUT             Vanuatu    EAP        EAP     Least Developed  96.282120
# 198  VNM            Viet Nam    EAP        EAP      Less Developed  98.408096
# 200  ZMB              Zambia    SSA        ESA     Least Developed  92.091568
#
#      Gender-Female  Gender-Male Source-Data source  Source-Time period
# 0        56.254749    74.084801                UIS              2018.0
# 1        99.629997    99.050003                UIS              2018.0
# 2        97.252159    97.594063                UIS              2018.0
# 7        99.757652    99.241829                UIS              2018.0
# 13       99.301338    99.976143                UIS              2018.0
# ..             ...          ...                ...                 ...
# 194      99.165993    98.604752                UIS              2018.0
# 195      99.999924    99.999931                UIS              2018.0
# 196      96.596611    95.976570                UIS              2018.0
# 198      98.353142    98.460121                UIS              2018.0
# 200      91.628189    92.559639                UIS              2018.0
#
# [78 rows x 10 columns]

# %% [markdown]
# ### Subset and renaming column

# %%
literacy.rename(columns={'Total':'Literacy_Total'}, inplace=True)
literacy = literacy[['Countries and areas', 'Literacy_Total']]
literacy
# Out:
#     Countries and areas  Literacy_Total
# 0           Afghanistan       65.420547
# 1               Albania       99.330002
# 2               Algeria       97.426521
# 7             Argentina       99.505524
# 13              Bahrain       99.687202
# ..                  ...             ...
# 194             Uruguay       98.880272
# 195          Uzbekistan       99.999939
# 196             Vanuatu       96.282120
# 198            Viet Nam       98.408096
# 200              Zambia       92.091568
#
# [78 rows x 2 columns]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Normalization

# %% [markdown]
# Data before normalization is performed on the data:

# %%
df[['Total', 'Sex-Girls', 'Sex-Boys', 'Residence-Rural', 'Residence-Urban', 'Wealth quintile-Poorest', 'Wealth quintile-Second', 'Wealth quintile-Middle', 'Wealth quintile-Fourth', 'Wealth quintile-Richest']]
# Out:
#         Total  Sex-Girls   Sex-Boys  Residence-Rural  Residence-Urban  \
# 0   48.814716  52.392544  45.074005        46.981983        55.805260
# 1   27.866051  28.959688  26.722622        26.574785        32.791283
# 2   24.599609  26.002825  23.178070        21.751852        35.798244
# 3   12.550222  12.392838  12.709662        11.408230        17.041044
# 4    4.693856   4.560828   4.809788         2.057838         9.213395
# ..        ...        ...        ...              ...              ...
# 93  70.000000  71.800000  68.300000        69.400000        70.900000
# 96  44.365719  48.368660  40.518608        36.768028        67.629013
# 97  24.620714  26.782095  22.543474        19.146442        41.382336
# 98  19.576178  21.219332  17.992134        12.351241        41.673153
# 99   5.108691   4.419424   5.773163         2.455187        13.224252
#
#     Wealth quintile-Poorest  Wealth quintile-Second  Wealth quintile-Middle  \
# 0                 35.360210               43.906765               50.639637
# 1                 19.557022               25.148443               27.337364
# 2                 16.602999               18.201494               22.767086
# 3                  8.673656               10.437841               11.085612
# 4                  0.486284                3.040068                1.691019
# ..                      ...                     ...                     ...
# 93                61.400000               68.000000               72.300000
# 96                25.323767               34.230465               44.128292
# 97                12.622963               21.344015               20.532696
# 98                 6.278276               10.377341               16.939035
# 99                 0.395979                2.538109                2.018403
#
#     Wealth quintile-Fourth  Wealth quintile-Richest
# 0                54.517452                63.611889
# 1                31.040785                38.721001
# 2                28.660402                42.274563
# 3                12.559054                22.395241
# 4                 4.024787                13.331376
# ..                     ...                      ...
# 93               71.200000                79.100000
# 96               56.616516                76.777069
# 97               31.470972                47.066925
# 98               27.667347                50.681393
# 99                8.800878                17.066843
#
# [94 rows x 10 columns]

# %%
sc = MinMaxScaler(feature_range = (0, 1))
df_min_max_scaled = df.copy()
#fit: get min/max of train data
col_list = [col for col in df.columns.tolist() if df[col].dtype.name != "object"]

df_min_max_scaled[col_list] = sc.fit_transform(df[col_list])
df_min_max_scaled
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 93              Turkmenistan    ECA       EECA      Less Developed
# 96                  Zimbabwe    SSA        ESA      Less Developed
# 97                  Zimbabwe    SSA        ESA      Less Developed
# 98                  Zimbabwe    SSA        ESA      Less Developed
# 99                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject     Total  Sex-Girls  Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  0.594802   0.620535  0.547070         0.563215
# 1   Age 7 to 14  Numeracy  0.337464   0.342727  0.321974         0.318458
# 2     Grade 2/3   Reading  0.297339   0.307672  0.278497         0.260614
# 3     Grade 2/3  Numeracy  0.149322   0.146319  0.150093         0.136556
# 4   Age 7 to 14   Reading  0.052813   0.053466  0.053194         0.024411
# ..          ...       ...       ...        ...       ...              ...
# 93  Age 7 to 14  Numeracy  0.855046   0.850621  0.831957         0.832089
# 96  Age 7 to 14   Reading  0.540150   0.572830  0.491194         0.440713
# 97  Age 7 to 14  Numeracy  0.297598   0.316911  0.270713         0.229365
# 98    Grade 2/3   Reading  0.235630   0.250961  0.214887         0.147866
# 99    Grade 2/3  Numeracy  0.057908   0.051790  0.065011         0.029176
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0          0.706396                 0.464655                0.488939
# 1          0.415080                 0.256991                0.280049
# 2          0.453142                 0.218173                0.202689
# 3          0.215709                 0.113977                0.116234
# 4          0.116625                 0.006390                0.033854
# ..              ...                      ...                     ...
# 93         0.897468                 0.806833                0.757238
# 96         0.856063                 0.332770                0.381186
# 97         0.523827                 0.165873                0.237684
# 98         0.527508                 0.082500                0.115561
# 99         0.167396                 0.005203                0.028264
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                 0.644270                0.682321                 0.750140
# 1                 0.347804                0.388495                 0.456616
# 2                 0.289658                0.358703                 0.498521
# 3                 0.141038                0.157185                 0.264095
# 4                 0.021514                0.050373                 0.157210
# ..                     ...                     ...                      ...
# 93                0.919847                0.891114                 0.932783
# 96                0.561429                0.708592                 0.905390
# 97                0.261230                0.393880                 0.555034
# 98                0.215509                0.346275                 0.597658
# 99                0.025679                0.110149                 0.201260
#
#     Data-Year
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4   2018-2019
# ..        ...
# 93       2019
# 96       2019
# 97       2019
# 98       2019
# 99       2019
#
# [94 rows x 17 columns]

# %% [markdown]
# Data after normalization is performed on the data:

# %%
df_min_max_scaled
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 93              Turkmenistan    ECA       EECA      Less Developed
# 96                  Zimbabwe    SSA        ESA      Less Developed
# 97                  Zimbabwe    SSA        ESA      Less Developed
# 98                  Zimbabwe    SSA        ESA      Less Developed
# 99                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject     Total  Sex-Girls  Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  0.594802   0.620535  0.547070         0.563215
# 1   Age 7 to 14  Numeracy  0.337464   0.342727  0.321974         0.318458
# 2     Grade 2/3   Reading  0.297339   0.307672  0.278497         0.260614
# 3     Grade 2/3  Numeracy  0.149322   0.146319  0.150093         0.136556
# 4   Age 7 to 14   Reading  0.052813   0.053466  0.053194         0.024411
# ..          ...       ...       ...        ...       ...              ...
# 93  Age 7 to 14  Numeracy  0.855046   0.850621  0.831957         0.832089
# 96  Age 7 to 14   Reading  0.540150   0.572830  0.491194         0.440713
# 97  Age 7 to 14  Numeracy  0.297598   0.316911  0.270713         0.229365
# 98    Grade 2/3   Reading  0.235630   0.250961  0.214887         0.147866
# 99    Grade 2/3  Numeracy  0.057908   0.051790  0.065011         0.029176
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0          0.706396                 0.464655                0.488939
# 1          0.415080                 0.256991                0.280049
# 2          0.453142                 0.218173                0.202689
# 3          0.215709                 0.113977                0.116234
# 4          0.116625                 0.006390                0.033854
# ..              ...                      ...                     ...
# 93         0.897468                 0.806833                0.757238
# 96         0.856063                 0.332770                0.381186
# 97         0.523827                 0.165873                0.237684
# 98         0.527508                 0.082500                0.115561
# 99         0.167396                 0.005203                0.028264
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                 0.644270                0.682321                 0.750140
# 1                 0.347804                0.388495                 0.456616
# 2                 0.289658                0.358703                 0.498521
# 3                 0.141038                0.157185                 0.264095
# 4                 0.021514                0.050373                 0.157210
# ..                     ...                     ...                      ...
# 93                0.919847                0.891114                 0.932783
# 96                0.561429                0.708592                 0.905390
# 97                0.261230                0.393880                 0.555034
# 98                0.215509                0.346275                 0.597658
# 99                0.025679                0.110149                 0.201260
#
#     Data-Year
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4   2018-2019
# ..        ...
# 93       2019
# 96       2019
# 97       2019
# 98       2019
# 99       2019
#
# [94 rows x 17 columns]

# %% [markdown]
# ### Merging

# %% [markdown]
# Merging is the process of combining two or more datasets into a single dataset.
# <br><br>
# In our datasets, outer merging is performed to allow us to unify and better understand the data when analyzing it.

# %%
df_merge = df.copy()

# %%
literacy.rename(columns={'Total':'Literacy_Total'}, inplace=True)
literacy = literacy[['Countries and areas', 'Literacy_Total']]
literacy
# Out:
#     Countries and areas  Literacy_Total
# 0           Afghanistan       65.420547
# 1               Albania       99.330002
# 2               Algeria       97.426521
# 7             Argentina       99.505524
# 13              Bahrain       99.687202
# ..                  ...             ...
# 194             Uruguay       98.880272
# 195          Uzbekistan       99.999939
# 196             Vanuatu       96.282120
# 198            Viet Nam       98.408096
# 200              Zambia       92.091568
#
# [78 rows x 2 columns]

# %%
df_merge = df_merge.merge(literacy, how='left')
df_merge
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 89              Turkmenistan    ECA       EECA      Less Developed
# 90                  Zimbabwe    SSA        ESA      Less Developed
# 91                  Zimbabwe    SSA        ESA      Less Developed
# 92                  Zimbabwe    SSA        ESA      Less Developed
# 93                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1   Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2     Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3     Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4   Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
# ..          ...       ...        ...        ...        ...              ...
# 89  Age 7 to 14  Numeracy  70.000000  71.800000  68.300000        69.400000
# 90  Age 7 to 14   Reading  44.365719  48.368660  40.518608        36.768028
# 91  Age 7 to 14  Numeracy  24.620714  26.782095  22.543474        19.146442
# 92    Grade 2/3   Reading  19.576178  21.219332  17.992134        12.351241
# 93    Grade 2/3  Numeracy   5.108691   4.419424   5.773163         2.455187
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0         55.805260                35.360210               43.906765
# 1         32.791283                19.557022               25.148443
# 2         35.798244                16.602999               18.201494
# 3         17.041044                 8.673656               10.437841
# 4          9.213395                 0.486284                3.040068
# ..              ...                      ...                     ...
# 89        70.900000                61.400000               68.000000
# 90        67.629013                25.323767               34.230465
# 91        41.382336                12.622963               21.344015
# 92        41.673153                 6.278276               10.377341
# 93        13.224252                 0.395979                2.538109
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                50.639637               54.517452                63.611889
# 1                27.337364               31.040785                38.721001
# 2                22.767086               28.660402                42.274563
# 3                11.085612               12.559054                22.395241
# 4                 1.691019                4.024787                13.331376
# ..                     ...                     ...                      ...
# 89               72.300000               71.200000                79.100000
# 90               44.128292               56.616516                76.777069
# 91               20.532696               31.470972                47.066925
# 92               16.939035               27.667347                50.681393
# 93                2.018403                8.800878                17.066843
#
#     Data-Year  Literacy_Total
# 0        2019       94.862427
# 1        2019       94.862427
# 2        2019       94.862427
# 3        2019       94.862427
# 4   2018-2019       38.268650
# ..        ...             ...
# 89       2019             NaN
# 90       2019             NaN
# 91       2019             NaN
# 92       2019             NaN
# 93       2019             NaN
#
# [94 rows x 18 columns]

# %%
df_merge['Literacy_Total'].fillna(value=df_merge['Literacy_Total'].mean(), inplace=True)

# %%
#df_merge[['Literacy_Total']] = sc.fit_transform(df_merge[['Literacy_Total']])

# %%
df_merge
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 89              Turkmenistan    ECA       EECA      Less Developed
# 90                  Zimbabwe    SSA        ESA      Less Developed
# 91                  Zimbabwe    SSA        ESA      Less Developed
# 92                  Zimbabwe    SSA        ESA      Less Developed
# 93                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1   Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2     Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3     Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4   Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
# ..          ...       ...        ...        ...        ...              ...
# 89  Age 7 to 14  Numeracy  70.000000  71.800000  68.300000        69.400000
# 90  Age 7 to 14   Reading  44.365719  48.368660  40.518608        36.768028
# 91  Age 7 to 14  Numeracy  24.620714  26.782095  22.543474        19.146442
# 92    Grade 2/3   Reading  19.576178  21.219332  17.992134        12.351241
# 93    Grade 2/3  Numeracy   5.108691   4.419424   5.773163         2.455187
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0         55.805260                35.360210               43.906765
# 1         32.791283                19.557022               25.148443
# 2         35.798244                16.602999               18.201494
# 3         17.041044                 8.673656               10.437841
# 4          9.213395                 0.486284                3.040068
# ..              ...                      ...                     ...
# 89        70.900000                61.400000               68.000000
# 90        67.629013                25.323767               34.230465
# 91        41.382336                12.622963               21.344015
# 92        41.673153                 6.278276               10.377341
# 93        13.224252                 0.395979                2.538109
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                50.639637               54.517452                63.611889
# 1                27.337364               31.040785                38.721001
# 2                22.767086               28.660402                42.274563
# 3                11.085612               12.559054                22.395241
# 4                 1.691019                4.024787                13.331376
# ..                     ...                     ...                      ...
# 89               72.300000               71.200000                79.100000
# 90               44.128292               56.616516                76.777069
# 91               20.532696               31.470972                47.066925
# 92               16.939035               27.667347                50.681393
# 93                2.018403                8.800878                17.066843
#
#     Data-Year  Literacy_Total
# 0        2019       94.862427
# 1        2019       94.862427
# 2        2019       94.862427
# 3        2019       94.862427
# 4   2018-2019       38.268650
# ..        ...             ...
# 89       2019       88.629192
# 90       2019       88.629192
# 91       2019       88.629192
# 92       2019       88.629192
# 93       2019       88.629192
#
# [94 rows x 18 columns]

# %% [markdown]
# ### Binning

# %% [markdown]
# Bining is a process of grouping or categorizing numeric data into discrete bins or discrete baskets, which is one of the ways of dealing with noisy data.
# <br><br>
# In this data, binning is performed on the ‘Total’ variable, and we bin it into 3 bins, which are ‘Low’, ‘Medium’, and ‘High’ to simplify the analysis.

# %%
df_min_max_scaled['Total'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# In order to get an idea on how the values are distributed, we use matplotlib library to plot the histogram.

# %%
plt.hist(df_min_max_scaled['Total'])

# set x/y labels and plot title
plt.xlabel('Total')
plt.ylabel('Number of Children')
plt.title('Total bins')
# Out:
# Text(0.5, 1.0, 'Total bins')

# %% [markdown]
# We want 3 bins of equal size, therefore we use Numpy's `linspace(start_value, end_value, numbers_generated)` function.
# <br><br>
# In order to build 3 bins, we need to define 4 dividers or boundaries:

# %%
bins = np.linspace(min(df_min_max_scaled['Total']), max(df_min_max_scaled['Total']), 4)
bins
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %% [markdown]
# So these are the dividers of the 3 bins, if we were to give it the starting value, ending value, and the number of values to be generated at equal intervals.
#
# The bin group names is created as shown below:

# %%
group_names = ['Low', 'Medium', 'High']

# %% [markdown]
# In order to determine the value of ‘Total’ is belongs to which level: ‘Low’, ‘Medium’, or ‘High’, the pandas function `cut` is applied to the data.

# %%
df_min_max_scaled['Total-binned'] = pd.cut(df_min_max_scaled['Total'], bins, labels=group_names, include_lowest=True )

# %%
df_min_max_scaled[['Total','Total-binned']].head(15)
# Out:
#        Total Total-binned
# 0   0.594802       Medium
# 1   0.337464       Medium
# 2   0.297339          Low
# 3   0.149322          Low
# 4   0.052813          Low
# 5   0.013920          Low
# 6   0.016966          Low
# 7   0.000000          Low
# 8   0.049165          Low
# 9   0.079003          Low
# 10  0.026280          Low
# 11  0.061384          Low
# 12  0.102334          Low
# 13  0.001275          Low
# 14  0.095865          Low

# %%
df_min_max_scaled['Total-binned'].value_counts()
# Out:
# Low       59
# Medium    25
# High      10
# Name: Total-binned, dtype: int64

# %% [markdown]
# Plotting the distribution of the bins:

# %%
plt.bar(group_names, df_min_max_scaled['Total-binned'].value_counts())

# set x/y labels and plot title 
plt.xlabel('Total')
plt.ylabel('Number of Children')
plt.title('Total Bins')
# Out:
# Text(0.5, 1.0, 'Total Bins')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_cleaned = df_min_max_scaled.copy()

# %%
df_cleaned
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 93              Turkmenistan    ECA       EECA      Less Developed
# 96                  Zimbabwe    SSA        ESA      Less Developed
# 97                  Zimbabwe    SSA        ESA      Less Developed
# 98                  Zimbabwe    SSA        ESA      Less Developed
# 99                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject     Total  Sex-Girls  Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  0.594802   0.620535  0.547070         0.563215
# 1   Age 7 to 14  Numeracy  0.337464   0.342727  0.321974         0.318458
# 2     Grade 2/3   Reading  0.297339   0.307672  0.278497         0.260614
# 3     Grade 2/3  Numeracy  0.149322   0.146319  0.150093         0.136556
# 4   Age 7 to 14   Reading  0.052813   0.053466  0.053194         0.024411
# ..          ...       ...       ...        ...       ...              ...
# 93  Age 7 to 14  Numeracy  0.855046   0.850621  0.831957         0.832089
# 96  Age 7 to 14   Reading  0.540150   0.572830  0.491194         0.440713
# 97  Age 7 to 14  Numeracy  0.297598   0.316911  0.270713         0.229365
# 98    Grade 2/3   Reading  0.235630   0.250961  0.214887         0.147866
# 99    Grade 2/3  Numeracy  0.057908   0.051790  0.065011         0.029176
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0          0.706396                 0.464655                0.488939
# 1          0.415080                 0.256991                0.280049
# 2          0.453142                 0.218173                0.202689
# 3          0.215709                 0.113977                0.116234
# 4          0.116625                 0.006390                0.033854
# ..              ...                      ...                     ...
# 93         0.897468                 0.806833                0.757238
# 96         0.856063                 0.332770                0.381186
# 97         0.523827                 0.165873                0.237684
# 98         0.527508                 0.082500                0.115561
# 99         0.167396                 0.005203                0.028264
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                 0.644270                0.682321                 0.750140
# 1                 0.347804                0.388495                 0.456616
# 2                 0.289658                0.358703                 0.498521
# 3                 0.141038                0.157185                 0.264095
# 4                 0.021514                0.050373                 0.157210
# ..                     ...                     ...                      ...
# 93                0.919847                0.891114                 0.932783
# 96                0.561429                0.708592                 0.905390
# 97                0.261230                0.393880                 0.555034
# 98                0.215509                0.346275                 0.597658
# 99                0.025679                0.110149                 0.201260
#
#     Data-Year Total-binned
# 0        2019       Medium
# 1        2019       Medium
# 2        2019          Low
# 3        2019          Low
# 4   2018-2019          Low
# ..        ...          ...
# 93       2019         High
# 96       2019       Medium
# 97       2019          Low
# 98       2019          Low
# 99       2019          Low
#
# [94 rows x 18 columns]

# %% [markdown]
# ### Descriptive Question

# %% [markdown]
# **“What is the mean of the percentage of children who acquired foundational learning skills are from age 7 to 14?”**

# %%
df_cleaned['Total'].unique()
# Out:
# array([0.59480211, 0.33746447, 0.29733884, 0.14932174, 0.05281255,
#        0.01392013, 0.01696592, 0.        , 0.04916508, 0.07900308,
#        0.02628041, 0.0613843 , 0.10233371, 0.00127469, 0.095865  ,
#        0.00414718, 0.14760852, 0.10122852, 0.0589104 , 0.04094385,
#        0.25783733, 0.18791412, 0.06695199, 0.09070282, 0.14776384,
#        0.08716702, 0.06627206, 0.05039741, 0.43038994, 0.26021728,
#        0.35147016, 0.14232494, 0.70463373, 0.62586819, 0.4705136 ,
#        0.36508159, 0.53291381, 0.15819981, 0.15269859, 0.00870904,
#        0.2840384 , 0.08432335, 0.16061969, 0.0431432 , 0.77210111,
#        0.56352979, 0.55051513, 0.35060715, 0.4763856 , 0.44780898,
#        0.23900976, 0.23668374, 0.78502646, 0.49757613, 0.44341632,
#        0.13839809, 0.30344008, 0.08392053, 0.46652061, 0.43484891,
#        0.24157059, 0.21387929, 0.19074573, 0.14517942, 0.06825832,
#        0.06441808, 0.64251426, 0.55776914, 0.31765184, 0.31463363,
#        0.5702703 , 0.30206648, 0.27775963, 0.05051276, 0.88885524,
#        0.83681515, 0.69673   , 0.62360202, 0.21283172, 0.10346371,
#        0.0446846 , 0.03247319, 0.76414332, 0.63884446, 0.80571504,
#        0.341575  , 0.57194491, 0.18403839, 1.        , 0.85504642,
#        0.54014973, 0.2975981 , 0.23562999, 0.05790846])

# %%
df_cleaned['Age group'].unique()
# Out:
# array(['Age 7 to 14', 'Grade 2/3'], dtype=object)

# %%
df_cleaned['Subject'].unique()
# Out:
# array(['Reading', 'Numeracy'], dtype=object)

# %%
df_cleaned.loc[df['Age group'] == 'Age 7 to 14'].groupby(['Age group', 'Subject'])['Total'].mean().to_frame('Mean of percentage of children who acquired foundational learning skills')
# Out:
#                       Mean of percentage of children who acquired foundational learning skills
# Age group   Subject
# Age 7 to 14 Numeracy                                           0.323884
#             Reading                                            0.474519

# %% [markdown]
# ### Exploratory Question

# %% [markdown]
# **“What is the relationship between the wealth quintile and the percentage of children in the given age group who demonstrated foundational reading or numeracy skills?”**

# %%
df_cleaned[['Total', 'Wealth quintile-Poorest', 'Wealth quintile-Second', 'Wealth quintile-Middle', 'Wealth quintile-Fourth', 'Wealth quintile-Richest']]
# Out:
#        Total  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0   0.594802                 0.464655                0.488939
# 1   0.337464                 0.256991                0.280049
# 2   0.297339                 0.218173                0.202689
# 3   0.149322                 0.113977                0.116234
# 4   0.052813                 0.006390                0.033854
# ..       ...                      ...                     ...
# 93  0.855046                 0.806833                0.757238
# 96  0.540150                 0.332770                0.381186
# 97  0.297598                 0.165873                0.237684
# 98  0.235630                 0.082500                0.115561
# 99  0.057908                 0.005203                0.028264
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest
# 0                 0.644270                0.682321                 0.750140
# 1                 0.347804                0.388495                 0.456616
# 2                 0.289658                0.358703                 0.498521
# 3                 0.141038                0.157185                 0.264095
# 4                 0.021514                0.050373                 0.157210
# ..                     ...                     ...                      ...
# 93                0.919847                0.891114                 0.932783
# 96                0.561429                0.708592                 0.905390
# 97                0.261230                0.393880                 0.555034
# 98                0.215509                0.346275                 0.597658
# 99                0.025679                0.110149                 0.201260
#
# [94 rows x 6 columns]

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# The correlation between two attributes, such as ‘Total’ and ‘Wealth quintile’ can be better visualized in a scatter plot of data points.

# %%
fig, axs = plt.subplots(figsize=(15,15), sharey=True)
plt.title('Relationship between the wealth quintile and the percentage of children in the given age group who demonstrated foundational reading or numeracy skills')
axs.scatter(df_cleaned['Wealth quintile-Poorest'],df_cleaned['Total'])
axs.scatter(df_cleaned['Wealth quintile-Second'],df_cleaned['Total'])
axs.scatter(df_cleaned['Wealth quintile-Middle'],df_cleaned['Total'])
axs.scatter(df_cleaned['Wealth quintile-Fourth'],df_cleaned['Total'])
axs.scatter(df_cleaned['Wealth quintile-Richest'],df_cleaned['Total'])
plt.ylim(0,)
# Out:
# (0.0, 1.0499999999999998)

# %%
sns.scatterplot(x=df_cleaned['Wealth quintile-Poorest'], y=df_cleaned['Total'], data=df_cleaned)
sns.regplot(x=df_cleaned['Wealth quintile-Poorest'], y=df_cleaned['Total'], data=df_cleaned,
            scatter_kws={"color": "yellow"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 1.1796037171653861)

# %%
sns.scatterplot(x=df_cleaned['Wealth quintile-Second'], y=df_cleaned['Total'], data=df_cleaned)
sns.regplot(x=df_cleaned['Wealth quintile-Second'], y=df_cleaned['Total'], data=df_cleaned,
            scatter_kws={"color": "g"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 1.2303206054518265)

# %%
sns.scatterplot(x=df_cleaned['Wealth quintile-Middle'], y=df_cleaned['Total'], data=df_cleaned)
sns.regplot(x=df_cleaned['Wealth quintile-Middle'], y=df_cleaned['Total'], data=df_cleaned,
            scatter_kws={"color": "r"}, line_kws={"color": "green"})
plt.ylim(0,)
# Out:
# (0.0, 1.0499999999999998)

# %%
sns.scatterplot(x=df_cleaned['Wealth quintile-Fourth'], y=df_cleaned['Total'], data=df_cleaned)
sns.regplot(x=df_cleaned['Wealth quintile-Fourth'], y=df_cleaned['Total'], data=df_cleaned,
            scatter_kws={"color": "b"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 1.0514465850213268)

# %%
sns.scatterplot(x=df_cleaned['Wealth quintile-Richest'], y=df_cleaned['Total'], data=df_cleaned)
sns.regplot(x=df_cleaned['Wealth quintile-Richest'], y=df_cleaned['Total'], data=df_cleaned,
            scatter_kws={"color": "orange"}, line_kws={"color": "red"})
plt.ylim(0,)
# Out:
# (0.0, 1.0553969007308082)

# %% [markdown]
# ### Inferential Question

# %% [markdown]
# **“Based on the sample population of children who lived in Mongolia, the percentage of children who demonstrated foundational reading skills is higher than the percentage of children who demonstrated foundation numeracy skills. Will this hypothesis stand for the children who lived in Lesotho?”**

# %%
dfIQ = df_cleaned[['Countries and areas','Age group','Subject','Total']]
dfIQ
# Out:
#          Countries and areas    Age group   Subject     Total
# 0                 Bangladesh  Age 7 to 14   Reading  0.594802
# 1                 Bangladesh  Age 7 to 14  Numeracy  0.337464
# 2                 Bangladesh    Grade 2/3   Reading  0.297339
# 3                 Bangladesh    Grade 2/3  Numeracy  0.149322
# 4   Central African Republic  Age 7 to 14   Reading  0.052813
# ..                       ...          ...       ...       ...
# 93              Turkmenistan  Age 7 to 14  Numeracy  0.855046
# 96                  Zimbabwe  Age 7 to 14   Reading  0.540150
# 97                  Zimbabwe  Age 7 to 14  Numeracy  0.297598
# 98                  Zimbabwe    Grade 2/3   Reading  0.235630
# 99                  Zimbabwe    Grade 2/3  Numeracy  0.057908
#
# [94 rows x 4 columns]

# %% [markdown]
# **Data Visualization**

# %%
filter = dfIQ['Countries and areas'] == 'Mongolia'
dfMong = dfIQ[filter]
dfMong
# Out:
#    Countries and areas    Age group   Subject     Total
# 44            Mongolia  Age 7 to 14   Reading  0.772101
# 45            Mongolia  Age 7 to 14  Numeracy  0.563530
# 46            Mongolia    Grade 2/3   Reading  0.550515
# 47            Mongolia    Grade 2/3  Numeracy  0.350607

# %%
sns.set_style('whitegrid')  # with lines
sns.boxplot(x='Subject', y='Total', width=0.3, data=dfMong)
# Out:
# <AxesSubplot:xlabel='Subject', ylabel='Total'>

# %%
filter = dfIQ['Countries and areas'] == 'Lesotho'
dfLeso = dfIQ[filter]
dfLeso
# Out:
#    Countries and areas    Age group   Subject     Total
# 36             Lesotho  Age 7 to 14   Reading  0.532914
# 37             Lesotho  Age 7 to 14  Numeracy  0.158200
# 38             Lesotho    Grade 2/3   Reading  0.152699
# 39             Lesotho    Grade 2/3  Numeracy  0.008709

# %%
sns.set_style('whitegrid')  # with lines
sns.boxplot(x='Subject', y='Total', width=0.3, data=dfLeso)
# Out:
# <AxesSubplot:xlabel='Subject', ylabel='Total'>

# %% [markdown]
# ## Predictive Question

# %% [markdown]
# **“What is the predicted average percentage of children of Mongolia who acquired foundational learning skills in the year 2022?"**

# %% [markdown]
# ### Data modeling

# %%
df_pred = df_merge.copy()

# %%
df_pred
# Out:
#          Countries and areas Region Sub-region Development regions  \
# 0                 Bangladesh     SA         SA     Least Developed
# 1                 Bangladesh     SA         SA     Least Developed
# 2                 Bangladesh     SA         SA     Least Developed
# 3                 Bangladesh     SA         SA     Least Developed
# 4   Central African Republic    SSA        WCA     Least Developed
# ..                       ...    ...        ...                 ...
# 89              Turkmenistan    ECA       EECA      Less Developed
# 90                  Zimbabwe    SSA        ESA      Less Developed
# 91                  Zimbabwe    SSA        ESA      Less Developed
# 92                  Zimbabwe    SSA        ESA      Less Developed
# 93                  Zimbabwe    SSA        ESA      Less Developed
#
#       Age group   Subject      Total  Sex-Girls   Sex-Boys  Residence-Rural  \
# 0   Age 7 to 14   Reading  48.814716  52.392544  45.074005        46.981983
# 1   Age 7 to 14  Numeracy  27.866051  28.959688  26.722622        26.574785
# 2     Grade 2/3   Reading  24.599609  26.002825  23.178070        21.751852
# 3     Grade 2/3  Numeracy  12.550222  12.392838  12.709662        11.408230
# 4   Age 7 to 14   Reading   4.693856   4.560828   4.809788         2.057838
# ..          ...       ...        ...        ...        ...              ...
# 89  Age 7 to 14  Numeracy  70.000000  71.800000  68.300000        69.400000
# 90  Age 7 to 14   Reading  44.365719  48.368660  40.518608        36.768028
# 91  Age 7 to 14  Numeracy  24.620714  26.782095  22.543474        19.146442
# 92    Grade 2/3   Reading  19.576178  21.219332  17.992134        12.351241
# 93    Grade 2/3  Numeracy   5.108691   4.419424   5.773163         2.455187
#
#     Residence-Urban  Wealth quintile-Poorest  Wealth quintile-Second  \
# 0         55.805260                35.360210               43.906765
# 1         32.791283                19.557022               25.148443
# 2         35.798244                16.602999               18.201494
# 3         17.041044                 8.673656               10.437841
# 4          9.213395                 0.486284                3.040068
# ..              ...                      ...                     ...
# 89        70.900000                61.400000               68.000000
# 90        67.629013                25.323767               34.230465
# 91        41.382336                12.622963               21.344015
# 92        41.673153                 6.278276               10.377341
# 93        13.224252                 0.395979                2.538109
#
#     Wealth quintile-Middle  Wealth quintile-Fourth  Wealth quintile-Richest  \
# 0                50.639637               54.517452                63.611889
# 1                27.337364               31.040785                38.721001
# 2                22.767086               28.660402                42.274563
# 3                11.085612               12.559054                22.395241
# 4                 1.691019                4.024787                13.331376
# ..                     ...                     ...                      ...
# 89               72.300000               71.200000                79.100000
# 90               44.128292               56.616516                76.777069
# 91               20.532696               31.470972                47.066925
# 92               16.939035               27.667347                50.681393
# 93                2.018403                8.800878                17.066843
#
#     Data-Year  Literacy_Total
# 0        2019       94.862427
# 1        2019       94.862427
# 2        2019       94.862427
# 3        2019       94.862427
# 4   2018-2019       38.268650
# ..        ...             ...
# 89       2019       88.629192
# 90       2019       88.629192
# 91       2019       88.629192
# 92       2019       88.629192
# 93       2019       88.629192
#
# [94 rows x 18 columns]

# %%
df1 = df_pred.groupby(['Countries and areas']).mean()
df1
# Out:
#                                       Total  Sex-Girls   Sex-Boys  \
# Countries and areas
# Bangladesh                        28.457650  29.936974  26.921090
# Central African Republic           2.098010   1.903119   2.257982
# Chad                               4.787120   3.673869   5.796649
# Democratic Republic of the Congo   4.538583   4.197713   4.839093
# Gambia                             7.490967   8.470875   6.290215
# Ghana                             12.674759  11.714040  13.613712
# Guinea-Bissau                      7.550170   6.811296   8.414608
# Kiribati                          24.498808  28.008585  21.276123
# Kyrgyzstan                        44.477615  47.493664  41.494103
# Lesotho                           17.744583  22.070246  13.339312
# Madagascar                        12.038136  13.358035  10.642258
# Mongolia                          45.915561  47.032182  44.896492
# Nepal                             28.884233  27.542053  30.115323
# North Macedonia                   52.600000  52.750000  52.450000
# Pakistan (Punjab)                 20.118644  20.672270  19.570481
# Sao Tome and Principe             28.007727  28.274540  27.726088
# Sierra Leone                       9.931302  10.093184   9.697365
# State of Palestine                37.689867  38.719875  36.612906
# Suriname                          24.828640  24.929855  24.720779
# Thailand                          62.384869  64.624920  60.344976
# Togo                               8.401932   8.747430   8.096163
# Tonga                             57.500000  59.250000  56.300000
# Tunisia                           39.128798  39.222327  39.045281
# Turkmenistan                      75.900000  78.100000  75.150000
# Zimbabwe                          23.417825  25.197378  21.706845
#
#                                   Residence-Rural  Residence-Urban  \
# Countries and areas
# Bangladesh                              26.679213        35.358958
# Central African Republic                 1.235993         3.572731
# Chad                                     3.337531        10.998854
# Democratic Republic of the Congo         1.951247         7.877791
# Gambia                                   3.353714         9.795963
# Ghana                                    7.257946        20.007260
# Guinea-Bissau                            5.329292        11.426943
# Kiribati                                25.201998        23.782427
# Kyrgyzstan                              40.868649        52.184168
# Lesotho                                 14.154734        25.551792
# Madagascar                              10.253337        19.181288
# Mongolia                                45.716413        45.971610
# Nepal                                   22.230234        32.268646
# North Macedonia                         49.750000        54.600000
# Pakistan (Punjab)                       17.216530        25.862854
# Sao Tome and Principe                   28.127020        28.029842
# Sierra Leone                             3.321153        18.810709
# State of Palestine                      44.952353        36.903003
# Suriname                                20.324048        28.259443
# Thailand                                60.087102        66.102015
# Togo                                     4.846422        15.205730
# Tonga                                   55.100000        66.650000
# Tunisia                                 30.498024        43.332021
# Turkmenistan                            76.400000        74.950000
# Zimbabwe                                17.680225        40.977188
#
#                                   Wealth quintile-Poorest  \
# Countries and areas
# Bangladesh                                      20.048472
# Central African Republic                         0.274432
# Chad                                             1.028218
# Democratic Republic of the Congo                 0.841633
# Gambia                                           3.051757
# Ghana                                            2.965855
# Guinea-Bissau                                    3.616009
# Kiribati                                        21.125338
# Kyrgyzstan                                      43.984973
# Lesotho                                         10.493038
# Madagascar                                       3.288500
# Mongolia                                        42.448674
# Nepal                                           17.220667
# North Macedonia                                 37.500000
# Pakistan (Punjab)                               10.268830
# Sao Tome and Principe                           15.351950
# Sierra Leone                                     2.121923
# State of Palestine                              24.899458
# Suriname                                        15.857430
# Thailand                                        51.291915
# Togo                                             2.994494
# Tonga                                           54.550000
# Tunisia                                         23.511508
# Turkmenistan                                    68.750000
# Zimbabwe                                        11.155246
#
#                                   Wealth quintile-Second  \
# Countries and areas
# Bangladesh                                     24.423636
# Central African Republic                        1.675630
# Chad                                            2.092605
# Democratic Republic of the Congo                2.178914
# Gambia                                          4.936874
# Ghana                                           9.244453
# Guinea-Bissau                                   5.439116
# Kiribati                                       26.591137
# Kyrgyzstan                                     32.767901
# Lesotho                                        14.375267
# Madagascar                                      6.839827
# Mongolia                                       42.331579
# Nepal                                          23.398364
# North Macedonia                                46.450000
# Pakistan (Punjab)                              17.682534
# Sao Tome and Principe                          23.204760
# Sierra Leone                                    3.209028
# State of Palestine                             34.292490
# Suriname                                       22.120027
# Thailand                                       63.096280
# Togo                                            2.852764
# Tonga                                          54.400000
# Tunisia                                        32.858882
# Turkmenistan                                   78.900000
# Zimbabwe                                       17.122483
#
#                                   Wealth quintile-Middle  \
# Countries and areas
# Bangladesh                                     27.957425
# Central African Republic                        1.446283
# Chad                                            3.087163
# Democratic Republic of the Congo                2.471255
# Gambia                                          6.671892
# Ghana                                           9.863954
# Guinea-Bissau                                   5.593220
# Kiribati                                       15.562242
# Kyrgyzstan                                     44.911137
# Lesotho                                        18.983188
# Madagascar                                      9.543415
# Mongolia                                       47.330433
# Nepal                                          28.046100
# North Macedonia                                62.100000
# Pakistan (Punjab)                              21.691156
# Sao Tome and Principe                          23.807015
# Sierra Leone                                    6.003114
# State of Palestine                             41.134936
# Suriname                                       24.613552
# Thailand                                       61.326746
# Togo                                            7.601809
# Tonga                                          56.900000
# Tunisia                                        44.478826
# Turkmenistan                                   75.450000
# Zimbabwe                                       20.904607
#
#                                   Wealth quintile-Fourth  \
# Countries and areas
# Bangladesh                                     31.694423
# Central African Republic                        1.641818
# Chad                                            5.168837
# Democratic Republic of the Congo                5.541369
# Gambia                                          9.002618
# Ghana                                          15.696862
# Guinea-Bissau                                  10.653504
# Kiribati                                       21.064391
# Kyrgyzstan                                     43.086610
# Lesotho                                        17.640988
# Madagascar                                     15.407758
# Mongolia                                       50.259643
# Nepal                                          33.386619
# North Macedonia                                59.100000
# Pakistan (Punjab)                              24.068590
# Sao Tome and Principe                          33.806330
# Sierra Leone                                   16.837421
# State of Palestine                             40.892951
# Suriname                                       31.265849
# Thailand                                       68.203829
# Togo                                           13.601930
# Tonga                                          58.700000
# Tunisia                                        43.976978
# Turkmenistan                                   75.550000
# Zimbabwe                                       31.138928
#
#                                   Wealth quintile-Richest  Literacy_Total
# Countries and areas
# Bangladesh                                      41.750673       94.862427
# Central African Republic                         5.060483       38.268650
# Chad                                            11.012239       88.629192
# Democratic Republic of the Congo                12.632685       88.629192
# Gambia                                          15.863188       88.629192
# Ghana                                           31.864600       92.490967
# Guinea-Bissau                                   12.506775       88.629192
# Kiribati                                        39.231844       88.629192
# Kyrgyzstan                                      61.754772       99.750000
# Lesotho                                         31.278154       88.629192
# Madagascar                                      31.608770       81.198372
# Mongolia                                        48.303205       98.629997
# Nepal                                           48.217019       92.393806
# North Macedonia                                 68.200000       88.629192
# Pakistan (Punjab)                               32.334630       88.629192
# Sao Tome and Principe                           45.730419       97.782547
# Sierra Leone                                    24.046462       66.648598
# State of Palestine                              49.904262       99.336250
# Suriname                                        43.619288       98.645561
# Thailand                                        69.455782       98.137169
# Togo                                            20.314568       88.629192
# Tonga                                           65.450000       99.441116
# Tunisia                                         53.403966       88.629192
# Turkmenistan                                    81.950000       88.629192
# Zimbabwe                                        47.898057       88.629192

# %%
df1.shape
# Out:
# (25, 11)

# %%
corr = df1.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds"))
# Out:
# <AxesSubplot:>

# %%
df1 = df1.reset_index()

# %% [markdown]
# ### Split train-test dataset

# %%
X = df1[['Total']]
Y = df1[['Literacy_Total']]

# %%
plt.plot(X,Y, linestyle='',marker='o')
plt.xlabel('Total')
plt.ylabel('Literacy Total')
plt.title('Total vs Literacy_Total')
# Out:
# Text(0.5, 1.0, 'Total vs Literacy_Total')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Create Linear Regression model

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([[0.28026504]])

# %%
lm.intercept_
# Out:
# array([81.18755437])

# %%
lm_y_test = lm.predict(X_test)
lm_y_train = lm.predict(X_train)

print('Train r2 score: ', r2_score(lm_y_train, y_train))
print('Test r2 score: ', r2_score(y_test, lm_y_test)) 
print('Train MAE: ', mean_absolute_error(lm_y_train, y_train))
print('Test MAE: ',mean_absolute_error(y_test, lm_y_test))
print('Train MSE: ', mean_squared_error(lm_y_train, y_train))
print('Test MSE: ',mean_squared_error(y_test, lm_y_test))
# Out:
# Train r2 score:  -3.660288056520913
# Test r2 score:  0.3917083662423514
# Train MAE:  7.152553217015968
# Test MAE:  7.256409821517974
# Train MSE:  131.0307153311166
# Test MSE:  83.71201922752401

# %%
sns.regplot(y_test, lm_y_test, data=df1)
# Out:
# <AxesSubplot:xlabel='Literacy_Total'>

# %% [markdown]
# ### Create Decision Tree Regression model

# %%
dtr1 = DecisionTreeRegressor(max_depth=3)
dtr1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
dtr_y_test = dtr1.predict(X_test)
dtr_y_train = dtr1.predict(X_train)

print('Train r2 score: ', r2_score(dtr_y_train, y_train))
print('Test r2 score: ', r2_score(y_test, dtr_y_test)) 
print('Train MAE: ', mean_absolute_error(dtr_y_train, y_train))
print('Test MAE: ',mean_absolute_error(y_test, dtr_y_test))
print('Train MSE: ', mean_squared_error(dtr_y_train, y_train))
print('Test MSE: ',mean_squared_error(y_test, dtr_y_test))
# Out:
# Train r2 score:  0.9286202624026584
# Test r2 score:  0.23187957351466804
# Train MAE:  2.3416746398925765
# Test MAE:  6.620469079589839
# Train MSE:  10.603040058719918
# Test MSE:  105.7073751183834

# %%
sns.regplot(y_test, dtr_y_test, data=df1)
# Out:
# <AxesSubplot:xlabel='Literacy_Total'>

# %%
depth = 30
max_depth = [i for i in range(1,depth+1)] 
dtr_mae = [] 
for i in range(1,depth+1):
    dtr = DecisionTreeRegressor(max_depth=i)
    dtr.fit(X_train, y_train)
    dtr_y_pred = dtr.predict(X_test)
    dtr_mae.append(mean_absolute_error(y_test, dtr_y_pred))
    
plt.plot(max_depth, dtr_mae)
plt.xlabel('max_depth')
plt.ylabel('MAE')
plt.title('max_depth vs MAE')
plt.show()

# %% [markdown]
# ### Create Neural Network Regression model

# %%
df_nn = df1.copy()

# %%
df_countries = df.copy()

# %%
df_countries = df_countries[['Countries and areas', 'Region', 'Sub-region', 'Development regions']]

# %%
df_countries = df_countries.drop_duplicates().reset_index()
df_countries.drop(columns=['index'], inplace = True)

# %%
df_nn = df_nn.merge(df_countries, how='left')
df_nn.head()
# Out:
#                 Countries and areas      Total  Sex-Girls   Sex-Boys  \
# 0                        Bangladesh  28.457650  29.936974  26.921090
# 1          Central African Republic   2.098010   1.903119   2.257982
# 2                              Chad   4.787120   3.673869   5.796649
# 3  Democratic Republic of the Congo   4.538583   4.197713   4.839093
# 4                            Gambia   7.490967   8.470875   6.290215
#
#    Residence-Rural  Residence-Urban  Wealth quintile-Poorest  \
# 0        26.679213        35.358958                20.048472
# 1         1.235993         3.572731                 0.274432
# 2         3.337531        10.998854                 1.028218
# 3         1.951247         7.877791                 0.841633
# 4         3.353714         9.795963                 3.051757
#
#    Wealth quintile-Second  Wealth quintile-Middle  Wealth quintile-Fourth  \
# 0               24.423636               27.957425               31.694423
# 1                1.675630                1.446283                1.641818
# 2                2.092605                3.087163                5.168837
# 3                2.178914                2.471255                5.541369
# 4                4.936874                6.671892                9.002618
#
#    Wealth quintile-Richest  Literacy_Total Region Sub-region  \
# 0                41.750673       94.862427     SA         SA
# 1                 5.060483       38.268650    SSA        WCA
# 2                11.012239       88.629192    SSA        WCA
# 3                12.632685       88.629192    SSA        WCA
# 4                15.863188       88.629192    SSA        WCA
#
#   Development regions
# 0     Least Developed
# 1     Least Developed
# 2     Least Developed
# 3     Least Developed
# 4     Least Developed

# %%
df_nn = df_nn[['Countries and areas', 'Region', 'Sub-region', 'Development regions', 'Total', 'Literacy_Total']]

# %%
sc_total = MinMaxScaler(feature_range = (0, 1))
sc_literacy = MinMaxScaler(feature_range = (0, 1))

sc_total = sc_total.fit(df1[['Total']])
sc_literacy = sc_literacy.fit(df1[['Literacy_Total']])

# %%
df_nn[['Total']] = sc_total.transform(df_nn[['Total']])
df_nn[['Literacy_Total']] = sc_literacy.transform(df_nn[['Literacy_Total']])
df_nn
# Out:
#                  Countries and areas Region Sub-region Development regions  \
# 0                         Bangladesh     SA         SA     Least Developed
# 1           Central African Republic    SSA        WCA     Least Developed
# 2                               Chad    SSA        WCA     Least Developed
# 3   Democratic Republic of the Congo    SSA        WCA     Least Developed
# 4                             Gambia    SSA        WCA     Least Developed
# 5                              Ghana    SSA        WCA      Less Developed
# 6                      Guinea-Bissau    SSA        WCA     Least Developed
# 7                           Kiribati    EAP        EAP     Least Developed
# 8                         Kyrgyzstan    ECA       EECA      Less Developed
# 9                            Lesotho    SSA        ESA     Least Developed
# 10                        Madagascar    SSA        ESA     Least Developed
# 11                          Mongolia    EAP        EAP      Less Developed
# 12                             Nepal     SA         SA     Least Developed
# 13                   North Macedonia    ECA       EECA      More Developed
# 14                 Pakistan (Punjab)     SA         SA      Less Developed
# 15             Sao Tome and Principe    SSA        WCA     Least Developed
# 16                      Sierra Leone    SSA        WCA     Least Developed
# 17                State of Palestine   MENA       MENA      Less Developed
# 18                          Suriname    LAC        LAC      Less Developed
# 19                          Thailand    EAP        EAP      Less Developed
# 20                              Togo    SSA        WCA     Least Developed
# 21                             Tonga    EAP        EAP      Less Developed
# 22                           Tunisia   MENA       MENA      Less Developed
# 23                      Turkmenistan    ECA       EECA      Less Developed
# 24                          Zimbabwe    SSA        ESA      Less Developed
#
#        Total  Literacy_Total
# 0   0.357167        0.920503
# 1   0.000000        0.000000
# 2   0.036437        0.819119
# 3   0.033069        0.819119
# 4   0.073073        0.819119
# 5   0.143313        0.881931
# 6   0.073876        0.819119
# 7   0.303526        0.819119
# 8   0.574234        1.000000
# 9   0.212007        0.819119
# 10  0.134686        0.698256
# 11  0.593718        0.981783
# 12  0.362947        0.880351
# 13  0.684290        0.819119
# 14  0.244175        0.819119
# 15  0.351071        0.967999
# 16  0.106139        0.461603
# 17  0.482261        0.993270
# 18  0.307995        0.982036
# 19  0.816873        0.973767
# 20  0.085417        0.819119
# 21  0.750684        0.994976
# 22  0.501759        0.819119
# 23  1.000000        0.819119
# 24  0.288879        0.819119

# %%
d = defaultdict(LabelEncoder)
col_list = [col for col in df_nn.columns.tolist() if df_nn[col].dtype.name == "object"]

df_nn[col_list] = df_nn[col_list].apply(lambda x: d[x.name].fit_transform(x))

# %%
X = df_nn.drop(columns=['Literacy_Total'])
y = df_nn['Literacy_Total']

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
#create model
model = Sequential()

#get number of columns in training data
n_cols = xTrain.shape[1]
n_cols
# Out:
# 5

# %%
#add model layers
model.add(Dense(250,  input_shape=(n_cols,)))
model.add(Dense(250, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#compile model using mse as a measure of model performance
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train model
history = model.fit(xTrain, yTrain, validation_split=0.2, epochs=200,  verbose=2)
# Out:
# Epoch 1/200
# 1/1 - 0s - loss: 0.0777 - val_loss: 0.0388 - 359ms/epoch - 359ms/step
# Epoch 2/200
# 1/1 - 0s - loss: 0.0375 - val_loss: 0.0652 - 16ms/epoch - 16ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 0.0346 - val_loss: 0.1014 - 19ms/epoch - 19ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 0.0305 - val_loss: 0.1326 - 19ms/epoch - 19ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 0.0306 - val_loss: 0.1498 - 21ms/epoch - 21ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 0.0316 - val_loss: 0.1557 - 19ms/epoch - 19ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 0.0306 - val_loss: 0.1551 - 22ms/epoch - 22ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 0.0289 - val_loss: 0.1516 - 19ms/epoch - 19ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 0.0280 - val_loss: 0.1481 - 18ms/epoch - 18ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.0281 - val_loss: 0.1473 - 18ms/epoch - 18ms/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.0285 - val_loss: 0.1503 - 26ms/epoch - 26ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.0284 - val_loss: 0.1565 - 20ms/epoch - 20ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.0278 - val_loss: 0.1644 - 19ms/epoch - 19ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.0272 - val_loss: 0.1723 - 19ms/epoch - 19ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.0268 - val_loss: 0.1788 - 20ms/epoch - 20ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.0267 - val_loss: 0.1835 - 16ms/epoch - 16ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.0268 - val_loss: 0.1863 - 18ms/epoch - 18ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.0269 - val_loss: 0.1876 - 17ms/epoch - 17ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.0267 - val_loss: 0.1878 - 18ms/epoch - 18ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.0265 - val_loss: 0.1873 - 17ms/epoch - 17ms/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.0262 - val_loss: 0.1863 - 19ms/epoch - 19ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.0261 - val_loss: 0.1853 - 17ms/epoch - 17ms/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.0261 - val_loss: 0.1848 - 17ms/epoch - 17ms/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.0262 - val_loss: 0.1852 - 17ms/epoch - 17ms/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.0262 - val_loss: 0.1864 - 18ms/epoch - 18ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.0261 - val_loss: 0.1882 - 17ms/epoch - 17ms/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.0260 - val_loss: 0.1904 - 18ms/epoch - 18ms/step
# Epoch 28/200
# 1/1 - 0s - loss: 0.0259 - val_loss: 0.1927 - 17ms/epoch - 17ms/step
# Epoch 29/200
# 1/1 - 0s - loss: 0.0258 - val_loss: 0.1946 - 16ms/epoch - 16ms/step
# Epoch 30/200
# 1/1 - 0s - loss: 0.0258 - val_loss: 0.1960 - 17ms/epoch - 17ms/step
# Epoch 31/200
# 1/1 - 0s - loss: 0.0258 - val_loss: 0.1970 - 25ms/epoch - 25ms/step
# Epoch 32/200
# 1/1 - 0s - loss: 0.0258 - val_loss: 0.1974 - 19ms/epoch - 19ms/step
# Epoch 33/200
# 1/1 - 0s - loss: 0.0258 - val_loss: 0.1975 - 18ms/epoch - 18ms/step
# Epoch 34/200
# 1/1 - 0s - loss: 0.0257 - val_loss: 0.1973 - 20ms/epoch - 20ms/step
# Epoch 35/200
# 1/1 - 0s - loss: 0.0257 - val_loss: 0.1971 - 19ms/epoch - 19ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.1970 - 18ms/epoch - 18ms/step
# Epoch 37/200
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.1971 - 17ms/epoch - 17ms/step
# Epoch 38/200
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.1973 - 17ms/epoch - 17ms/step
# Epoch 39/200
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.1977 - 18ms/epoch - 18ms/step
# Epoch 40/200
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.1983 - 17ms/epoch - 17ms/step
# Epoch 41/200
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.1990 - 17ms/epoch - 17ms/step
# Epoch 42/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.1998 - 19ms/epoch - 19ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2005 - 22ms/epoch - 22ms/step
# Epoch 44/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2011 - 19ms/epoch - 19ms/step
# Epoch 45/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2016 - 18ms/epoch - 18ms/step
# Epoch 46/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2018 - 17ms/epoch - 17ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2019 - 17ms/epoch - 17ms/step
# Epoch 48/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2018 - 17ms/epoch - 17ms/step
# Epoch 49/200
# 1/1 - 0s - loss: 0.0255 - val_loss: 0.2017 - 17ms/epoch - 17ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2016 - 17ms/epoch - 17ms/step
# Epoch 51/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2017 - 17ms/epoch - 17ms/step
# Epoch 52/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2018 - 18ms/epoch - 18ms/step
# Epoch 53/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2020 - 18ms/epoch - 18ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2022 - 18ms/epoch - 18ms/step
# Epoch 55/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2026 - 18ms/epoch - 18ms/step
# Epoch 56/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2031 - 18ms/epoch - 18ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.2035 - 16ms/epoch - 16ms/step
# Epoch 58/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2038 - 17ms/epoch - 17ms/step
# Epoch 59/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2041 - 17ms/epoch - 17ms/step
# Epoch 60/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2042 - 17ms/epoch - 17ms/step
# Epoch 61/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2043 - 18ms/epoch - 18ms/step
# Epoch 62/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2043 - 17ms/epoch - 17ms/step
# Epoch 63/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2044 - 16ms/epoch - 16ms/step
# Epoch 64/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2043 - 17ms/epoch - 17ms/step
# Epoch 65/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2044 - 18ms/epoch - 18ms/step
# Epoch 66/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2045 - 18ms/epoch - 18ms/step
# Epoch 67/200
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.2046 - 17ms/epoch - 17ms/step
# Epoch 68/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2048 - 18ms/epoch - 18ms/step
# Epoch 69/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2049 - 18ms/epoch - 18ms/step
# Epoch 70/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2051 - 16ms/epoch - 16ms/step
# Epoch 71/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2053 - 18ms/epoch - 18ms/step
# Epoch 72/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2055 - 18ms/epoch - 18ms/step
# Epoch 73/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2057 - 17ms/epoch - 17ms/step
# Epoch 74/200
# 1/1 - 0s - loss: 0.0252 - val_loss: 0.2058 - 20ms/epoch - 20ms/step
# Epoch 75/200
# 1/1 - 0s - loss: 0.0251 - val_loss: 0.2059 - 17ms/epoch - 17ms/step
# Epoch 76/200
# 1/1 - 0s - loss: 0.0251 - val_loss: 0.2060 - 18ms/epoch - 18ms/step
# Epoch 77/200
# 1/1 - 0s - loss: 0.0251 - val_loss: 0.2060 - 16ms/epoch - 16ms/step
# Epoch 78/200
# 1/1 - 0s - loss: 0.0250 - val_loss: 0.2060 - 18ms/epoch - 18ms/step
# Epoch 79/200
# 1/1 - 0s - loss: 0.0250 - val_loss: 0.2059 - 17ms/epoch - 17ms/step
# Epoch 80/200
# 1/1 - 0s - loss: 0.0250 - val_loss: 0.2059 - 18ms/epoch - 18ms/step
# Epoch 81/200
# 1/1 - 0s - loss: 0.0250 - val_loss: 0.2058 - 17ms/epoch - 17ms/step
# Epoch 82/200
# 1/1 - 0s - loss: 0.0250 - val_loss: 0.2058 - 18ms/epoch - 18ms/step
# Epoch 83/200
# 1/1 - 0s - loss: 0.0249 - val_loss: 0.2059 - 17ms/epoch - 17ms/step
# Epoch 84/200
# 1/1 - 0s - loss: 0.0249 - val_loss: 0.2059 - 17ms/epoch - 17ms/step
# Epoch 85/200
# 1/1 - 0s - loss: 0.0249 - val_loss: 0.2060 - 19ms/epoch - 19ms/step
# Epoch 86/200
# 1/1 - 0s - loss: 0.0248 - val_loss: 0.2061 - 19ms/epoch - 19ms/step
# Epoch 87/200
# 1/1 - 0s - loss: 0.0248 - val_loss: 0.2062 - 17ms/epoch - 17ms/step
# Epoch 88/200
# 1/1 - 0s - loss: 0.0247 - val_loss: 0.2064 - 18ms/epoch - 18ms/step
# Epoch 89/200
# 1/1 - 0s - loss: 0.0247 - val_loss: 0.2065 - 17ms/epoch - 17ms/step
# Epoch 90/200
# 1/1 - 0s - loss: 0.0247 - val_loss: 0.2067 - 17ms/epoch - 17ms/step
# Epoch 91/200
# 1/1 - 0s - loss: 0.0246 - val_loss: 0.2067 - 20ms/epoch - 20ms/step
# Epoch 92/200
# 1/1 - 0s - loss: 0.0246 - val_loss: 0.2067 - 18ms/epoch - 18ms/step
# Epoch 93/200
# 1/1 - 0s - loss: 0.0245 - val_loss: 0.2066 - 22ms/epoch - 22ms/step
# Epoch 94/200
# 1/1 - 0s - loss: 0.0244 - val_loss: 0.2065 - 24ms/epoch - 24ms/step
# Epoch 95/200
# 1/1 - 0s - loss: 0.0244 - val_loss: 0.2064 - 20ms/epoch - 20ms/step
# Epoch 96/200
# 1/1 - 0s - loss: 0.0243 - val_loss: 0.2064 - 25ms/epoch - 25ms/step
# Epoch 97/200
# 1/1 - 0s - loss: 0.0242 - val_loss: 0.2063 - 18ms/epoch - 18ms/step
# Epoch 98/200
# 1/1 - 0s - loss: 0.0241 - val_loss: 0.2063 - 18ms/epoch - 18ms/step
# Epoch 99/200
# 1/1 - 0s - loss: 0.0239 - val_loss: 0.2063 - 18ms/epoch - 18ms/step
# Epoch 100/200
# 1/1 - 0s - loss: 0.0237 - val_loss: 0.2062 - 19ms/epoch - 19ms/step
# Epoch 101/200
# 1/1 - 0s - loss: 0.0235 - val_loss: 0.2062 - 17ms/epoch - 17ms/step
# Epoch 102/200
# 1/1 - 0s - loss: 0.0233 - val_loss: 0.2061 - 19ms/epoch - 19ms/step
# Epoch 103/200
# 1/1 - 0s - loss: 0.0230 - val_loss: 0.2060 - 18ms/epoch - 18ms/step
# Epoch 104/200
# 1/1 - 0s - loss: 0.0227 - val_loss: 0.2057 - 17ms/epoch - 17ms/step
# Epoch 105/200
# 1/1 - 0s - loss: 0.0222 - val_loss: 0.2053 - 17ms/epoch - 17ms/step
# Epoch 106/200
# 1/1 - 0s - loss: 0.0216 - val_loss: 0.2049 - 19ms/epoch - 19ms/step
# Epoch 107/200
# 1/1 - 0s - loss: 0.0209 - val_loss: 0.2043 - 16ms/epoch - 16ms/step
# Epoch 108/200
# 1/1 - 0s - loss: 0.0199 - val_loss: 0.2036 - 18ms/epoch - 18ms/step
# Epoch 109/200
# 1/1 - 0s - loss: 0.0186 - val_loss: 0.2027 - 18ms/epoch - 18ms/step
# Epoch 110/200
# 1/1 - 0s - loss: 0.0169 - val_loss: 0.2014 - 16ms/epoch - 16ms/step
# Epoch 111/200
# 1/1 - 0s - loss: 0.0150 - val_loss: 0.2008 - 17ms/epoch - 17ms/step
# Epoch 112/200
# 1/1 - 0s - loss: 0.0132 - val_loss: 0.2072 - 17ms/epoch - 17ms/step
# Epoch 113/200
# 1/1 - 0s - loss: 0.0138 - val_loss: 0.2111 - 18ms/epoch - 18ms/step
# Epoch 114/200
# 1/1 - 0s - loss: 0.0148 - val_loss: 0.2017 - 17ms/epoch - 17ms/step
# Epoch 115/200
# 1/1 - 0s - loss: 0.0128 - val_loss: 0.1974 - 18ms/epoch - 18ms/step
# Epoch 116/200
# 1/1 - 0s - loss: 0.0129 - val_loss: 0.1979 - 17ms/epoch - 17ms/step
# Epoch 117/200
# 1/1 - 0s - loss: 0.0131 - val_loss: 0.2002 - 17ms/epoch - 17ms/step
# Epoch 118/200
# 1/1 - 0s - loss: 0.0128 - val_loss: 0.2026 - 17ms/epoch - 17ms/step
# Epoch 119/200
# 1/1 - 0s - loss: 0.0123 - val_loss: 0.2042 - 18ms/epoch - 18ms/step
# Epoch 120/200
# 1/1 - 0s - loss: 0.0121 - val_loss: 0.2048 - 17ms/epoch - 17ms/step
# Epoch 121/200
# 1/1 - 0s - loss: 0.0120 - val_loss: 0.2044 - 18ms/epoch - 18ms/step
# Epoch 122/200
# 1/1 - 0s - loss: 0.0117 - val_loss: 0.2032 - 18ms/epoch - 18ms/step
# Epoch 123/200
# 1/1 - 0s - loss: 0.0111 - val_loss: 0.2012 - 18ms/epoch - 18ms/step
# Epoch 124/200
# 1/1 - 0s - loss: 0.0108 - val_loss: 0.1993 - 16ms/epoch - 16ms/step
# Epoch 125/200
# 1/1 - 0s - loss: 0.0107 - val_loss: 0.1980 - 18ms/epoch - 18ms/step
# Epoch 126/200
# 1/1 - 0s - loss: 0.0107 - val_loss: 0.1979 - 17ms/epoch - 17ms/step
# Epoch 127/200
# 1/1 - 0s - loss: 0.0106 - val_loss: 0.1991 - 17ms/epoch - 17ms/step
# Epoch 128/200
# 1/1 - 0s - loss: 0.0102 - val_loss: 0.2010 - 18ms/epoch - 18ms/step
# Epoch 129/200
# 1/1 - 0s - loss: 0.0098 - val_loss: 0.2032 - 17ms/epoch - 17ms/step
# Epoch 130/200
# 1/1 - 0s - loss: 0.0095 - val_loss: 0.2048 - 17ms/epoch - 17ms/step
# Epoch 131/200
# 1/1 - 0s - loss: 0.0094 - val_loss: 0.2056 - 17ms/epoch - 17ms/step
# Epoch 132/200
# 1/1 - 0s - loss: 0.0092 - val_loss: 0.2059 - 17ms/epoch - 17ms/step
# Epoch 133/200
# 1/1 - 0s - loss: 0.0090 - val_loss: 0.2061 - 18ms/epoch - 18ms/step
# Epoch 134/200
# 1/1 - 0s - loss: 0.0087 - val_loss: 0.2065 - 18ms/epoch - 18ms/step
# Epoch 135/200
# 1/1 - 0s - loss: 0.0084 - val_loss: 0.2073 - 17ms/epoch - 17ms/step
# Epoch 136/200
# 1/1 - 0s - loss: 0.0081 - val_loss: 0.2085 - 17ms/epoch - 17ms/step
# Epoch 137/200
# 1/1 - 0s - loss: 0.0079 - val_loss: 0.2091 - 20ms/epoch - 20ms/step
# Epoch 138/200
# 1/1 - 0s - loss: 0.0077 - val_loss: 0.2087 - 25ms/epoch - 25ms/step
# Epoch 139/200
# 1/1 - 0s - loss: 0.0075 - val_loss: 0.2082 - 23ms/epoch - 23ms/step
# Epoch 140/200
# 1/1 - 0s - loss: 0.0073 - val_loss: 0.2085 - 23ms/epoch - 23ms/step
# Epoch 141/200
# 1/1 - 0s - loss: 0.0071 - val_loss: 0.2096 - 19ms/epoch - 19ms/step
# Epoch 142/200
# 1/1 - 0s - loss: 0.0069 - val_loss: 0.2110 - 19ms/epoch - 19ms/step
# Epoch 143/200
# 1/1 - 0s - loss: 0.0068 - val_loss: 0.2114 - 22ms/epoch - 22ms/step
# Epoch 144/200
# 1/1 - 0s - loss: 0.0067 - val_loss: 0.2109 - 21ms/epoch - 21ms/step
# Epoch 145/200
# 1/1 - 0s - loss: 0.0065 - val_loss: 0.2104 - 20ms/epoch - 20ms/step
# Epoch 146/200
# 1/1 - 0s - loss: 0.0064 - val_loss: 0.2107 - 24ms/epoch - 24ms/step
# Epoch 147/200
# 1/1 - 0s - loss: 0.0063 - val_loss: 0.2116 - 26ms/epoch - 26ms/step
# Epoch 148/200
# 1/1 - 0s - loss: 0.0062 - val_loss: 0.2122 - 23ms/epoch - 23ms/step
# Epoch 149/200
# 1/1 - 0s - loss: 0.0061 - val_loss: 0.2118 - 20ms/epoch - 20ms/step
# Epoch 150/200
# 1/1 - 0s - loss: 0.0060 - val_loss: 0.2113 - 20ms/epoch - 20ms/step
# Epoch 151/200
# 1/1 - 0s - loss: 0.0059 - val_loss: 0.2116 - 19ms/epoch - 19ms/step
# Epoch 152/200
# 1/1 - 0s - loss: 0.0058 - val_loss: 0.2126 - 22ms/epoch - 22ms/step
# Epoch 153/200
# 1/1 - 0s - loss: 0.0057 - val_loss: 0.2134 - 25ms/epoch - 25ms/step
# Epoch 154/200
# 1/1 - 0s - loss: 0.0056 - val_loss: 0.2131 - 26ms/epoch - 26ms/step
# Epoch 155/200
# 1/1 - 0s - loss: 0.0055 - val_loss: 0.2128 - 27ms/epoch - 27ms/step
# Epoch 156/200
# 1/1 - 0s - loss: 0.0055 - val_loss: 0.2132 - 22ms/epoch - 22ms/step
# Epoch 157/200
# 1/1 - 0s - loss: 0.0054 - val_loss: 0.2139 - 22ms/epoch - 22ms/step
# Epoch 158/200
# 1/1 - 0s - loss: 0.0053 - val_loss: 0.2140 - 22ms/epoch - 22ms/step
# Epoch 159/200
# 1/1 - 0s - loss: 0.0053 - val_loss: 0.2135 - 44ms/epoch - 44ms/step
# Epoch 160/200
# 1/1 - 0s - loss: 0.0052 - val_loss: 0.2132 - 64ms/epoch - 64ms/step
# Epoch 161/200
# 1/1 - 0s - loss: 0.0052 - val_loss: 0.2135 - 44ms/epoch - 44ms/step
# Epoch 162/200
# 1/1 - 0s - loss: 0.0051 - val_loss: 0.2139 - 33ms/epoch - 33ms/step
# Epoch 163/200
# 1/1 - 0s - loss: 0.0050 - val_loss: 0.2139 - 22ms/epoch - 22ms/step
# Epoch 164/200
# 1/1 - 0s - loss: 0.0050 - val_loss: 0.2136 - 17ms/epoch - 17ms/step
# Epoch 165/200
# 1/1 - 0s - loss: 0.0049 - val_loss: 0.2138 - 18ms/epoch - 18ms/step
# Epoch 166/200
# 1/1 - 0s - loss: 0.0049 - val_loss: 0.2141 - 17ms/epoch - 17ms/step
# Epoch 167/200
# 1/1 - 0s - loss: 0.0049 - val_loss: 0.2140 - 26ms/epoch - 26ms/step
# Epoch 168/200
# 1/1 - 0s - loss: 0.0048 - val_loss: 0.2136 - 22ms/epoch - 22ms/step
# Epoch 169/200
# 1/1 - 0s - loss: 0.0048 - val_loss: 0.2135 - 19ms/epoch - 19ms/step
# Epoch 170/200
# 1/1 - 0s - loss: 0.0047 - val_loss: 0.2137 - 18ms/epoch - 18ms/step
# Epoch 171/200
# 1/1 - 0s - loss: 0.0047 - val_loss: 0.2138 - 18ms/epoch - 18ms/step
# Epoch 172/200
# 1/1 - 0s - loss: 0.0047 - val_loss: 0.2136 - 17ms/epoch - 17ms/step
# Epoch 173/200
# 1/1 - 0s - loss: 0.0047 - val_loss: 0.2136 - 16ms/epoch - 16ms/step
# Epoch 174/200
# 1/1 - 0s - loss: 0.0046 - val_loss: 0.2139 - 18ms/epoch - 18ms/step
# Epoch 175/200
# 1/1 - 0s - loss: 0.0046 - val_loss: 0.2141 - 18ms/epoch - 18ms/step
# Epoch 176/200
# 1/1 - 0s - loss: 0.0046 - val_loss: 0.2142 - 23ms/epoch - 23ms/step
# Epoch 177/200
# 1/1 - 0s - loss: 0.0045 - val_loss: 0.2142 - 18ms/epoch - 18ms/step
# Epoch 178/200
# 1/1 - 0s - loss: 0.0045 - val_loss: 0.2143 - 18ms/epoch - 18ms/step
# Epoch 179/200
# 1/1 - 0s - loss: 0.0045 - val_loss: 0.2144 - 17ms/epoch - 17ms/step
# Epoch 180/200
# 1/1 - 0s - loss: 0.0045 - val_loss: 0.2144 - 17ms/epoch - 17ms/step
# Epoch 181/200
# 1/1 - 0s - loss: 0.0045 - val_loss: 0.2145 - 17ms/epoch - 17ms/step
# Epoch 182/200
# 1/1 - 0s - loss: 0.0044 - val_loss: 0.2146 - 18ms/epoch - 18ms/step
# Epoch 183/200
# 1/1 - 0s - loss: 0.0044 - val_loss: 0.2146 - 16ms/epoch - 16ms/step
# Epoch 184/200
# 1/1 - 0s - loss: 0.0044 - val_loss: 0.2149 - 18ms/epoch - 18ms/step
# Epoch 185/200
# 1/1 - 0s - loss: 0.0044 - val_loss: 0.2146 - 19ms/epoch - 19ms/step
# Epoch 186/200
# 1/1 - 0s - loss: 0.0044 - val_loss: 0.2147 - 16ms/epoch - 16ms/step
# Epoch 187/200
# 1/1 - 0s - loss: 0.0044 - val_loss: 0.2152 - 17ms/epoch - 17ms/step
# Epoch 188/200
# 1/1 - 0s - loss: 0.0043 - val_loss: 0.2149 - 17ms/epoch - 17ms/step
# Epoch 189/200
# 1/1 - 0s - loss: 0.0043 - val_loss: 0.2146 - 18ms/epoch - 18ms/step
# Epoch 190/200
# 1/1 - 0s - loss: 0.0043 - val_loss: 0.2149 - 20ms/epoch - 20ms/step
# Epoch 191/200
# 1/1 - 0s - loss: 0.0043 - val_loss: 0.2153 - 18ms/epoch - 18ms/step
# Epoch 192/200
# 1/1 - 0s - loss: 0.0043 - val_loss: 0.2153 - 16ms/epoch - 16ms/step
# Epoch 193/200
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.2153 - 18ms/epoch - 18ms/step
# Epoch 194/200
# 1/1 - 0s - loss: 0.0043 - val_loss: 0.2156 - 18ms/epoch - 18ms/step
# Epoch 195/200
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.2160 - 16ms/epoch - 16ms/step
# Epoch 196/200
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.2152 - 16ms/epoch - 16ms/step
# Epoch 197/200
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.2155 - 16ms/epoch - 16ms/step
# Epoch 198/200
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.2164 - 17ms/epoch - 17ms/step
# Epoch 199/200
# 1/1 - 0s - loss: 0.0042 - val_loss: 0.2162 - 15ms/epoch - 15ms/step
# Epoch 200/200
# 1/1 - 0s - loss: 0.0041 - val_loss: 0.2157 - 16ms/epoch - 16ms/step

# %%
nn_y_test = model.predict(xTest)
nn_y_train = model.predict(xTrain)

# %%
print('Train r2 score: ', r2_score(yTrain, nn_y_train))
print('Test r2 score: ', r2_score(yTest, nn_y_test)) 
print('Train MAE: ', mean_absolute_error(yTrain, nn_y_train))
print('Test MAE: ',mean_absolute_error(yTest, nn_y_test))
print('Train MSE: ', mean_squared_error(yTrain, nn_y_train))
print('Test MSE: ',mean_squared_error(yTest, nn_y_test))
# Out:
# Train r2 score:  -0.1029086075915362
# Test r2 score:  -1.711763350612613
# Train MAE:  0.09911787318891238
# Test MAE:  0.23271890349868102
# Train MSE:  0.046435659754569134
# Test MSE:  0.09872814379969962

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Regression models prediction

# %%
dtr1.predict([[50]])
# Out:
# array([95.49667694])

# %%
lm.predict([[50]])
# Out:
# array([[95.20080623]])

# %%
df_pred = df_nn.copy()

# %%
real_X = df_pred.drop(columns=['Literacy_Total'])

# %%
real_X = real_X.assign(Total=50)

# %%
real_X[['Total']] = sc_total.transform(real_X[['Total']])

# %%
sc_literacy.inverse_transform([[model.predict(real_X).mean()]])
# Out:
# array([[87.15257239]])

# %% [markdown]
# ## Causal Question

# %% [markdown]
# **“Will an increase in the age of children increase the percentage of children who demonstrated foundational reading or numeracy skills?”**

# %%
df2 = df.copy()

# %%
df2 = df2.groupby(['Age group']).mean().Total.to_frame().reset_index()
df2
# Out:
#      Age group      Total
# 0  Age 7 to 14  32.891776
# 1    Grade 2/3  16.083508

# %%
df2.plot.bar(x='Age group', y='Total')
# Out:
# <AxesSubplot:xlabel='Age group'>

# %%
df2.iloc[0].Total
# Out:
# 32.89177642941475

# %% [markdown]
# For grade 2/3, the age is around 7 to 9, so we take the total of age 7 to 14 minus with grade 2/3 to get the total percentage of age 9 to 14

# %%
new_row = pd.DataFrame({'Age group':['Age 9 to 14'], 'Total': [df2.iloc[0].Total - df2.iloc[1].Total]})
df2 = pd.concat([df2, new_row], ignore_index = True, axis = 0)
df2
# Out:
#      Age group      Total
# 0  Age 7 to 14  32.891776
# 1    Grade 2/3  16.083508
# 2  Age 9 to 14  16.808268

# %%
df2.drop(df2.loc[df2['Age group']=='Age 7 to 14'].index, inplace=True)

# %%
df2.loc[1,['Age group']] = 'Age 7 to 9'

# %%
df2
# Out:
#      Age group      Total
# 1   Age 7 to 9  16.083508
# 2  Age 9 to 14  16.808268

# %%
df2.plot.bar(x='Age group', y='Total')
# Out:
# <AxesSubplot:xlabel='Age group'>

# %% [markdown]
# # Dataset 2: COLLEGE AND UNIVERSITIES

# %% [markdown]
# ## Data collection

# %% [markdown]
# ### Colleges_and_Universities.csv

# %%
df = pd.read_csv('Colleges_and_Universities.csv')

df.head()
# Out:
#             X          Y   FID  IPEDSID  \
# 0  -92.260490  34.759308  7001   107840
# 1 -121.289431  38.713353  7002   112181
# 2 -118.287070  34.101481  7003   116660
# 3 -121.652662  36.700631  7004   125310
# 4  -71.070737  42.369930  7005   164368
#
#                                        NAME                 ADDRESS  \
# 0                           Shorter College           604 Locust St
# 1             Citrus Heights Beauty College          7518 Baird Way
# 2  Joe Blasco Makeup Artist Training Center   1670 Hillhurst Avenue
# 3                  Waynes College of Beauty  1271 North Main Street
# 4        Hult International Business School      1 Education Street
#
#         ADDRESS2            CITY STATE    ZIP  ...          ALIAS SIZE_SET  \
# 0  NOT AVAILABLE   N Little Rock    AR  72114  ...  NOT AVAILABLE       -3
# 1  NOT AVAILABLE  Citris Heights    CA  95610  ...  NOT AVAILABLE       -3
# 2  NOT AVAILABLE     Los Angeles    CA  90027  ...  NOT AVAILABLE       -3
# 3  NOT AVAILABLE         Salinas    CA  93906  ...  NOT AVAILABLE       -3
# 4  NOT AVAILABLE       Cambridge    MA  02141  ...  NOT AVAILABLE       -3
#
#    INST_SIZE PT_ENROLL  FT_ENROLL TOT_ENROLL  HOUSING DORM_CAP  TOT_EMPLOY  \
# 0          1        24         28         52        2        0          18
# 1          1         6         24         30        2        0           9
# 2          1         0         24         24        2        0          11
# 3          1        18         16         34        2        0           9
# 4          2         0       2243       2243        2        0         143
#
#       SHELTER_ID
# 0  NOT AVAILABLE
# 1  NOT AVAILABLE
# 2  NOT AVAILABLE
# 3  NOT AVAILABLE
# 4  NOT AVAILABLE
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (7735, 46)

# %%
df.dtypes
# Out:
# X             float64
# Y             float64
# FID             int64
# IPEDSID         int64
# NAME           object
# ADDRESS        object
# ADDRESS2       object
# CITY           object
# STATE          object
# ZIP            object
# ZIP4           object
# TELEPHONE      object
# TYPE            int64
# STATUS         object
# POPULATION      int64
# COUNTY         object
# COUNTYFIPS      int64
# COUNTRY        object
# LATITUDE      float64
# LONGITUDE     float64
# NAICS_CODE      int64
# NAICS_DESC     object
# SOURCE         object
# SOURCE_DAT     object
# VAL_METHOD     object
# VAL_DATE       object
# WEBSITE        object
# STFIPS          int64
# COFIPS          int64
# SECTOR          int64
# LEVEL_          int64
# HI_OFFER        int64
# DEG_GRANT       int64
# LOCALE          int64
# CLOSE_DATE     object
# MERGE_ID        int64
# ALIAS          object
# SIZE_SET        int64
# INST_SIZE       int64
# PT_ENROLL       int64
# FT_ENROLL       int64
# TOT_ENROLL      int64
# HOUSING         int64
# DORM_CAP        int64
# TOT_EMPLOY      int64
# SHELTER_ID     object
# dtype: object

# %%
df.describe()
# Out:
#                  X            Y          FID        IPEDSID         TYPE  \
# count  7735.000000  7735.000000  7735.000000    7735.000000  7735.000000
# mean    -90.506517    37.425260  3868.000000  281864.075889     2.201034
# std      17.595184     5.800367  2233.046499  131529.530737     0.842711
# min    -170.743175   -14.323171     1.000000  100636.000000    -3.000000
# 25%     -97.362353    33.990664  1934.500000  170270.500000     1.000000
# 50%     -86.663047    38.855847  3868.000000  222886.000000     2.000000
# 75%     -79.225690    41.392206  5801.500000  440314.000000     3.000000
# max     171.378442    71.324702  7735.000000  480569.000000     3.000000
#
#           POPULATION    COUNTYFIPS     LATITUDE    LONGITUDE     NAICS_CODE  \
# count    7735.000000   7735.000000  7735.000000  7735.000000    7735.000000
# mean     3233.846800  29196.812023    37.425260   -90.506517  611360.962379
# std      7826.541161  16713.057137     5.800367    17.595184     131.336865
# min         0.000000   -999.000000   -14.323171  -170.743175  611210.000000
# 25%       140.000000  13121.000000    33.990664   -97.362353  611210.000000
# 50%       514.000000  29147.000000    38.855847   -86.663047  611310.000000
# 75%      2657.500000  42029.000000    41.392206   -79.225690  611511.000000
# max    227548.000000  78030.000000    71.324702   171.378442  611710.000000
#
#        ...       LOCALE      MERGE_ID     SIZE_SET    INST_SIZE     PT_ENROLL  \
# count  ...  7735.000000    7735.00000  7735.000000  7735.000000   7735.000000
# mean   ...    19.491920     424.98927     1.787977     1.577893   1032.233355
# std    ...     9.381378    9463.44996     5.878855     1.077236   3006.886573
# min    ...    -3.000000      -2.00000    -3.000000    -2.000000      0.000000
# 25%    ...    12.000000      -2.00000    -3.000000     1.000000      0.000000
# 50%    ...    21.000000      -2.00000    -2.000000     1.000000     59.000000
# 75%    ...    21.000000      -2.00000     5.000000     2.000000    600.000000
# max    ...    43.000000  443544.00000    18.000000     5.000000  65310.000000
#
#            FT_ENROLL     TOT_ENROLL     HOUSING     DORM_CAP    TOT_EMPLOY
# count    7735.000000    7735.000000  7735.00000   7735.00000   7735.000000
# mean     1727.344796    2759.578151     1.63245    388.18384    474.268649
# std      4790.666270    6695.364257     0.70059   1199.39176   1488.795583
# min         0.000000       0.000000    -2.00000      0.00000      0.000000
# 25%        81.000000     114.000000     1.00000      0.00000     20.000000
# 50%       318.000000     434.000000     2.00000      0.00000     74.000000
# 75%      1415.000000    2232.500000     2.00000    105.00000    383.000000
# max    204920.000000  204920.000000     2.00000  16018.00000  28018.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Data Cleanning

# %% [markdown]
# ### Step 1: Check if there is any missing data

# %% [markdown]
# **Are there any missing values?**

# %%
df.isnull().sum()
# Out:
# X             0
# Y             0
# FID           0
# IPEDSID       0
# NAME          0
# ADDRESS       0
# ADDRESS2      0
# CITY          0
# STATE         0
# ZIP           0
# ZIP4          0
# TELEPHONE     0
# TYPE          0
# STATUS        0
# POPULATION    0
# COUNTY        0
# COUNTYFIPS    0
# COUNTRY       0
# LATITUDE      0
# LONGITUDE     0
# NAICS_CODE    0
# NAICS_DESC    0
# SOURCE        0
# SOURCE_DAT    0
# VAL_METHOD    0
# VAL_DATE      0
# WEBSITE       0
# STFIPS        0
# COFIPS        0
# SECTOR        0
# LEVEL_        0
# HI_OFFER      0
# DEG_GRANT     0
# LOCALE        0
# CLOSE_DATE    0
# MERGE_ID      0
# ALIAS         0
# SIZE_SET      0
# INST_SIZE     0
# PT_ENROLL     0
# FT_ENROLL     0
# TOT_ENROLL    0
# HOUSING       0
# DORM_CAP      0
# TOT_EMPLOY    0
# SHELTER_ID    0
# dtype: int64

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# X             0.0
# Y             0.0
# FID           0.0
# IPEDSID       0.0
# NAME          0.0
# ADDRESS       0.0
# ADDRESS2      0.0
# CITY          0.0
# STATE         0.0
# ZIP           0.0
# ZIP4          0.0
# TELEPHONE     0.0
# TYPE          0.0
# STATUS        0.0
# POPULATION    0.0
# COUNTY        0.0
# COUNTYFIPS    0.0
# COUNTRY       0.0
# LATITUDE      0.0
# LONGITUDE     0.0
# NAICS_CODE    0.0
# NAICS_DESC    0.0
# SOURCE        0.0
# SOURCE_DAT    0.0
# VAL_METHOD    0.0
# VAL_DATE      0.0
# WEBSITE       0.0
# STFIPS        0.0
# COFIPS        0.0
# SECTOR        0.0
# LEVEL_        0.0
# HI_OFFER      0.0
# DEG_GRANT     0.0
# LOCALE        0.0
# CLOSE_DATE    0.0
# MERGE_ID      0.0
# ALIAS         0.0
# SIZE_SET      0.0
# INST_SIZE     0.0
# PT_ENROLL     0.0
# FT_ENROLL     0.0
# TOT_ENROLL    0.0
# HOUSING       0.0
# DORM_CAP      0.0
# TOT_EMPLOY    0.0
# SHELTER_ID    0.0
# dtype: float64

# %% [markdown]
# ### Step 2: Remove the irrelevant observations

# %% [markdown]
# **Drop the unnecessary data column**

# %%
df.drop(['X', 'Y', 'FID', 'ADDRESS2', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'SOURCE','SOURCE_DAT', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'SECTOR', 'LEVEL_','HI_OFFER', 'DEG_GRANT', 'LOCALE', 'CLOSE_DATE', 'MERGE_ID', 'ALIAS', 'SIZE_SET', 'HOUSING', 'DORM_CAP', 'SHELTER_ID'], inplace=True, axis=1)

# %% [markdown]
# ## Describing the Data

# %%
df.shape
# Out:
# (7735, 21)

# %%
df.dtypes
# Out:
# IPEDSID         int64
# NAME           object
# ADDRESS        object
# CITY           object
# STATE          object
# ZIP            object
# POPULATION      int64
# COUNTY         object
# COUNTYFIPS      int64
# COUNTRY        object
# LATITUDE      float64
# LONGITUDE     float64
# NAICS_CODE      int64
# NAICS_DESC     object
# STFIPS          int64
# COFIPS          int64
# INST_SIZE       int64
# PT_ENROLL       int64
# FT_ENROLL       int64
# TOT_ENROLL      int64
# TOT_EMPLOY      int64
# dtype: object

# %%
df.describe()
# Out:
#              IPEDSID     POPULATION    COUNTYFIPS     LATITUDE    LONGITUDE  \
# count    7735.000000    7735.000000   7735.000000  7735.000000  7735.000000
# mean   281864.075889    3233.846800  29196.812023    37.425260   -90.506517
# std    131529.530737    7826.541161  16713.057137     5.800367    17.595184
# min    100636.000000       0.000000   -999.000000   -14.323171  -170.743175
# 25%    170270.500000     140.000000  13121.000000    33.990664   -97.362353
# 50%    222886.000000     514.000000  29147.000000    38.855847   -86.663047
# 75%    440314.000000    2657.500000  42029.000000    41.392206   -79.225690
# max    480569.000000  227548.000000  78030.000000    71.324702   171.378442
#
#           NAICS_CODE       STFIPS       COFIPS    INST_SIZE     PT_ENROLL  \
# count    7735.000000  7735.000000  7735.000000  7735.000000   7735.000000
# mean   611360.962379    29.152165    83.819134     1.577893   1032.233355
# std       131.336865    16.704485   103.618466     1.077236   3006.886573
# min    611210.000000     1.000000  -999.000000    -2.000000      0.000000
# 25%    611210.000000    13.000000    29.000000     1.000000      0.000000
# 50%    611310.000000    29.000000    61.000000     1.000000     59.000000
# 75%    611511.000000    42.000000   107.000000     2.000000    600.000000
# max    611710.000000    78.000000   840.000000     5.000000  65310.000000
#
#            FT_ENROLL     TOT_ENROLL    TOT_EMPLOY
# count    7735.000000    7735.000000   7735.000000
# mean     1727.344796    2759.578151    474.268649
# std      4790.666270    6695.364257   1488.795583
# min         0.000000       0.000000      0.000000
# 25%        81.000000     114.000000     20.000000
# 50%       318.000000     434.000000     74.000000
# 75%      1415.000000    2232.500000    383.000000
# max    204920.000000  204920.000000  28018.000000

# %% [markdown]
# ## Additional Dataset

# %% [markdown]
# ### co-est2021-alldata.csv

# %%
population = pd.read_csv('co-est2021-alldata.csv', encoding= 'unicode_escape')

# %%
population
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3189      50       4         8     56      37  Wyoming  Sweetwater County
# 3190      50       4         8     56      39  Wyoming       Teton County
# 3191      50       4         8     56      41  Wyoming       Uinta County
# 3192      50       4         8     56      43  Wyoming    Washakie County
# 3193      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RESIDUAL2021  \
# 0               5024279          5024803          5039877  ...           242
# 1                 58805            58877            59095  ...             8
# 2                231767           233140           239294  ...           -82
# 3                 25223            25180            24964  ...             1
# 4                 22293            22223            22477  ...            -1
# ...                 ...              ...              ...  ...           ...
# 3189              42272            42158            41614  ...            -4
# 3190              23331            23347            23575  ...             1
# 3191              20450            20441            20635  ...             0
# 3192               7685             7658             7705  ...            -1
# 3193               6838             6809             6745  ...             1
#
#       GQESTIMATESBASE2020  GQESTIMATES2020  GQESTIMATES2021  RBIRTH2021  \
# 0                  114572           114572           114572   11.191613
# 1                     442              442              442   11.002611
# 2                    2177             2177             2177    9.567474
# 3                    2789             2789             2789   10.928526
# 4                    2062             2062             2062   10.111857
# ...                   ...              ...              ...         ...
# 3189                  720              720              720   11.483551
# 3190                  215              215              215    9.377264
# 3191                  187              187              187   11.003993
# 3192                  119              119              119    9.893901
# 3193                  300              300              300    7.673012
#
#       RDEATH2021  RNATURALCHG2021  RINTERNATIONALMIG2021  RDOMESTICMIG2021  \
# 0      12.890226        -1.698613               0.247201          4.398749
# 1      11.545112        -0.542502               0.084766          4.017903
# 2      12.137145        -2.569671               0.266704         28.702422
# 3      15.714742        -4.786216               0.039885         -3.908743
# 4      12.617450        -2.505593               0.089485         13.825503
# ...          ...              ...                    ...               ...
# 3189    9.549730         1.933820               0.429738        -15.255694
# 3190    4.091897         5.285367               0.340991          4.049273
# 3191    8.082579         2.921414               0.146071          6.378420
# 3192   14.971034        -5.077133               0.000000         11.325913
# 3193   13.280212        -5.607201               0.000000         -3.984064
#
#       RNETMIG2021
# 0        4.645950
# 1        4.102668
# 2       28.969126
# 3       -3.868858
# 4       13.914989
# ...           ...
# 3189   -14.825956
# 3190     4.390265
# 3191     6.524491
# 3192    11.325913
# 3193    -3.984064
#
# [3194 rows x 35 columns]

# %%
population.dtypes
# Out:
# SUMLEV                     int64
# REGION                     int64
# DIVISION                   int64
# STATE                      int64
# COUNTY                     int64
# STNAME                    object
# CTYNAME                   object
# ESTIMATESBASE2020          int64
# POPESTIMATE2020            int64
# POPESTIMATE2021            int64
# NPOPCHG2020                int64
# NPOPCHG2021                int64
# BIRTHS2020                 int64
# BIRTHS2021                 int64
# DEATHS2020                 int64
# DEATHS2021                 int64
# NATURALCHG2020             int64
# NATURALCHG2021             int64
# INTERNATIONALMIG2020       int64
# INTERNATIONALMIG2021       int64
# DOMESTICMIG2020            int64
# DOMESTICMIG2021            int64
# NETMIG2020                 int64
# NETMIG2021                 int64
# RESIDUAL2020               int64
# RESIDUAL2021               int64
# GQESTIMATESBASE2020        int64
# GQESTIMATES2020            int64
# GQESTIMATES2021            int64
# RBIRTH2021               float64
# RDEATH2021               float64
# RNATURALCHG2021          float64
# RINTERNATIONALMIG2021    float64
# RDOMESTICMIG2021         float64
# RNETMIG2021              float64
# dtype: object

# %%
population.describe()
# Out:
#             SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3194.000000  3194.000000  3194.000000  3194.000000  3194.000000
# mean     49.840326     2.669067     5.192549    30.250157   101.845335
# std       1.253691     0.807730     1.974832    15.159773   107.576954
# min      40.000000     1.000000     1.000000     1.000000     0.000000
# 25%      50.000000     2.000000     4.000000    18.000000    33.000000
# 50%      50.000000     3.000000     5.000000    29.000000    77.000000
# 75%      50.000000     3.000000     7.000000    45.000000   133.000000
# max      50.000000     4.000000     9.000000    56.000000   840.000000
#
#        ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021   NPOPCHG2020  \
# count       3.194000e+03     3.194000e+03     3.194000e+03   3194.000000
# mean        2.075449e+05     2.075774e+05     2.078233e+05     32.435191
# std         1.269954e+06     1.269952e+06     1.269011e+06   2217.319165
# min         6.400000e+01     6.700000e+01     5.700000e+01 -46316.000000
# 25%         1.097425e+04     1.092850e+04     1.094275e+04    -52.750000
# 50%         2.657950e+04     2.653750e+04     2.641100e+04    -13.000000
# 75%         7.408775e+04     7.390850e+04     7.400625e+04     20.000000
# max         3.953822e+07     3.949974e+07     3.923784e+07  72148.000000
#
#          NPOPCHG2021  ...  RESIDUAL2021  GQESTIMATESBASE2020  GQESTIMATES2020  \
# count    3194.000000  ...   3194.000000          3194.000000      3194.000000
# mean      245.876644  ...      0.000000          4859.648716      4859.648716
# std     12021.429239  ...    125.328544         28286.520532     28286.520532
# min   -319020.000000  ...  -3645.000000             0.000000         0.000000
# 25%       -75.000000  ...     -2.000000           139.000000       139.000000
# 50%        32.500000  ...      1.000000           553.500000       553.500000
# 75%       312.750000  ...      5.000000          2288.500000      2288.500000
# max    310288.000000  ...   1285.000000        815696.000000    815696.000000
#
#        GQESTIMATES2021   RBIRTH2021   RDEATH2021  RNATURALCHG2021  \
# count      3194.000000  3194.000000  3194.000000      3194.000000
# mean       4859.648716    10.476861    12.679550        -2.202689
# std       28286.520532     2.396415     3.293721         4.349472
# min           0.000000     0.000000     0.000000       -32.258065
# 25%         139.000000     9.108967    10.558537        -4.908418
# 50%         553.500000    10.371332    12.778106        -2.327026
# 75%        2288.500000    11.658382    14.810587         0.249733
# max      815696.000000    29.072202    48.387097        19.022552
#
#        RINTERNATIONALMIG2021  RDOMESTICMIG2021  RNETMIG2021
# count            3194.000000       3194.000000  3194.000000
# mean                0.346609          4.977854     5.324463
# std                 0.700890         14.365999    14.258942
# min                -1.295197       -112.903226  -112.903226
# 25%                 0.000000         -2.475981    -2.169724
# 50%                 0.147322          3.796239     4.193642
# 75%                 0.426908         11.860913    12.157585
# max                17.299737         80.717489    80.717489
#
# [8 rows x 33 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Step 1: Check if there is any missing data

# %% [markdown]
# **Are there any missing values?**

# %%
population.isnull().sum()
# Out:
# SUMLEV                   0
# REGION                   0
# DIVISION                 0
# STATE                    0
# COUNTY                   0
# STNAME                   0
# CTYNAME                  0
# ESTIMATESBASE2020        0
# POPESTIMATE2020          0
# POPESTIMATE2021          0
# NPOPCHG2020              0
# NPOPCHG2021              0
# BIRTHS2020               0
# BIRTHS2021               0
# DEATHS2020               0
# DEATHS2021               0
# NATURALCHG2020           0
# NATURALCHG2021           0
# INTERNATIONALMIG2020     0
# INTERNATIONALMIG2021     0
# DOMESTICMIG2020          0
# DOMESTICMIG2021          0
# NETMIG2020               0
# NETMIG2021               0
# RESIDUAL2020             0
# RESIDUAL2021             0
# GQESTIMATESBASE2020      0
# GQESTIMATES2020          0
# GQESTIMATES2021          0
# RBIRTH2021               0
# RDEATH2021               0
# RNATURALCHG2021          0
# RINTERNATIONALMIG2021    0
# RDOMESTICMIG2021         0
# RNETMIG2021              0
# dtype: int64

# %%
population.isnull().sum() * 100 / len(population)
# Out:
# SUMLEV                   0.0
# REGION                   0.0
# DIVISION                 0.0
# STATE                    0.0
# COUNTY                   0.0
# STNAME                   0.0
# CTYNAME                  0.0
# ESTIMATESBASE2020        0.0
# POPESTIMATE2020          0.0
# POPESTIMATE2021          0.0
# NPOPCHG2020              0.0
# NPOPCHG2021              0.0
# BIRTHS2020               0.0
# BIRTHS2021               0.0
# DEATHS2020               0.0
# DEATHS2021               0.0
# NATURALCHG2020           0.0
# NATURALCHG2021           0.0
# INTERNATIONALMIG2020     0.0
# INTERNATIONALMIG2021     0.0
# DOMESTICMIG2020          0.0
# DOMESTICMIG2021          0.0
# NETMIG2020               0.0
# NETMIG2021               0.0
# RESIDUAL2020             0.0
# RESIDUAL2021             0.0
# GQESTIMATESBASE2020      0.0
# GQESTIMATES2020          0.0
# GQESTIMATES2021          0.0
# RBIRTH2021               0.0
# RDEATH2021               0.0
# RNATURALCHG2021          0.0
# RINTERNATIONALMIG2021    0.0
# RDOMESTICMIG2021         0.0
# RNETMIG2021              0.0
# dtype: float64

# %% [markdown]
# No missing data (NaN)

# %% [markdown]
# ### Step 2: Get desired observations for further analysis

# %% [markdown]
# **Get the necessary data columns**

# %%
population = population[['STATE', 'COUNTY', 'POPESTIMATE2021']]

# %%
population
# Out:
#       STATE  COUNTY  POPESTIMATE2021
# 0         1       0          5039877
# 1         1       1            59095
# 2         1       3           239294
# 3         1       5            24964
# 4         1       7            22477
# ...     ...     ...              ...
# 3189     56      37            41614
# 3190     56      39            23575
# 3191     56      41            20635
# 3192     56      43             7705
# 3193     56      45             6745
#
# [3194 rows x 3 columns]

# %% [markdown]
# ## Describing the Data

# %%
population.shape
# Out:
# (3194, 3)

# %%
population.dtypes
# Out:
# STATE              int64
# COUNTY             int64
# POPESTIMATE2021    int64
# dtype: object

# %%
population.describe()
# Out:
#              STATE       COUNTY  POPESTIMATE2021
# count  3194.000000  3194.000000     3.194000e+03
# mean     30.250157   101.845335     2.078233e+05
# std      15.159773   107.576954     1.269011e+06
# min       1.000000     0.000000     5.700000e+01
# 25%      18.000000    33.000000     1.094275e+04
# 50%      29.000000    77.000000     2.641100e+04
# 75%      45.000000   133.000000     7.400625e+04
# max      56.000000   840.000000     3.923784e+07

# %%
population.nunique()
# Out:
# STATE                51
# COUNTY              326
# POPESTIMATE2021    3142
# dtype: int64

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Normalization

# %% [markdown]
# Data before normalization is performed on the data:

# %%
df[['POPULATION', 'LATITUDE', 'LONGITUDE', 'INST_SIZE', 'PT_ENROLL', 'FT_ENROLL', 'TOT_ENROLL', 'TOT_EMPLOY']]
# Out:
#       POPULATION   LATITUDE   LONGITUDE  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0             70  34.759308  -92.260490          1         24         28
# 1             39  38.713353 -121.289431          1          6         24
# 2             35  34.101481 -118.287070          1          0         24
# 3             43  36.700631 -121.652662          1         18         16
# 4           2386  42.369930  -71.070737          2          0       2243
# ...          ...        ...         ...        ...        ...        ...
# 7730         163  41.347074  -72.042638          1        119         19
# 7731        3470  39.482878  -80.160335          2        772       2415
# 7732           0  33.895708 -118.236350          1          0          0
# 7733         752  34.042875  -84.176526          1        227        441
# 7734         567  40.030759  -83.121729          1        221        263
#
#       TOT_ENROLL  TOT_EMPLOY
# 0             52          18
# 1             30           9
# 2             24          11
# 3             34           9
# 4           2243         143
# ...          ...         ...
# 7730         138          25
# 7731        3187         283
# 7732           0           0
# 7733         668          84
# 7734         484          83
#
# [7735 rows x 8 columns]

# %% [markdown]
# Data after normalization is performed on the data:

# %%
sc = MinMaxScaler(feature_range = (0, 1))
df_min_max_scaled = df.copy()
#fit: get min/max of train data
col_list = [col for col in df.columns.tolist() if df[col].dtype.name != "object"]

df_min_max_scaled[col_list] = sc.fit_transform(df[col_list])
df_min_max_scaled[['POPULATION', 'LATITUDE', 'LONGITUDE', 'INST_SIZE', 'PT_ENROLL', 'FT_ENROLL', 'TOT_ENROLL', 'TOT_EMPLOY']]
# Out:
#       POPULATION  LATITUDE  LONGITUDE  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0       0.000308  0.573073   0.229400   0.428571   0.000367   0.000137
# 1       0.000171  0.619239   0.144550   0.428571   0.000092   0.000117
# 2       0.000154  0.565392   0.153326   0.428571   0.000000   0.000117
# 3       0.000189  0.595739   0.143488   0.428571   0.000276   0.000078
# 4       0.010486  0.661932   0.291336   0.571429   0.000000   0.010946
# ...          ...       ...        ...        ...        ...        ...
# 7730    0.000716  0.649990   0.288495   0.428571   0.001822   0.000093
# 7731    0.015250  0.628224   0.264768   0.571429   0.011821   0.011785
# 7732    0.000000  0.562990   0.153474   0.428571   0.000000   0.000000
# 7733    0.003305  0.564708   0.253029   0.428571   0.003476   0.002152
# 7734    0.002492  0.634621   0.256112   0.428571   0.003384   0.001283
#
#       TOT_ENROLL  TOT_EMPLOY
# 0       0.000254    0.000642
# 1       0.000146    0.000321
# 2       0.000117    0.000393
# 3       0.000166    0.000321
# 4       0.010946    0.005104
# ...          ...         ...
# 7730    0.000673    0.000892
# 7731    0.015552    0.010101
# 7732    0.000000    0.000000
# 7733    0.003260    0.002998
# 7734    0.002362    0.002962
#
# [7735 rows x 8 columns]

# %% [markdown]
# ### Merging

# %% [markdown]
# Merging is the process of combining two or more datasets into a single dataset.
# <br><br>
# In our datasets, outer merging is performed to allow us to unify and better understand the data when analyzing it.

# %%
df_merge = df.copy()

# %%
population.rename(columns={"STATE": "STFIPS", "COUNTY": "COFIPS"}, inplace=True)
population
# Out:
#       STFIPS  COFIPS  POPESTIMATE2021
# 0          1       0          5039877
# 1          1       1            59095
# 2          1       3           239294
# 3          1       5            24964
# 4          1       7            22477
# ...      ...     ...              ...
# 3189      56      37            41614
# 3190      56      39            23575
# 3191      56      41            20635
# 3192      56      43             7705
# 3193      56      45             6745
#
# [3194 rows x 3 columns]

# %%
df_merge = df_merge.merge(population, how='left')
df_merge
# Out:
#       IPEDSID                                           NAME  \
# 0      107840                                Shorter College
# 1      112181                  Citrus Heights Beauty College
# 2      116660       Joe Blasco Makeup Artist Training Center
# 3      125310                       Waynes College of Beauty
# 4      164368             Hult International Business School
# ...       ...                                            ...
# 7730   443483  Connecticut Center for Massage Therapy-Groton
# 7731   443492       Pierpont Community and Technical College
# 7732   443517        Universal College of Beauty Inc-Compton
# 7733   443526                 ITT Technical Institute-Duluth
# 7734   443535               ITT Technical Institute-Hilliard
#
#                               ADDRESS            CITY STATE    ZIP  \
# 0                       604 Locust St   N Little Rock    AR  72114
# 1                      7518 Baird Way  Citris Heights    CA  95610
# 2               1670 Hillhurst Avenue     Los Angeles    CA  90027
# 3              1271 North Main Street         Salinas    CA  93906
# 4                  1 Education Street       Cambridge    MA  02141
# ...                               ...             ...   ...    ...
# 7730               1154 Poquonnock Rd          Groton    CT  06340
# 7731                  1201 Locust Ave        Fairmont    WV  26554
# 7732            718 West Compton Blvd         Compton    CA  90220
# 7733  10700 Abbotts Bridge Rd-Ste 190          Duluth    GA  30097
# 7734      3781 Park Mill Run, Suite 1        Hilliard    OH  43026
#
#       POPULATION       COUNTY  COUNTYFIPS COUNTRY  ...  NAICS_CODE  \
# 0             70      Pulaski        5119      US  ...      611210
# 1             39   Sacramento        6067      US  ...      611511
# 2             35  Los Angeles        6037      US  ...      611511
# 3             43     Monterey        6053      US  ...      611511
# 4           2386    Middlesex       25017      US  ...      611310
# ...          ...          ...         ...     ...  ...         ...
# 7730         163   New London        9011      US  ...      611519
# 7731        3470       Marion       54049      US  ...      611210
# 7732           0  Los Angeles        6037      US  ...      611710
# 7733         752       Fulton       13121      US  ...      611310
# 7734         567     Franklin       39049      US  ...      611210
#
#                                             NAICS_DESC  STFIPS COFIPS  \
# 0                                      Junior Colleges       5    119
# 1                       Cosmetology and Barber Schools       6     67
# 2                       Cosmetology and Barber Schools       6     37
# 3                       Cosmetology and Barber Schools       6     53
# 4     Colleges, Universities, and Professional Schools      25     17
# ...                                                ...     ...    ...
# 7730                 Other Technical and Trade Schools       9     11
# 7731                                   Junior Colleges      54     49
# 7732               Educational Support Services/Closed       6     37
# 7733  Colleges, Universities, and Professional Schools      13    121
# 7734                                   Junior Colleges      39     49
#
#       INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  POPESTIMATE2021
# 0             1         24         28          52          18         397821.0
# 1             1          6         24          30           9        1588921.0
# 2             1          0         24          24          11        9829544.0
# 3             1         18         16          34           9         437325.0
# 4             2          0       2243        2243         143        1614742.0
# ...         ...        ...        ...         ...         ...              ...
# 7730          1        119         19         138          25         268805.0
# 7731          2        772       2415        3187         283          56001.0
# 7732          1          0          0           0           0        9829544.0
# 7733          1        227        441         668          84        1065334.0
# 7734          1        221        263         484          83        1321414.0
#
# [7735 rows x 22 columns]

# %%
df_merge.isnull().sum()
# Out:
# IPEDSID              0
# NAME                 0
# ADDRESS              0
# CITY                 0
# STATE                0
# ZIP                  0
# POPULATION           0
# COUNTY               0
# COUNTYFIPS           0
# COUNTRY              0
# LATITUDE             0
# LONGITUDE            0
# NAICS_CODE           0
# NAICS_DESC           0
# STFIPS               0
# COFIPS               0
# INST_SIZE            0
# PT_ENROLL            0
# FT_ENROLL            0
# TOT_ENROLL           0
# TOT_EMPLOY           0
# POPESTIMATE2021    175
# dtype: int64

# %%
df_merge.dropna(inplace=True)

# %%
df_merge['POPESTIMATE2021'] = (df_merge['POPESTIMATE2021'].to_numpy()[:, None] * 0.072)
df_merge['POPESTIMATE2021'] = df_merge['POPESTIMATE2021'].astype(int)

# %% [markdown]
# ### Binning

# %% [markdown]
# Bining is a process of grouping or categorizing numeric data into discrete bins or discrete baskets, which is one of the ways of dealing with noisy data.
# <br><br>
# In this data, binning is performed on the ‘TOT_ENROLL’ variable, and we bin it into 3 bins, which are ‘Low’, ‘Medium’, and ‘High’ to simplify the analysis.

# %%
df_min_max_scaled['TOT_ENROLL'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# In order to get an idea on how the values are distributed, we use matplotlib library to plot the histogram.

# %%
plt.hist(df_min_max_scaled['TOT_ENROLL'])

# set x/y labels and plot title
plt.xlabel('Total')
plt.ylabel('Number of enrollment')
plt.title('Total bins')
# Out:
# Text(0.5, 1.0, 'Total bins')

# %% [markdown]
# We want 3 bins of equal size, therefore we use Numpy's `linspace(start_value, end_value, numbers_generated)` function.
# <br><br>
# In order to build 3 bins, we need to define 4 dividers or boundaries:

# %%
bins = np.linspace(min(df['TOT_ENROLL']), max(df['TOT_ENROLL']), 4)
bins
# Out:
# array([     0.        ,  68306.66666667, 136613.33333333, 204920.        ])

# %% [markdown]
# So these are the dividers of the 3 bins, if we were to give it the starting value, ending value, and the number of values to be generated at equal intervals.
#
# The bin group names is created as shown below:

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['BINNED_TOT_ENROLL'] = pd.cut(df['TOT_ENROLL'], bins, labels=group_names, include_lowest=True )
df[['TOT_ENROLL','BINNED_TOT_ENROLL']].head()
# Out:
#    TOT_ENROLL BINNED_TOT_ENROLL
# 0          52               Low
# 1          30               Low
# 2          24               Low
# 3          34               Low
# 4        2243               Low

# %%
df['BINNED_TOT_ENROLL'].value_counts()
# Out:
# Low       7730
# Medium       4
# High         1
# Name: BINNED_TOT_ENROLL, dtype: int64

# %%
df['BINNED_TOT_ENROLL'] = df['BINNED_TOT_ENROLL'].astype(str)

# %% [markdown]
# In order to get an idea on how the values are distributed, we use matplotlib library to plot the histogram.

# %%
plt.bar(group_names, df['BINNED_TOT_ENROLL'].value_counts())

# set x/y labels and plot title 
plt.xlabel('Total')
plt.ylabel('Number of enrollment')
plt.title('Total Bins')
# Out:
# Text(0.5, 1.0, 'Total Bins')

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Clustering

# %%
x = df[['LONGITUDE', 'LATITUDE']]
ss = StandardScaler()
X = ss.fit_transform(x)

print(X)
# Out:
# [[-0.09969125 -0.45964748]
#  [-1.74962101  0.22208539]
#  [-1.57897459 -0.57306609]
#  ...
#  [-1.5760918  -0.60854424]
#  [ 0.35978031 -0.58317059]
#  [ 0.41973224  0.44922468]]

# %%
model = KMeans(n_clusters = 3, verbose=0)   #build the model
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans_labels = pd.DataFrame(model.labels_)   # put into a DataFrame. We will use this shortly...
kmeans_labels
# Out:
#       0
# 0     0
# 1     1
# 2     1
# 3     1
# 4     2
# ...  ..
# 7730  2
# 7731  2
# 7732  1
# 7733  0
# 7734  2
#
# [7735 rows x 1 columns]

# %%
def plot_kmeans_scatter(v1, v2):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    scatter = ax.scatter(v1, v2, c=kmeans_labels[0],s=50,cmap='jet',alpha=0.7)
    ax.set_title('K-Means Clustering')
    ax.set_xlabel(v1.name)
    ax.set_ylabel(v2.name)
    plt.colorbar(scatter)
    plt.show()

v1 = df['LONGITUDE']
v2 = df['LATITUDE']
plot_kmeans_scatter(v1, v2)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Descriptive Question

# %% [markdown]
# **“What is the maximum number of part-time enrollment and full-time enrollment of students of colleges and universities in the US?”**

# %%
max_pt = df['PT_ENROLL'].max()
max_ft = df['FT_ENROLL'].max()
print('Max number of part-time enrollment:', max_pt)
print('Max number of full-time enrollment:', max_ft)
# Out:
# Max number of part-time enrollment: 65310
# Max number of full-time enrollment: 204920

# %% [markdown]
# ### Exploratory Question

# %% [markdown]
# **“What is the relationship between the population and the total enrollment of the colleges and universities students in the US?”**

# %% [markdown]
# **Data Visualization**

# %%
corr_list = list(['POPULATION', 'TOT_ENROLL'])
corr = df[corr_list].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds"))
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['POPULATION'],df['TOT_ENROLL'])
plt.plot(np.unique(df['POPULATION']), np.poly1d(np.polyfit(df['POPULATION'], df['TOT_ENROLL'], 1))
         (np.unique(df['POPULATION'])), color='red')
plt.title('Population vs Enrollment')
# Out:
# Text(0.5, 1.0, 'Population vs Enrollment')

# %% [markdown]
# ### Inferential Question

# %% [markdown]
# **“The larger population of the state is linked with a higher total enrollment of college or university. Is this hypothesis also true for the California population?”**

# %%
df1 = df.copy()

# %%
filter = df1['STATE'] == 'CA'
df1 = df1[filter]
df1.head()
# Out:
#     IPEDSID                                               NAME  \
# 1    112181                      Citrus Heights Beauty College
# 2    116660           Joe Blasco Makeup Artist Training Center
# 3    125310                           Waynes College of Beauty
# 9    395195  Colton-Redlands-Yucaipa Regional Occupational ...
# 14   475097           International Culinary Center-California
#
#                      ADDRESS            CITY STATE    ZIP  POPULATION  \
# 1             7518 Baird Way  Citris Heights    CA  95610          39
# 2      1670 Hillhurst Avenue     Los Angeles    CA  90027          35
# 3     1271 North Main Street         Salinas    CA  93906          43
# 9            1214 Indiana Ct        Redlands    CA  92374         231
# 14  700 West Hamilton Avenue        Campbell    CA  95008         123
#
#             COUNTY  COUNTYFIPS COUNTRY  ...  NAICS_CODE  \
# 1       Sacramento        6067      US  ...      611511
# 2      Los Angeles        6037      US  ...      611511
# 3         Monterey        6053      US  ...      611511
# 9   San Bernardino        6071      US  ...      611519
# 14     Santa Clara        6085      US  ...      611519
#
#                            NAICS_DESC  STFIPS COFIPS  INST_SIZE  PT_ENROLL  \
# 1      Cosmetology and Barber Schools       6     67          1          6
# 2      Cosmetology and Barber Schools       6     37          1          0
# 3      Cosmetology and Barber Schools       6     53          1         18
# 9   Other Technical and Trade Schools       6     71          1          0
# 14  Other Technical and Trade Schools       6     85          1         20
#
#     FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  BINNED_TOT_ENROLL
# 1          24          30           9                Low
# 2          24          24          11                Low
# 3          16          34           9                Low
# 9         142         142          89                Low
# 14         54          74          49                Low
#
# [5 rows x 22 columns]

# %%
corr_list = list(['POPULATION', 'TOT_ENROLL'])
corr = df1[corr_list].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds"))
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df1['POPULATION'],df1['TOT_ENROLL'])
plt.plot(np.unique(df1['POPULATION']), np.poly1d(np.polyfit(df1['POPULATION'], df1['TOT_ENROLL'], 1))
         (np.unique(df1['POPULATION'])), color='red')
plt.title('Population vs Enrollment')
# Out:
# Text(0.5, 1.0, 'Population vs Enrollment')

# %% [markdown]
# ### Predictive Question

# %% [markdown]
# **“What is the predicted mean of the total enrolled students in the junior colleges by the end of 2021?”**

# %%
corr = df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds"))
# Out:
# <AxesSubplot:>

# %%
corr_with_enroll = df.corr()["TOT_ENROLL"].sort_values(ascending=False)
plt.figure(figsize=(10,10))
corr_with_enroll.drop("TOT_ENROLL").plot.bar()
plt.show()

# %%
df
# Out:
#       IPEDSID                                           NAME  \
# 0      107840                                Shorter College
# 1      112181                  Citrus Heights Beauty College
# 2      116660       Joe Blasco Makeup Artist Training Center
# 3      125310                       Waynes College of Beauty
# 4      164368             Hult International Business School
# ...       ...                                            ...
# 7730   443483  Connecticut Center for Massage Therapy-Groton
# 7731   443492       Pierpont Community and Technical College
# 7732   443517        Universal College of Beauty Inc-Compton
# 7733   443526                 ITT Technical Institute-Duluth
# 7734   443535               ITT Technical Institute-Hilliard
#
#                               ADDRESS            CITY STATE    ZIP  \
# 0                       604 Locust St   N Little Rock    AR  72114
# 1                      7518 Baird Way  Citris Heights    CA  95610
# 2               1670 Hillhurst Avenue     Los Angeles    CA  90027
# 3              1271 North Main Street         Salinas    CA  93906
# 4                  1 Education Street       Cambridge    MA  02141
# ...                               ...             ...   ...    ...
# 7730               1154 Poquonnock Rd          Groton    CT  06340
# 7731                  1201 Locust Ave        Fairmont    WV  26554
# 7732            718 West Compton Blvd         Compton    CA  90220
# 7733  10700 Abbotts Bridge Rd-Ste 190          Duluth    GA  30097
# 7734      3781 Park Mill Run, Suite 1        Hilliard    OH  43026
#
#       POPULATION       COUNTY  COUNTYFIPS COUNTRY  ...  NAICS_CODE  \
# 0             70      Pulaski        5119      US  ...      611210
# 1             39   Sacramento        6067      US  ...      611511
# 2             35  Los Angeles        6037      US  ...      611511
# 3             43     Monterey        6053      US  ...      611511
# 4           2386    Middlesex       25017      US  ...      611310
# ...          ...          ...         ...     ...  ...         ...
# 7730         163   New London        9011      US  ...      611519
# 7731        3470       Marion       54049      US  ...      611210
# 7732           0  Los Angeles        6037      US  ...      611710
# 7733         752       Fulton       13121      US  ...      611310
# 7734         567     Franklin       39049      US  ...      611210
#
#                                             NAICS_DESC  STFIPS COFIPS  \
# 0                                      Junior Colleges       5    119
# 1                       Cosmetology and Barber Schools       6     67
# 2                       Cosmetology and Barber Schools       6     37
# 3                       Cosmetology and Barber Schools       6     53
# 4     Colleges, Universities, and Professional Schools      25     17
# ...                                                ...     ...    ...
# 7730                 Other Technical and Trade Schools       9     11
# 7731                                   Junior Colleges      54     49
# 7732               Educational Support Services/Closed       6     37
# 7733  Colleges, Universities, and Professional Schools      13    121
# 7734                                   Junior Colleges      39     49
#
#       INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  \
# 0             1         24         28          52          18
# 1             1          6         24          30           9
# 2             1          0         24          24          11
# 3             1         18         16          34           9
# 4             2          0       2243        2243         143
# ...         ...        ...        ...         ...         ...
# 7730          1        119         19         138          25
# 7731          2        772       2415        3187         283
# 7732          1          0          0           0           0
# 7733          1        227        441         668          84
# 7734          1        221        263         484          83
#
#       BINNED_TOT_ENROLL
# 0                   Low
# 1                   Low
# 2                   Low
# 3                   Low
# 4                   Low
# ...                 ...
# 7730                Low
# 7731                Low
# 7732                Low
# 7733                Low
# 7734                Low
#
# [7735 rows x 22 columns]

# %%
df_junior = df_merge.copy()

# %%
filter = df_junior['NAICS_DESC'] == 'Junior Colleges'
df_junior = df_junior[filter]
df_junior
# Out:
#       IPEDSID                                      NAME  \
# 0      107840                           Shorter College
# 16     475352                 Virginia College-Savannah
# 26     475477                    City College-Hollywood
# 37     475583                          Bryan University
# 38     475592                    Virginia College-Tulsa
# ...       ...                                       ...
# 7715   443270         Southeastern College-Jacksonville
# 7723   443377                 Triangle Tech Inc-Sunbury
# 7726   443438        Medvance Institute-Fort Lauderdale
# 7731   443492  Pierpont Community and Technical College
# 7734   443535          ITT Technical Institute-Hilliard
#
#                                     ADDRESS              CITY STATE    ZIP  \
# 0                             604 Locust St     N Little Rock    AR  72114
# 16        14045 Abercorn Street, Suite 1503          Savannah    GA  31419
# 26                         6565 Taft Street         Hollywood    FL  33024
# 37         3215 LeMone Industrial Boulevard          Columbia    MO  65201
# 38                 5124 South Peoria Avenue             Tulsa    OK  74105
# ...                                     ...               ...   ...    ...
# 7715     6700 Southpoint Parkway, Suite 400      Jacksonville    FL  32216
# 7723                   191 Performance Road           Sunbury    PA  17801
# 7726  4850 W. Oakland Park Blvd., Suite 200  Lauderdale Lakes    FL  33313
# 7731                        1201 Locust Ave          Fairmont    WV  26554
# 7734            3781 Park Mill Run, Suite 1          Hilliard    OH  43026
#
#       POPULATION          COUNTY  COUNTYFIPS COUNTRY  ...  NAICS_CODE  \
# 0             70         Pulaski        5119      US  ...      611210
# 16           902         Chatham       13051      US  ...      611210
# 26            82         Broward       12011      US  ...      611210
# 37           154           Boone       29019      US  ...      611210
# 38           231           Tulsa       40143      US  ...      611210
# ...          ...             ...         ...     ...  ...         ...
# 7715         313           Duval       12031      US  ...      611210
# 7723         127  Northumberland       42097      US  ...      611210
# 7726         365         Broward       12011      US  ...      611210
# 7731        3470          Marion       54049      US  ...      611210
# 7734         567        Franklin       39049      US  ...      611210
#
#            NAICS_DESC  STFIPS COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0     Junior Colleges       5    119          1         24         28
# 16    Junior Colleges      13     51          1        177        586
# 26    Junior Colleges      12     11          1         18         47
# 37    Junior Colleges      29     19          1          0        121
# 38    Junior Colleges      40    143          1         17        143
# ...               ...     ...    ...        ...        ...        ...
# 7715  Junior Colleges      12     31          1         45        165
# 7723  Junior Colleges      42     97          1          0        105
# 7726  Junior Colleges      12     11          1          0        331
# 7731  Junior Colleges      54     49          2        772       2415
# 7734  Junior Colleges      39     49          1        221        263
#
#       TOT_ENROLL  TOT_EMPLOY  POPESTIMATE2021
# 0             52          18            28643
# 16           763         139            21335
# 26            65          17           139030
# 37           121          33            13380
# 38           160          71            48445
# ...          ...         ...              ...
# 7715         210         103            71995
# 7723         105          22             6571
# 7726         331          34           139030
# 7731        3187         283             4032
# 7734         484          83            95141
#
# [1998 rows x 22 columns]

# %% [markdown]
# ### Regression

# %% [markdown]
# ### Split train-test dataset

# %%
X = df[['POPULATION']]
Y = df[['TOT_ENROLL']]

# %%
plt.plot(X,Y, linestyle='',marker='o')
plt.title('Population vs Enrollment')
# Out:
# Text(0.5, 1.0, 'Population vs Enrollment')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Create Linear Regression model

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([[0.84543691]])

# %%
lm.intercept_
# Out:
# array([22.70442192])

# %%
lm_y_test = lm.predict(X_test)
lm_y_train = lm.predict(X_train)

print('Train r2 score: ', r2_score(lm_y_train, y_train))
print('Test r2 score: ', r2_score(y_test, lm_y_test)) 
print('Train MAE: ', mean_absolute_error(lm_y_train, y_train))
print('Test MAE: ',mean_absolute_error(y_test, lm_y_test))
print('Train MSE: ', mean_squared_error(lm_y_train, y_train))
print('Test MSE: ',mean_squared_error(y_test, lm_y_test))
# Out:
# Train r2 score:  0.9819861144001455
# Test r2 score:  0.9816923218118879
# Train MAE:  231.5494600903543
# Test MAE:  229.86777539443798
# Train MSE:  808259.8912486824
# Test MSE:  757975.4924688424

# %%
sns.regplot(y_test, lm_y_test, data=df)
# Out:
# <AxesSubplot:xlabel='TOT_ENROLL'>

# %% [markdown]
# ### Create Decision Tree Regression model

# %%
dtr1 = DecisionTreeRegressor(max_depth=7)
dtr1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7)

# %%
dtr_y_test = dtr1.predict(X_test)
dtr_y_train = dtr1.predict(X_train)

print('Train r2 score: ', r2_score(dtr_y_train, y_train))
print('Test r2 score: ', r2_score(y_test, dtr_y_test)) 
print('Train MAE: ', mean_absolute_error(dtr_y_train, y_train))
print('Test MAE: ',mean_absolute_error(y_test, dtr_y_test))
print('Train MSE: ', mean_squared_error(dtr_y_train, y_train))
print('Test MSE: ',mean_squared_error(y_test, dtr_y_test))
# Out:
# Train r2 score:  0.9916790160379184
# Test r2 score:  0.9597524325006341
# Train MAE:  167.7700568302921
# Test MAE:  263.48660348367974
# Train MSE:  376940.8531221265
# Test MSE:  1666331.9882809622

# %%
sns.regplot(y_test, dtr_y_test, data=df)
# Out:
# <AxesSubplot:xlabel='TOT_ENROLL'>

# %%
depth = 30
max_depth = [i for i in range(1,depth+1)] 
dtr_mae = [] 
for i in range(1,depth+1):
    dtr = DecisionTreeRegressor(max_depth=i)
    dtr.fit(X_train, y_train)
    dtr_y_pred = dtr.predict(X_test)
    dtr_mae.append(mean_absolute_error(y_test, dtr_y_pred))
    
plt.plot(max_depth, dtr_mae)
plt.xlabel('max_depth')
plt.ylabel('MAE')
plt.title('max_depth vs MAE')
plt.show()

# %%
df_le = df.copy()

# %%
d = defaultdict(LabelEncoder)
col_list = [col for col in df_le.columns.tolist() if df_le[col].dtype.name == "object"]

df_le[col_list] = df_le[col_list].apply(lambda x: d[x.name].fit_transform(x))
df_le.drop("BINNED_TOT_ENROLL", 1, inplace=True)
df_le
# Out:
#       IPEDSID  NAME  ADDRESS  CITY  STATE   ZIP  POPULATION  COUNTY  \
# 0      107840  5846     5743  1478      2  3459          70     764
# 1      112181  1326     6402   410      5  4638          39     808
# 2      116660  3300     1874  1250      5  4231          35     560
# 3      125310  7324     1083  1941      5  4520          43     640
# 4      164368  2899       28   313     22   151        2386     623
# ...       ...   ...      ...   ...    ...   ...         ...     ...
# 7730   443483  1574      756   890      7   316         163     666
# 7731   443492  5073      908   707     57  1241        3470     588
# 7732   443517  6721     6258   464      5  4255           0     560
# 7733   443526  2947      484   602     12  1489         752     345
# 7734   443535  2964     4305   968     40  2162         567     339
#
#       COUNTYFIPS  COUNTRY  ...   LONGITUDE  NAICS_CODE  NAICS_DESC  STFIPS  \
# 0           5119        7  ...  -92.260490      611210           7       5
# 1           6067        7  ... -121.289431      611511           3       6
# 2           6037        7  ... -118.287070      611511           3       6
# 3           6053        7  ... -121.652662      611511           3       6
# 4          25017        7  ...  -71.070737      611310           1      25
# ...          ...      ...  ...         ...         ...         ...     ...
# 7730        9011        7  ...  -72.042638      611519           8       9
# 7731       54049        7  ...  -80.160335      611210           7      54
# 7732        6037        7  ... -118.236350      611710           4       6
# 7733       13121        7  ...  -84.176526      611310           1      13
# 7734       39049        7  ...  -83.121729      611210           7      39
#
#       COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY
# 0        119          1         24         28          52          18
# 1         67          1          6         24          30           9
# 2         37          1          0         24          24          11
# 3         53          1         18         16          34           9
# 4         17          2          0       2243        2243         143
# ...      ...        ...        ...        ...         ...         ...
# 7730      11          1        119         19         138          25
# 7731      49          2        772       2415        3187         283
# 7732      37          1          0          0           0           0
# 7733     121          1        227        441         668          84
# 7734      49          1        221        263         484          83
#
# [7735 rows x 21 columns]

# %%
X = df_le.drop(columns=['TOT_ENROLL'])
y = df_le['TOT_ENROLL']

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
#create model
model = Sequential()

#get number of columns in training data
n_cols = xTrain.shape[1]
n_cols
# Out:
# 20

# %%
#add model layers
model.add(Dense(100,  input_shape=(n_cols,)))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
#compile model using mse as a measure of model performance
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train model
history = model.fit(xTrain, yTrain, validation_split=0.2, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 155/155 - 0s - loss: 49187752.0000 - val_loss: 76588352.0000 - 396ms/epoch - 3ms/step
# Epoch 2/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 119ms/epoch - 766us/step
# Epoch 3/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 134ms/epoch - 862us/step
# Epoch 4/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 119ms/epoch - 766us/step
# Epoch 5/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 6/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 7/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 118ms/epoch - 759us/step
# Epoch 8/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 119ms/epoch - 766us/step
# Epoch 9/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 117ms/epoch - 753us/step
# Epoch 10/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 121ms/epoch - 779us/step
# Epoch 11/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 126ms/epoch - 811us/step
# Epoch 12/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 115ms/epoch - 740us/step
# Epoch 13/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 137ms/epoch - 882us/step
# Epoch 14/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 132ms/epoch - 849us/step
# Epoch 15/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 16/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 17/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 18/200
# 155/155 - 0s - loss: 47503164.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 19/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 133ms/epoch - 856us/step
# Epoch 20/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 21/200
# 155/155 - 0s - loss: 47503168.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 22/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 120ms/epoch - 772us/step
# Epoch 23/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 140ms/epoch - 901us/step
# Epoch 24/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 125ms/epoch - 804us/step
# Epoch 25/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 122ms/epoch - 785us/step
# Epoch 26/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 27/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 28/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 29/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 30/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 31/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 32/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 124ms/epoch - 798us/step
# Epoch 33/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 131ms/epoch - 843us/step
# Epoch 34/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 115ms/epoch - 740us/step
# Epoch 35/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 36/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 37/200
# 155/155 - 0s - loss: 47503164.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 38/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 111ms/epoch - 714us/step
# Epoch 39/200
# 155/155 - 0s - loss: 47503124.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 40/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 41/200
# 155/155 - 0s - loss: 47503168.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 42/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 125ms/epoch - 804us/step
# Epoch 43/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 129ms/epoch - 830us/step
# Epoch 44/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 45/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 46/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 47/200
# 155/155 - 0s - loss: 47503164.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 48/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 49/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 50/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 51/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 52/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 53/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 128ms/epoch - 824us/step
# Epoch 54/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 55/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 56/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 57/200
# 155/155 - 0s - loss: 47503168.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 58/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 59/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 60/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 61/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 62/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 63/200
# 155/155 - 0s - loss: 47503164.0000 - val_loss: 76588352.0000 - 128ms/epoch - 824us/step
# Epoch 64/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 65/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 66/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 67/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 68/200
# 155/155 - 0s - loss: 47503164.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 69/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 70/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 71/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 72/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 73/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 123ms/epoch - 791us/step
# Epoch 74/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 119ms/epoch - 766us/step
# Epoch 75/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 76/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 77/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 117ms/epoch - 753us/step
# Epoch 78/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 79/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 80/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 109ms/epoch - 701us/step
# Epoch 81/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 111ms/epoch - 714us/step
# Epoch 82/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 109ms/epoch - 701us/step
# Epoch 83/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 118ms/epoch - 759us/step
# Epoch 84/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 120ms/epoch - 772us/step
# Epoch 85/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 86/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 87/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 88/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 89/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 105ms/epoch - 677us/step
# Epoch 90/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 91/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 678us/step
# Epoch 92/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 93/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 94/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 113ms/epoch - 727us/step
# Epoch 95/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 96/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 106ms/epoch - 684us/step
# Epoch 97/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 98/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 99/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 100/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 101/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 102/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 103/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 104/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 105/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 115ms/epoch - 740us/step
# Epoch 106/200
# 155/155 - 0s - loss: 47503164.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 107/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 108/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 109/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 110/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 105ms/epoch - 675us/step
# Epoch 111/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 104ms/epoch - 673us/step
# Epoch 112/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 113/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 104ms/epoch - 670us/step
# Epoch 114/200
# 155/155 - 0s - loss: 47503172.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 115/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 116/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 117/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 118ms/epoch - 760us/step
# Epoch 118/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 679us/step
# Epoch 119/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 120/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 681us/step
# Epoch 121/200
# 155/155 - 0s - loss: 47503132.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 122/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 123/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 124/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 125/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 126/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 127/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 128/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 111ms/epoch - 718us/step
# Epoch 129/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 130/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 107ms/epoch - 688us/step
# Epoch 131/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 132/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 133/200
# 155/155 - 0s - loss: 47503132.0000 - val_loss: 76588352.0000 - 105ms/epoch - 677us/step
# Epoch 134/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 135/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 105ms/epoch - 677us/step
# Epoch 136/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 137/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 674us/step
# Epoch 138/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 109ms/epoch - 701us/step
# Epoch 139/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 122ms/epoch - 790us/step
# Epoch 140/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 141/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 142/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 143/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 144/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 145/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 146/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 106ms/epoch - 685us/step
# Epoch 147/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 148/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 115ms/epoch - 740us/step
# Epoch 149/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 128ms/epoch - 824us/step
# Epoch 150/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 124ms/epoch - 798us/step
# Epoch 151/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 120ms/epoch - 772us/step
# Epoch 152/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 137ms/epoch - 882us/step
# Epoch 153/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 126ms/epoch - 811us/step
# Epoch 154/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 111ms/epoch - 714us/step
# Epoch 155/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 120ms/epoch - 772us/step
# Epoch 156/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 157/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 158/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 127ms/epoch - 817us/step
# Epoch 159/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 144ms/epoch - 927us/step
# Epoch 160/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 109ms/epoch - 701us/step
# Epoch 161/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 111ms/epoch - 714us/step
# Epoch 162/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 108ms/epoch - 695us/step
# Epoch 163/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 109ms/epoch - 701us/step
# Epoch 164/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 133ms/epoch - 855us/step
# Epoch 165/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 166/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 138ms/epoch - 888us/step
# Epoch 167/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 135ms/epoch - 869us/step
# Epoch 168/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 169/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 125ms/epoch - 804us/step
# Epoch 170/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 116ms/epoch - 746us/step
# Epoch 171/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 172/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 106ms/epoch - 682us/step
# Epoch 173/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 140ms/epoch - 903us/step
# Epoch 174/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 175/200
# 155/155 - 0s - loss: 47503168.0000 - val_loss: 76588352.0000 - 130ms/epoch - 836us/step
# Epoch 176/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 120ms/epoch - 772us/step
# Epoch 177/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step
# Epoch 178/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 147ms/epoch - 946us/step
# Epoch 179/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 180/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 113ms/epoch - 728us/step
# Epoch 181/200
# 155/155 - 0s - loss: 47503168.0000 - val_loss: 76588352.0000 - 114ms/epoch - 734us/step
# Epoch 182/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 183/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 184/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 119ms/epoch - 766us/step
# Epoch 185/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 131ms/epoch - 843us/step
# Epoch 186/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 187/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 117ms/epoch - 755us/step
# Epoch 188/200
# 155/155 - 0s - loss: 47503156.0000 - val_loss: 76588352.0000 - 142ms/epoch - 914us/step
# Epoch 189/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 110ms/epoch - 708us/step
# Epoch 190/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 191/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 192/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 103ms/epoch - 663us/step
# Epoch 193/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 103ms/epoch - 663us/step
# Epoch 194/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 195/200
# 155/155 - 0s - loss: 47503152.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 196/200
# 155/155 - 0s - loss: 47503136.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 197/200
# 155/155 - 0s - loss: 47503144.0000 - val_loss: 76588352.0000 - 104ms/epoch - 669us/step
# Epoch 198/200
# 155/155 - 0s - loss: 47503140.0000 - val_loss: 76588352.0000 - 105ms/epoch - 676us/step
# Epoch 199/200
# 155/155 - 0s - loss: 47503148.0000 - val_loss: 76588352.0000 - 111ms/epoch - 714us/step
# Epoch 200/200
# 155/155 - 0s - loss: 47503160.0000 - val_loss: 76588352.0000 - 112ms/epoch - 721us/step

# %%
nn_y_test = model.predict(xTest)
nn_y_train = model.predict(xTrain)

# %%
print('Train r2 score: ', r2_score(yTrain, nn_y_train))
print('Test r2 score: ', r2_score(yTest, nn_y_test)) 
print('Train MAE: ', mean_absolute_error(yTrain, nn_y_train))
print('Test MAE: ',mean_absolute_error(yTest, nn_y_test))
print('Train MSE: ', mean_squared_error(yTrain, nn_y_train))
print('Test MSE: ',mean_squared_error(yTest, nn_y_test))
# Out:
# Train r2 score:  -0.16737308902767123
# Test r2 score:  -0.18106723382770928
# Train MAE:  2764.9767291532
# Test MAE:  2737.983839689722
# Train MSE:  53322070.77246283
# Test MSE:  48898610.13510019

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# ### Data visualization for prediction of regression model

# %%
plt.plot(X_test,lm_y_test, linestyle='',marker='o', label='LR Model')
plt.plot(X_test,dtr_y_test, linestyle='',marker='*', label='DT Model')
plt.plot(X_test,nn_y_test, linestyle='',marker='^', label='NN Model')
plt.plot(X_test,y_test, linestyle='',marker='+', label='y_test')
plt.ticklabel_format(style='plain')
plt.legend()

# %% [markdown]
# ### Model prediction

# %%
real_X = df_junior[['POPESTIMATE2021']]
real_X
# Out:
#       POPESTIMATE2021
# 0               28643
# 16              21335
# 26             139030
# 37              13380
# 38              48445
# ...               ...
# 7715            71995
# 7723             6571
# 7726           139030
# 7731             4032
# 7734            95141
#
# [1998 rows x 1 columns]

# %%
df_nn = df_junior.copy()
df_nn.drop(['POPULATION'], 1, inplace=True)
df_nn.rename(columns ={'POPESTIMATE2021':'POPULATION'}, inplace=True)
df_nn
# Out:
#       IPEDSID                                      NAME  \
# 0      107840                           Shorter College
# 16     475352                 Virginia College-Savannah
# 26     475477                    City College-Hollywood
# 37     475583                          Bryan University
# 38     475592                    Virginia College-Tulsa
# ...       ...                                       ...
# 7715   443270         Southeastern College-Jacksonville
# 7723   443377                 Triangle Tech Inc-Sunbury
# 7726   443438        Medvance Institute-Fort Lauderdale
# 7731   443492  Pierpont Community and Technical College
# 7734   443535          ITT Technical Institute-Hilliard
#
#                                     ADDRESS              CITY STATE    ZIP  \
# 0                             604 Locust St     N Little Rock    AR  72114
# 16        14045 Abercorn Street, Suite 1503          Savannah    GA  31419
# 26                         6565 Taft Street         Hollywood    FL  33024
# 37         3215 LeMone Industrial Boulevard          Columbia    MO  65201
# 38                 5124 South Peoria Avenue             Tulsa    OK  74105
# ...                                     ...               ...   ...    ...
# 7715     6700 Southpoint Parkway, Suite 400      Jacksonville    FL  32216
# 7723                   191 Performance Road           Sunbury    PA  17801
# 7726  4850 W. Oakland Park Blvd., Suite 200  Lauderdale Lakes    FL  33313
# 7731                        1201 Locust Ave          Fairmont    WV  26554
# 7734            3781 Park Mill Run, Suite 1          Hilliard    OH  43026
#
#               COUNTY  COUNTYFIPS COUNTRY   LATITUDE  ...  NAICS_CODE  \
# 0            Pulaski        5119      US  34.759308  ...      611210
# 16           Chatham       13051      US  31.983580  ...      611210
# 26           Broward       12011      US  26.025270  ...      611210
# 37             Boone       29019      US  38.915735  ...      611210
# 38             Tulsa       40143      US  36.088311  ...      611210
# ...              ...         ...     ...        ...  ...         ...
# 7715           Duval       12031      US  30.220468  ...      611210
# 7723  Northumberland       42097      US  40.855276  ...      611210
# 7726         Broward       12011      US  26.162566  ...      611210
# 7731          Marion       54049      US  39.482878  ...      611210
# 7734        Franklin       39049      US  40.030759  ...      611210
#
#            NAICS_DESC STFIPS  COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0     Junior Colleges      5     119          1         24         28
# 16    Junior Colleges     13      51          1        177        586
# 26    Junior Colleges     12      11          1         18         47
# 37    Junior Colleges     29      19          1          0        121
# 38    Junior Colleges     40     143          1         17        143
# ...               ...    ...     ...        ...        ...        ...
# 7715  Junior Colleges     12      31          1         45        165
# 7723  Junior Colleges     42      97          1          0        105
# 7726  Junior Colleges     12      11          1          0        331
# 7731  Junior Colleges     54      49          2        772       2415
# 7734  Junior Colleges     39      49          1        221        263
#
#       TOT_ENROLL  TOT_EMPLOY  POPULATION
# 0             52          18       28643
# 16           763         139       21335
# 26            65          17      139030
# 37           121          33       13380
# 38           160          71       48445
# ...          ...         ...         ...
# 7715         210         103       71995
# 7723         105          22        6571
# 7726         331          34      139030
# 7731        3187         283        4032
# 7734         484          83       95141
#
# [1998 rows x 21 columns]

# %%
col_list = [col for col in df_nn.columns.tolist() if df_nn[col].dtype.name == "object"]

df_nn[col_list] = df_nn[col_list].apply(lambda x: d[x.name].fit_transform(x))
nn_real_X = df_nn.drop('TOT_ENROLL', 1)

# %%
lm_y_pred = lm.predict(real_X)
drt_y_pred = dtr1.predict(real_X)
nn_y_pred = model.predict(nn_real_X)
lm_y_pred = pd.DataFrame(lm_y_pred, columns=['LR'])
drt_y_pred = pd.DataFrame(drt_y_pred, columns=['DT'])
nn_y_pred = pd.DataFrame(nn_y_pred, columns=['NN'])

# %%
lm_y_pred = lm_y_pred.astype(int)
drt_y_pred = drt_y_pred.astype(int)
nn_y_pred = nn_y_pred.astype(int)

# %%
df_new = pd.concat([df_junior.reset_index(drop=True), lm_y_pred, drt_y_pred, nn_y_pred], axis=1) 

df_new
# Out:
#       IPEDSID                                      NAME  \
# 0      107840                           Shorter College
# 1      475352                 Virginia College-Savannah
# 2      475477                    City College-Hollywood
# 3      475583                          Bryan University
# 4      475592                    Virginia College-Tulsa
# ...       ...                                       ...
# 1993   443270         Southeastern College-Jacksonville
# 1994   443377                 Triangle Tech Inc-Sunbury
# 1995   443438        Medvance Institute-Fort Lauderdale
# 1996   443492  Pierpont Community and Technical College
# 1997   443535          ITT Technical Institute-Hilliard
#
#                                     ADDRESS              CITY STATE    ZIP  \
# 0                             604 Locust St     N Little Rock    AR  72114
# 1         14045 Abercorn Street, Suite 1503          Savannah    GA  31419
# 2                          6565 Taft Street         Hollywood    FL  33024
# 3          3215 LeMone Industrial Boulevard          Columbia    MO  65201
# 4                  5124 South Peoria Avenue             Tulsa    OK  74105
# ...                                     ...               ...   ...    ...
# 1993     6700 Southpoint Parkway, Suite 400      Jacksonville    FL  32216
# 1994                   191 Performance Road           Sunbury    PA  17801
# 1995  4850 W. Oakland Park Blvd., Suite 200  Lauderdale Lakes    FL  33313
# 1996                        1201 Locust Ave          Fairmont    WV  26554
# 1997            3781 Park Mill Run, Suite 1          Hilliard    OH  43026
#
#       POPULATION          COUNTY  COUNTYFIPS COUNTRY  ...  COFIPS  INST_SIZE  \
# 0             70         Pulaski        5119      US  ...     119          1
# 1            902         Chatham       13051      US  ...      51          1
# 2             82         Broward       12011      US  ...      11          1
# 3            154           Boone       29019      US  ...      19          1
# 4            231           Tulsa       40143      US  ...     143          1
# ...          ...             ...         ...     ...  ...     ...        ...
# 1993         313           Duval       12031      US  ...      31          1
# 1994         127  Northumberland       42097      US  ...      97          1
# 1995         365         Broward       12011      US  ...      11          1
# 1996        3470          Marion       54049      US  ...      49          2
# 1997         567        Franklin       39049      US  ...      49          1
#
#       PT_ENROLL FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  POPESTIMATE2021      LR  \
# 0            24        28          52          18            28643   24238
# 1           177       586         763         139            21335   18060
# 2            18        47          65          17           139030  117563
# 3             0       121         121          33            13380   11334
# 4            17       143         160          71            48445   40979
# ...         ...       ...         ...         ...              ...     ...
# 1993         45       165         210         103            71995   60889
# 1994          0       105         105          22             6571    5578
# 1995          0       331         331          34           139030  117563
# 1996        772      2415        3187         283             4032    3431
# 1997        221       263         484          83            95141   80458
#
#           DT     NN
# 0      26222  60374
# 1      19147  48819
# 2     102887  75086
# 3      11460  44604
# 4      42109  49286
# ...      ...    ...
# 1993   64514  61739
# 1994    5690  43625
# 1995  102887  77550
# 1996    3568  40906
# 1997   56387  62560
#
# [1998 rows x 25 columns]

# %% [markdown]
# ### Data visualization

# %%
plt.plot(df_new['POPESTIMATE2021'],df_new['LR'], linestyle='',marker='o', label='LR Model')
plt.plot(df_new['POPESTIMATE2021'],df_new['DT'], linestyle='',marker='+', label='DT Model')
plt.plot(df_new['POPESTIMATE2021'],df_new['NN'], linestyle='',marker='*', label='NN Model')
plt.xlabel('Population')
plt.ylabel('Enrollment')
plt.title('Predicted Enrollment in 2021')
plt.ticklabel_format(style='plain')
plt.legend()

# %%
print('LR mean: ', df_new['LR'].mean())
print('DT mean: ', df_new['DT'].mean())
print('NN mean: ', df_new['NN'].mean())
# Out:
# LR mean:  64604.514014014014
# DT mean:  50456.331831831834
# NN mean:  63176.321321321324

# %% [markdown]
# ### Causal Question

# %% [markdown]
# **“Will an increase in the size of institutions increase the total enrollment of students of colleges and universities in the US?”**

# %%
df2 = df.copy()
filter = df2['INST_SIZE'] > 0
df2 = df2[filter]
df2.head()
# Out:
#    IPEDSID                                      NAME                 ADDRESS  \
# 0   107840                           Shorter College           604 Locust St
# 1   112181             Citrus Heights Beauty College          7518 Baird Way
# 2   116660  Joe Blasco Makeup Artist Training Center   1670 Hillhurst Avenue
# 3   125310                  Waynes College of Beauty  1271 North Main Street
# 4   164368        Hult International Business School      1 Education Street
#
#              CITY STATE    ZIP  POPULATION       COUNTY  COUNTYFIPS COUNTRY  \
# 0   N Little Rock    AR  72114          70      Pulaski        5119      US
# 1  Citris Heights    CA  95610          39   Sacramento        6067      US
# 2     Los Angeles    CA  90027          35  Los Angeles        6037      US
# 3         Salinas    CA  93906          43     Monterey        6053      US
# 4       Cambridge    MA  02141        2386    Middlesex       25017      US
#
#    ...  NAICS_CODE                                        NAICS_DESC  STFIPS  \
# 0  ...      611210                                   Junior Colleges       5
# 1  ...      611511                    Cosmetology and Barber Schools       6
# 2  ...      611511                    Cosmetology and Barber Schools       6
# 3  ...      611511                    Cosmetology and Barber Schools       6
# 4  ...      611310  Colleges, Universities, and Professional Schools      25
#
#   COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  \
# 0    119          1         24         28          52          18
# 1     67          1          6         24          30           9
# 2     37          1          0         24          24          11
# 3     53          1         18         16          34           9
# 4     17          2          0       2243        2243         143
#
#    BINNED_TOT_ENROLL
# 0                Low
# 1                Low
# 2                Low
# 3                Low
# 4                Low
#
# [5 rows x 22 columns]

# %%
corr_list = list(['INST_SIZE', 'TOT_ENROLL'])
corr = df2[corr_list].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds"))
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df2['INST_SIZE'],df2['TOT_ENROLL'])
plt.plot(np.unique(df2['INST_SIZE']), np.poly1d(np.polyfit(df2['INST_SIZE'], df2['TOT_ENROLL'], 1))
         (np.unique(df2['INST_SIZE'])), color='red')
plt.title('Institution size vs Enrollment')
# Out:
# Text(0.5, 1.0, 'Institution size vs Enrollment')
