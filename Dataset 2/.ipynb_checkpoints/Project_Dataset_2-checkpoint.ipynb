# %% [markdown]
# # COLLEGE AND UNIVERSITIES

# %% [markdown]
# ## Load Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.preprocessing import StandardScaler  # For scaling dataset
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation 

from sklearn.model_selection import train_test_split

from sklearn import preprocessing 
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy
from sklearn.feature_selection import RFECV

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping

from tensorflow.keras.utils import to_categorical
from iteration_utilities import deepflatten

import warnings
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve

from sklearn.ensemble import RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report
from sklearn.datasets import make_classification

from imblearn.over_sampling import SMOTE
from sklearn.utils import resample

# %% [markdown]
# ## Data collection

# %% [markdown]
# ### Colleges_and_Universities.csv

# %%
df = pd.read_csv('Colleges_and_Universities.csv')

df.head()
# Out:
#             X          Y   FID  IPEDSID  \
# 0  -92.260490  34.759308  7001   107840
# 1 -121.289431  38.713353  7002   112181
# 2 -118.287070  34.101481  7003   116660
# 3 -121.652662  36.700631  7004   125310
# 4  -71.070737  42.369930  7005   164368
#
#                                        NAME                 ADDRESS  \
# 0                           Shorter College           604 Locust St
# 1             Citrus Heights Beauty College          7518 Baird Way
# 2  Joe Blasco Makeup Artist Training Center   1670 Hillhurst Avenue
# 3                  Waynes College of Beauty  1271 North Main Street
# 4        Hult International Business School      1 Education Street
#
#         ADDRESS2            CITY STATE    ZIP  ...          ALIAS SIZE_SET  \
# 0  NOT AVAILABLE   N Little Rock    AR  72114  ...  NOT AVAILABLE       -3
# 1  NOT AVAILABLE  Citris Heights    CA  95610  ...  NOT AVAILABLE       -3
# 2  NOT AVAILABLE     Los Angeles    CA  90027  ...  NOT AVAILABLE       -3
# 3  NOT AVAILABLE         Salinas    CA  93906  ...  NOT AVAILABLE       -3
# 4  NOT AVAILABLE       Cambridge    MA  02141  ...  NOT AVAILABLE       -3
#
#    INST_SIZE PT_ENROLL  FT_ENROLL TOT_ENROLL  HOUSING DORM_CAP  TOT_EMPLOY  \
# 0          1        24         28         52        2        0          18
# 1          1         6         24         30        2        0           9
# 2          1         0         24         24        2        0          11
# 3          1        18         16         34        2        0           9
# 4          2         0       2243       2243        2        0         143
#
#       SHELTER_ID
# 0  NOT AVAILABLE
# 1  NOT AVAILABLE
# 2  NOT AVAILABLE
# 3  NOT AVAILABLE
# 4  NOT AVAILABLE
#
# [5 rows x 46 columns]

# %%
df.shape
# Out:
# (7735, 46)

# %%
df.dtypes
# Out:
# X             float64
# Y             float64
# FID             int64
# IPEDSID         int64
# NAME           object
# ADDRESS        object
# ADDRESS2       object
# CITY           object
# STATE          object
# ZIP            object
# ZIP4           object
# TELEPHONE      object
# TYPE            int64
# STATUS         object
# POPULATION      int64
# COUNTY         object
# COUNTYFIPS      int64
# COUNTRY        object
# LATITUDE      float64
# LONGITUDE     float64
# NAICS_CODE      int64
# NAICS_DESC     object
# SOURCE         object
# SOURCE_DAT     object
# VAL_METHOD     object
# VAL_DATE       object
# WEBSITE        object
# STFIPS          int64
# COFIPS          int64
# SECTOR          int64
# LEVEL_          int64
# HI_OFFER        int64
# DEG_GRANT       int64
# LOCALE          int64
# CLOSE_DATE     object
# MERGE_ID        int64
# ALIAS          object
# SIZE_SET        int64
# INST_SIZE       int64
# PT_ENROLL       int64
# FT_ENROLL       int64
# TOT_ENROLL      int64
# HOUSING         int64
# DORM_CAP        int64
# TOT_EMPLOY      int64
# SHELTER_ID     object
# dtype: object

# %%
df.describe()
# Out:
#                  X            Y          FID        IPEDSID         TYPE  \
# count  7735.000000  7735.000000  7735.000000    7735.000000  7735.000000
# mean    -90.506517    37.425260  3868.000000  281864.075889     2.201034
# std      17.595184     5.800367  2233.046499  131529.530737     0.842711
# min    -170.743175   -14.323171     1.000000  100636.000000    -3.000000
# 25%     -97.362353    33.990664  1934.500000  170270.500000     1.000000
# 50%     -86.663047    38.855847  3868.000000  222886.000000     2.000000
# 75%     -79.225690    41.392206  5801.500000  440314.000000     3.000000
# max     171.378442    71.324702  7735.000000  480569.000000     3.000000
#
#           POPULATION    COUNTYFIPS     LATITUDE    LONGITUDE     NAICS_CODE  \
# count    7735.000000   7735.000000  7735.000000  7735.000000    7735.000000
# mean     3233.846800  29196.812023    37.425260   -90.506517  611360.962379
# std      7826.541161  16713.057137     5.800367    17.595184     131.336865
# min         0.000000   -999.000000   -14.323171  -170.743175  611210.000000
# 25%       140.000000  13121.000000    33.990664   -97.362353  611210.000000
# 50%       514.000000  29147.000000    38.855847   -86.663047  611310.000000
# 75%      2657.500000  42029.000000    41.392206   -79.225690  611511.000000
# max    227548.000000  78030.000000    71.324702   171.378442  611710.000000
#
#        ...       LOCALE      MERGE_ID     SIZE_SET    INST_SIZE     PT_ENROLL  \
# count  ...  7735.000000    7735.00000  7735.000000  7735.000000   7735.000000
# mean   ...    19.491920     424.98927     1.787977     1.577893   1032.233355
# std    ...     9.381378    9463.44996     5.878855     1.077236   3006.886573
# min    ...    -3.000000      -2.00000    -3.000000    -2.000000      0.000000
# 25%    ...    12.000000      -2.00000    -3.000000     1.000000      0.000000
# 50%    ...    21.000000      -2.00000    -2.000000     1.000000     59.000000
# 75%    ...    21.000000      -2.00000     5.000000     2.000000    600.000000
# max    ...    43.000000  443544.00000    18.000000     5.000000  65310.000000
#
#            FT_ENROLL     TOT_ENROLL     HOUSING     DORM_CAP    TOT_EMPLOY
# count    7735.000000    7735.000000  7735.00000   7735.00000   7735.000000
# mean     1727.344796    2759.578151     1.63245    388.18384    474.268649
# std      4790.666270    6695.364257     0.70059   1199.39176   1488.795583
# min         0.000000       0.000000    -2.00000      0.00000      0.000000
# 25%        81.000000     114.000000     1.00000      0.00000     20.000000
# 50%       318.000000     434.000000     2.00000      0.00000     74.000000
# 75%      1415.000000    2232.500000     2.00000    105.00000    383.000000
# max    204920.000000  204920.000000     2.00000  16018.00000  28018.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ## Data Cleanning

# %% [markdown]
# ### Step 1: Check if there is any missing data

# %% [markdown]
# **Are there any missing values?**

# %%
df.isnull().sum()
# Out:
# X             0
# Y             0
# FID           0
# IPEDSID       0
# NAME          0
# ADDRESS       0
# ADDRESS2      0
# CITY          0
# STATE         0
# ZIP           0
# ZIP4          0
# TELEPHONE     0
# TYPE          0
# STATUS        0
# POPULATION    0
# COUNTY        0
# COUNTYFIPS    0
# COUNTRY       0
# LATITUDE      0
# LONGITUDE     0
# NAICS_CODE    0
# NAICS_DESC    0
# SOURCE        0
# SOURCE_DAT    0
# VAL_METHOD    0
# VAL_DATE      0
# WEBSITE       0
# STFIPS        0
# COFIPS        0
# SECTOR        0
# LEVEL_        0
# HI_OFFER      0
# DEG_GRANT     0
# LOCALE        0
# CLOSE_DATE    0
# MERGE_ID      0
# ALIAS         0
# SIZE_SET      0
# INST_SIZE     0
# PT_ENROLL     0
# FT_ENROLL     0
# TOT_ENROLL    0
# HOUSING       0
# DORM_CAP      0
# TOT_EMPLOY    0
# SHELTER_ID    0
# dtype: int64

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# X             0.0
# Y             0.0
# FID           0.0
# IPEDSID       0.0
# NAME          0.0
# ADDRESS       0.0
# ADDRESS2      0.0
# CITY          0.0
# STATE         0.0
# ZIP           0.0
# ZIP4          0.0
# TELEPHONE     0.0
# TYPE          0.0
# STATUS        0.0
# POPULATION    0.0
# COUNTY        0.0
# COUNTYFIPS    0.0
# COUNTRY       0.0
# LATITUDE      0.0
# LONGITUDE     0.0
# NAICS_CODE    0.0
# NAICS_DESC    0.0
# SOURCE        0.0
# SOURCE_DAT    0.0
# VAL_METHOD    0.0
# VAL_DATE      0.0
# WEBSITE       0.0
# STFIPS        0.0
# COFIPS        0.0
# SECTOR        0.0
# LEVEL_        0.0
# HI_OFFER      0.0
# DEG_GRANT     0.0
# LOCALE        0.0
# CLOSE_DATE    0.0
# MERGE_ID      0.0
# ALIAS         0.0
# SIZE_SET      0.0
# INST_SIZE     0.0
# PT_ENROLL     0.0
# FT_ENROLL     0.0
# TOT_ENROLL    0.0
# HOUSING       0.0
# DORM_CAP      0.0
# TOT_EMPLOY    0.0
# SHELTER_ID    0.0
# dtype: float64

# %% [markdown]
# ### Step 2: Remove the irrelevant observations

# %% [markdown]
# **Drop the unnecessary data column**

# %%
df.drop(['X', 'Y', 'FID', 'ADDRESS2', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'SOURCE','SOURCE_DAT', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'SECTOR', 'LEVEL_','HI_OFFER', 'DEG_GRANT', 'LOCALE', 'CLOSE_DATE', 'MERGE_ID', 'ALIAS', 'SIZE_SET', 'HOUSING', 'DORM_CAP', 'SHELTER_ID'], inplace=True, axis=1)

# %% [markdown]
# ## Describing the Data

# %%
df.shape
# Out:
# (7735, 21)

# %%
df.dtypes
# Out:
# IPEDSID         int64
# NAME           object
# ADDRESS        object
# CITY           object
# STATE          object
# ZIP            object
# POPULATION      int64
# COUNTY         object
# COUNTYFIPS      int64
# COUNTRY        object
# LATITUDE      float64
# LONGITUDE     float64
# NAICS_CODE      int64
# NAICS_DESC     object
# STFIPS          int64
# COFIPS          int64
# INST_SIZE       int64
# PT_ENROLL       int64
# FT_ENROLL       int64
# TOT_ENROLL      int64
# TOT_EMPLOY      int64
# dtype: object

# %%
df.describe()
# Out:
#              IPEDSID     POPULATION    COUNTYFIPS     LATITUDE    LONGITUDE  \
# count    7735.000000    7735.000000   7735.000000  7735.000000  7735.000000
# mean   281864.075889    3233.846800  29196.812023    37.425260   -90.506517
# std    131529.530737    7826.541161  16713.057137     5.800367    17.595184
# min    100636.000000       0.000000   -999.000000   -14.323171  -170.743175
# 25%    170270.500000     140.000000  13121.000000    33.990664   -97.362353
# 50%    222886.000000     514.000000  29147.000000    38.855847   -86.663047
# 75%    440314.000000    2657.500000  42029.000000    41.392206   -79.225690
# max    480569.000000  227548.000000  78030.000000    71.324702   171.378442
#
#           NAICS_CODE       STFIPS       COFIPS    INST_SIZE     PT_ENROLL  \
# count    7735.000000  7735.000000  7735.000000  7735.000000   7735.000000
# mean   611360.962379    29.152165    83.819134     1.577893   1032.233355
# std       131.336865    16.704485   103.618466     1.077236   3006.886573
# min    611210.000000     1.000000  -999.000000    -2.000000      0.000000
# 25%    611210.000000    13.000000    29.000000     1.000000      0.000000
# 50%    611310.000000    29.000000    61.000000     1.000000     59.000000
# 75%    611511.000000    42.000000   107.000000     2.000000    600.000000
# max    611710.000000    78.000000   840.000000     5.000000  65310.000000
#
#            FT_ENROLL     TOT_ENROLL    TOT_EMPLOY
# count    7735.000000    7735.000000   7735.000000
# mean     1727.344796    2759.578151    474.268649
# std      4790.666270    6695.364257   1488.795583
# min         0.000000       0.000000      0.000000
# 25%        81.000000     114.000000     20.000000
# 50%       318.000000     434.000000     74.000000
# 75%      1415.000000    2232.500000    383.000000
# max    204920.000000  204920.000000  28018.000000

# %% [markdown]
# ## Additional Dataset

# %% [markdown]
# ### co-est2021-alldata.csv

# %%
population = pd.read_csv('co-est2021-alldata.csv', encoding= 'unicode_escape')

# %%
population
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3189      50       4         8     56      37  Wyoming  Sweetwater County
# 3190      50       4         8     56      39  Wyoming       Teton County
# 3191      50       4         8     56      41  Wyoming       Uinta County
# 3192      50       4         8     56      43  Wyoming    Washakie County
# 3193      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RESIDUAL2021  \
# 0               5024279          5024803          5039877  ...           242
# 1                 58805            58877            59095  ...             8
# 2                231767           233140           239294  ...           -82
# 3                 25223            25180            24964  ...             1
# 4                 22293            22223            22477  ...            -1
# ...                 ...              ...              ...  ...           ...
# 3189              42272            42158            41614  ...            -4
# 3190              23331            23347            23575  ...             1
# 3191              20450            20441            20635  ...             0
# 3192               7685             7658             7705  ...            -1
# 3193               6838             6809             6745  ...             1
#
#       GQESTIMATESBASE2020  GQESTIMATES2020  GQESTIMATES2021  RBIRTH2021  \
# 0                  114572           114572           114572   11.191613
# 1                     442              442              442   11.002611
# 2                    2177             2177             2177    9.567474
# 3                    2789             2789             2789   10.928526
# 4                    2062             2062             2062   10.111857
# ...                   ...              ...              ...         ...
# 3189                  720              720              720   11.483551
# 3190                  215              215              215    9.377264
# 3191                  187              187              187   11.003993
# 3192                  119              119              119    9.893901
# 3193                  300              300              300    7.673012
#
#       RDEATH2021  RNATURALCHG2021  RINTERNATIONALMIG2021  RDOMESTICMIG2021  \
# 0      12.890226        -1.698613               0.247201          4.398749
# 1      11.545112        -0.542502               0.084766          4.017903
# 2      12.137145        -2.569671               0.266704         28.702422
# 3      15.714742        -4.786216               0.039885         -3.908743
# 4      12.617450        -2.505593               0.089485         13.825503
# ...          ...              ...                    ...               ...
# 3189    9.549730         1.933820               0.429738        -15.255694
# 3190    4.091897         5.285367               0.340991          4.049273
# 3191    8.082579         2.921414               0.146071          6.378420
# 3192   14.971034        -5.077133               0.000000         11.325913
# 3193   13.280212        -5.607201               0.000000         -3.984064
#
#       RNETMIG2021
# 0        4.645950
# 1        4.102668
# 2       28.969126
# 3       -3.868858
# 4       13.914989
# ...           ...
# 3189   -14.825956
# 3190     4.390265
# 3191     6.524491
# 3192    11.325913
# 3193    -3.984064
#
# [3194 rows x 35 columns]

# %%
population.dtypes
# Out:
# SUMLEV                     int64
# REGION                     int64
# DIVISION                   int64
# STATE                      int64
# COUNTY                     int64
# STNAME                    object
# CTYNAME                   object
# ESTIMATESBASE2020          int64
# POPESTIMATE2020            int64
# POPESTIMATE2021            int64
# NPOPCHG2020                int64
# NPOPCHG2021                int64
# BIRTHS2020                 int64
# BIRTHS2021                 int64
# DEATHS2020                 int64
# DEATHS2021                 int64
# NATURALCHG2020             int64
# NATURALCHG2021             int64
# INTERNATIONALMIG2020       int64
# INTERNATIONALMIG2021       int64
# DOMESTICMIG2020            int64
# DOMESTICMIG2021            int64
# NETMIG2020                 int64
# NETMIG2021                 int64
# RESIDUAL2020               int64
# RESIDUAL2021               int64
# GQESTIMATESBASE2020        int64
# GQESTIMATES2020            int64
# GQESTIMATES2021            int64
# RBIRTH2021               float64
# RDEATH2021               float64
# RNATURALCHG2021          float64
# RINTERNATIONALMIG2021    float64
# RDOMESTICMIG2021         float64
# RNETMIG2021              float64
# dtype: object

# %%
population.describe()
# Out:
#             SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3194.000000  3194.000000  3194.000000  3194.000000  3194.000000
# mean     49.840326     2.669067     5.192549    30.250157   101.845335
# std       1.253691     0.807730     1.974832    15.159773   107.576954
# min      40.000000     1.000000     1.000000     1.000000     0.000000
# 25%      50.000000     2.000000     4.000000    18.000000    33.000000
# 50%      50.000000     3.000000     5.000000    29.000000    77.000000
# 75%      50.000000     3.000000     7.000000    45.000000   133.000000
# max      50.000000     4.000000     9.000000    56.000000   840.000000
#
# RINTERNATIONALMIG2021    0
# RDOMESTICMIG2021         0
# RNETMIG2021              0
# dtype: int64

# %%
population.isnull().sum() * 100 / len(population)
# Out:
# SUMLEV                   0.0
# REGION                   0.0
# DIVISION                 0.0
# STATE                    0.0
# COUNTY                   0.0
# STNAME                   0.0
# CTYNAME                  0.0
# ESTIMATESBASE2020        0.0
# POPESTIMATE2020          0.0
# POPESTIMATE2021          0.0
# NPOPCHG2020              0.0
# NPOPCHG2021              0.0
# BIRTHS2020               0.0
# BIRTHS2021               0.0
# DEATHS2020               0.0
# DEATHS2021               0.0
# NATURALCHG2020           0.0
# NATURALCHG2021           0.0
# INTERNATIONALMIG2020     0.0
# INTERNATIONALMIG2021     0.0
# DOMESTICMIG2020          0.0
# DOMESTICMIG2021          0.0
# NETMIG2020               0.0
# NETMIG2021               0.0
# RESIDUAL2020             0.0
# RESIDUAL2021             0.0
# GQESTIMATESBASE2020      0.0
# GQESTIMATES2020          0.0
# GQESTIMATES2021          0.0
# RBIRTH2021               0.0
# RDEATH2021               0.0
# RNATURALCHG2021          0.0
# RINTERNATIONALMIG2021    0.0
# RDOMESTICMIG2021         0.0
# RNETMIG2021              0.0
# dtype: float64

# %% [markdown]
# No missing data (NaN)

# %% [markdown]
# ### Step 2: Get desired observations for further analysis

# %% [markdown]
# **Get the necessary data columns**

# %%
population = population[['STATE', 'COUNTY', 'POPESTIMATE2021']]

# %%
population
# Out:
#       STATE  COUNTY  POPESTIMATE2021
# 0         1       0          5039877
# 1         1       1            59095
# 2         1       3           239294
# 3         1       5            24964
# 4         1       7            22477
# ...     ...     ...              ...
# 3189     56      37            41614
# 3190     56      39            23575
# 3191     56      41            20635
# 3192     56      43             7705
# 3193     56      45             6745
#
# [3194 rows x 3 columns]

# %% [markdown]
# ## Describing the Data

# %%
population.shape
# Out:
# (3194, 3)

# %%
population.dtypes
# Out:
# STATE              int64
# COUNTY             int64
# POPESTIMATE2021    int64
# dtype: object

# %%
population.describe()
# Out:
#              STATE       COUNTY  POPESTIMATE2021
# count  3194.000000  3194.000000     3.194000e+03
# mean     30.250157   101.845335     2.078233e+05
# std      15.159773   107.576954     1.269011e+06
# min       1.000000     0.000000     5.700000e+01
# 25%      18.000000    33.000000     1.094275e+04
# 50%      29.000000    77.000000     2.641100e+04
# 75%      45.000000   133.000000     7.400625e+04
# max      56.000000   840.000000     3.923784e+07

# %%
population.nunique()
# Out:
# STATE                51
# COUNTY              326
# POPESTIMATE2021    3142
# dtype: int64

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Normalization

# %% [markdown]
# Data before normalization is performed on the data:

# %%
df[['POPULATION', 'LATITUDE', 'LONGITUDE', 'INST_SIZE', 'PT_ENROLL', 'FT_ENROLL', 'TOT_ENROLL', 'TOT_EMPLOY']]
# Out:
#       POPULATION   LATITUDE   LONGITUDE  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0             70  34.759308  -92.260490          1         24         28
# 1             39  38.713353 -121.289431          1          6         24
# 2             35  34.101481 -118.287070          1          0         24
# 3             43  36.700631 -121.652662          1         18         16
# 4           2386  42.369930  -71.070737          2          0       2243
# ...          ...        ...         ...        ...        ...        ...
# 7730         163  41.347074  -72.042638          1        119         19
# 7731        3470  39.482878  -80.160335          2        772       2415
# 7732           0  33.895708 -118.236350          1          0          0
# 7733         752  34.042875  -84.176526          1        227        441
# 7734         567  40.030759  -83.121729          1        221        263
#
#       TOT_ENROLL  TOT_EMPLOY
# 0             52          18
# 1             30           9
# 2             24          11
# 3             34           9
# 4           2243         143
# ...          ...         ...
# 7730         138          25
# 7731        3187         283
# 7732           0           0
# 7733         668          84
# 7734         484          83
#
# [7735 rows x 8 columns]

# %% [markdown]
# Data after normalization is performed on the data:

# %%
sc = MinMaxScaler(feature_range = (0, 1))
df_min_max_scaled = df.copy()
#fit: get min/max of train data
col_list = [col for col in df.columns.tolist() if df[col].dtype.name != "object"]

df_min_max_scaled[col_list] = sc.fit_transform(df[col_list])
df_min_max_scaled[['POPULATION', 'LATITUDE', 'LONGITUDE', 'INST_SIZE', 'PT_ENROLL', 'FT_ENROLL', 'TOT_ENROLL', 'TOT_EMPLOY']]
# Out:
#       POPULATION  LATITUDE  LONGITUDE  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0       0.000308  0.573073   0.229400   0.428571   0.000367   0.000137
# 1       0.000171  0.619239   0.144550   0.428571   0.000092   0.000117
# 2       0.000154  0.565392   0.153326   0.428571   0.000000   0.000117
# 3       0.000189  0.595739   0.143488   0.428571   0.000276   0.000078
# 4       0.010486  0.661932   0.291336   0.571429   0.000000   0.010946
# ...          ...       ...        ...        ...        ...        ...
# 7730    0.000716  0.649990   0.288495   0.428571   0.001822   0.000093
# 7731    0.015250  0.628224   0.264768   0.571429   0.011821   0.011785
# 7732    0.000000  0.562990   0.153474   0.428571   0.000000   0.000000
# 7733    0.003305  0.564708   0.253029   0.428571   0.003476   0.002152
# 7734    0.002492  0.634621   0.256112   0.428571   0.003384   0.001283
#
#       TOT_ENROLL  TOT_EMPLOY
# 0       0.000254    0.000642
# 1       0.000146    0.000321
# 2       0.000117    0.000393
# 3       0.000166    0.000321
# 4       0.010946    0.005104
# ...          ...         ...
# 7730    0.000673    0.000892
# 7731    0.015552    0.010101
# 7732    0.000000    0.000000
# 7733    0.003260    0.002998
# 7734    0.002362    0.002962
#
# [7735 rows x 8 columns]

# %% [markdown]
# ### Merging

# %% [markdown]
# Merging is the process of combining two or more datasets into a single dataset.
# <br><br>
# In our datasets, outer merging is performed to allow us to unify and better understand the data when analyzing it.

# %%
df_merge = df.copy()

# %%
population.rename(columns={"STATE": "STFIPS", "COUNTY": "COFIPS"}, inplace=True)
population
# Out:
#       STFIPS  COFIPS  POPESTIMATE2021
# 0          1       0          5039877
# 1          1       1            59095
# 2          1       3           239294
# 3          1       5            24964
# 4          1       7            22477
# ...      ...     ...              ...
# 3189      56      37            41614
# 3190      56      39            23575
# 3191      56      41            20635
# 3192      56      43             7705
# 3193      56      45             6745
#
# [3194 rows x 3 columns]

# %%
df_merge = df_merge.merge(population, how='left')
df_merge
# Out:
#       IPEDSID                                           NAME  \
# 0      107840                                Shorter College
# 1      112181                  Citrus Heights Beauty College
# 2      116660       Joe Blasco Makeup Artist Training Center
# 3      125310                       Waynes College of Beauty
# 4      164368             Hult International Business School
# ...       ...                                            ...
# 7730   443483  Connecticut Center for Massage Therapy-Groton
# 7731   443492       Pierpont Community and Technical College
# 7732   443517        Universal College of Beauty Inc-Compton
# 7733   443526                 ITT Technical Institute-Duluth
# 7734   443535               ITT Technical Institute-Hilliard
#
#                               ADDRESS            CITY STATE    ZIP  \
# 0                       604 Locust St   N Little Rock    AR  72114
# 1                      7518 Baird Way  Citris Heights    CA  95610
# 2               1670 Hillhurst Avenue     Los Angeles    CA  90027
# 3              1271 North Main Street         Salinas    CA  93906
# 4                  1 Education Street       Cambridge    MA  02141
# ...                               ...             ...   ...    ...
# 7730               1154 Poquonnock Rd          Groton    CT  06340
# 7731                  1201 Locust Ave        Fairmont    WV  26554
# 7732            718 West Compton Blvd         Compton    CA  90220
# 7733  10700 Abbotts Bridge Rd-Ste 190          Duluth    GA  30097
# 7734      3781 Park Mill Run, Suite 1        Hilliard    OH  43026
#
#       POPULATION       COUNTY  COUNTYFIPS COUNTRY  ...  NAICS_CODE  \
# 0             70      Pulaski        5119      US  ...      611210
# 1             39   Sacramento        6067      US  ...      611511
# 2             35  Los Angeles        6037      US  ...      611511
# 3             43     Monterey        6053      US  ...      611511
# 4           2386    Middlesex       25017      US  ...      611310
# ...          ...          ...         ...     ...  ...         ...
# 7730         163   New London        9011      US  ...      611519
# 7731        3470       Marion       54049      US  ...      611210
# 7732           0  Los Angeles        6037      US  ...      611710
# 7733         752       Fulton       13121      US  ...      611310
# 7734         567     Franklin       39049      US  ...      611210
#
#                                             NAICS_DESC  STFIPS COFIPS  \
# 0                                      Junior Colleges       5    119
# 1                       Cosmetology and Barber Schools       6     67
# 2                       Cosmetology and Barber Schools       6     37
# 3                       Cosmetology and Barber Schools       6     53
# 4     Colleges, Universities, and Professional Schools      25     17
# ...                                                ...     ...    ...
# 7730                 Other Technical and Trade Schools       9     11
# 7731                                   Junior Colleges      54     49
# 7732               Educational Support Services/Closed       6     37
# 7733  Colleges, Universities, and Professional Schools      13    121
# 7734                                   Junior Colleges      39     49
#
#       INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  POPESTIMATE2021
# 0             1         24         28          52          18         397821.0
# 1             1          6         24          30           9        1588921.0
# 2             1          0         24          24          11        9829544.0
# 3             1         18         16          34           9         437325.0
# 4             2          0       2243        2243         143        1614742.0
# ...         ...        ...        ...         ...         ...              ...
# 7730          1        119         19         138          25         268805.0
# 7731          2        772       2415        3187         283          56001.0
# 7732          1          0          0           0           0        9829544.0
# 7733          1        227        441         668          84        1065334.0
# 7734          1        221        263         484          83        1321414.0
#
# [7735 rows x 22 columns]

# %%
df_merge.isnull().sum()
# Out:
# IPEDSID              0
# NAME                 0
# ADDRESS              0
# CITY                 0
# STATE                0
# ZIP                  0
# POPULATION           0
# COUNTY               0
# COUNTYFIPS           0
# COUNTRY              0
# LATITUDE             0
# LONGITUDE            0
# NAICS_CODE           0
# NAICS_DESC           0
# STFIPS               0
# COFIPS               0
# INST_SIZE            0
# PT_ENROLL            0
# FT_ENROLL            0
# TOT_ENROLL           0
# TOT_EMPLOY           0
# POPESTIMATE2021    175
# dtype: int64

# %%
df_merge.dropna(inplace=True)

# %%
df_merge['POPESTIMATE2021'] = (df_merge['POPESTIMATE2021'].to_numpy()[:, None] * 0.072)
df_merge['POPESTIMATE2021'] = df_merge['POPESTIMATE2021'].astype(int)

# %% [markdown]
# ### Binning

# %% [markdown]
# Bining is a process of grouping or categorizing numeric data into discrete bins or discrete baskets, which is one of the ways of dealing with noisy data.
# <br><br>
# In this data, binning is performed on the ‘TOT_ENROLL’ variable, and we bin it into 3 bins, which are ‘Low’, ‘Medium’, and ‘High’ to simplify the analysis.

# %%
df_min_max_scaled['TOT_ENROLL'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# In order to get an idea on how the values are distributed, we use matplotlib library to plot the histogram.

# %%
plt.hist(df_min_max_scaled['TOT_ENROLL'])

# set x/y labels and plot title
plt.xlabel('Total')
plt.ylabel('Number of enrollment')
plt.title('Total bins').figure.savefig('TotalEnroll_Histogram.png')

# %% [markdown]
# We want 3 bins of equal size, therefore we use Numpy's `linspace(start_value, end_value, numbers_generated)` function.
# <br><br>
# In order to build 3 bins, we need to define 4 dividers or boundaries:

# %%
bins = np.linspace(min(df['TOT_ENROLL']), max(df['TOT_ENROLL']), 4)
bins
# Out:
# array([     0.        ,  68306.66666667, 136613.33333333, 204920.        ])

# %% [markdown]
# So these are the dividers of the 3 bins, if we were to give it the starting value, ending value, and the number of values to be generated at equal intervals.
#
# The bin group names is created as shown below:

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['BINNED_TOT_ENROLL'] = pd.cut(df['TOT_ENROLL'], bins, labels=group_names, include_lowest=True )
df[['TOT_ENROLL','BINNED_TOT_ENROLL']].head()
# Out:
#    TOT_ENROLL BINNED_TOT_ENROLL
# 0          52               Low
# 1          30               Low
# 2          24               Low
# 3          34               Low
# 4        2243               Low

# %%
df['BINNED_TOT_ENROLL'].value_counts()
# Out:
# Low       7730
# Medium       4
# High         1
# Name: BINNED_TOT_ENROLL, dtype: int64

# %%
df['BINNED_TOT_ENROLL'] = df['BINNED_TOT_ENROLL'].astype(str)

# %% [markdown]
# In order to get an idea on how the values are distributed, we use matplotlib library to plot the histogram.

# %%
plt.bar(group_names, df['BINNED_TOT_ENROLL'].value_counts())

# set x/y labels and plot title 
plt.xlabel('Total')
plt.ylabel('Number of enrollment')
plt.title('Total Bins').figure.savefig('Binned_Enrollment.png')

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Clustering

# %%
x = df[['LONGITUDE', 'LATITUDE']]
ss = StandardScaler()
X = ss.fit_transform(x)

print(X)
# Out:
# [[-0.09969125 -0.45964748]
#  [-1.74962101  0.22208539]
#  [-1.57897459 -0.57306609]
#  ...
#  [-1.5760918  -0.60854424]
#  [ 0.35978031 -0.58317059]
#  [ 0.41973224  0.44922468]]

# %%
model = KMeans(n_clusters = 3, verbose=0)   #build the model
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans_labels = pd.DataFrame(model.labels_)   # put into a DataFrame. We will use this shortly...
kmeans_labels
# Out:
#       0
# 0     2
# 1     0
# 2     0
# 3     0
# 4     1
# ...  ..
# 7730  1
# 7731  1
# 7732  0
# 7733  2
# 7734  1
#
# [7735 rows x 1 columns]

# %%
def plot_kmeans_scatter(v1, v2):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    scatter = ax.scatter(v1, v2, c=kmeans_labels[0],s=50,cmap='jet',alpha=0.7)
    ax.set_title('K-Means Clustering')
    ax.set_xlabel(v1.name)
    ax.set_ylabel(v2.name)
    plt.colorbar(scatter)
    plt.show()
    ax.figure.savefig('K-Means.png')

v1 = df['LONGITUDE']
v2 = df['LATITUDE']
plot_kmeans_scatter(v1, v2)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Descriptive Question

# %% [markdown]
# **“What is the maximum number of part-time enrollment and full-time enrollment of students of colleges and universities in the US?”**

# %%
max_pt = df['PT_ENROLL'].max()
max_ft = df['FT_ENROLL'].max()
print('Max number of part-time enrollment:', max_pt)
print('Max number of full-time enrollment:', max_ft)
# Out:
# Max number of part-time enrollment: 65310
# Max number of full-time enrollment: 204920

# %% [markdown]
# ### Exploratory Question

# %% [markdown]
# **“What is the relationship between the population and the total enrollment of the colleges and universities students in the US?”**

# %% [markdown]
# **Data Visualization**

# %%
corr_list = list(['POPULATION', 'TOT_ENROLL'])
corr = df[corr_list].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds")).figure.savefig('Heatmap.png')

# %%
plt.scatter(df['POPULATION'],df['TOT_ENROLL'])
plt.plot(np.unique(df['POPULATION']), np.poly1d(np.polyfit(df['POPULATION'], df['TOT_ENROLL'], 1))
         (np.unique(df['POPULATION'])), color='red')
plt.title('Population vs Enrollment').figure.savefig('Population_vs_Enrollment_Regplot_All.png')

# %% [markdown]
# ### Inferential Question

# %% [markdown]
# **“The larger population of the state is linked with a higher total enrollment of college or university. Is this hypothesis also true for the California population?”**

# %%
df1 = df.copy()

# %%
filter = df1['STATE'] == 'CA'
df1 = df1[filter]
df1.head()
# Out:
#     IPEDSID                                               NAME  \
# 1    112181                      Citrus Heights Beauty College
# 2    116660           Joe Blasco Makeup Artist Training Center
# 3    125310                           Waynes College of Beauty
# 9    395195  Colton-Redlands-Yucaipa Regional Occupational ...
# 14   475097           International Culinary Center-California
#
#                      ADDRESS            CITY STATE    ZIP  POPULATION  \
# 1             7518 Baird Way  Citris Heights    CA  95610          39
# 2      1670 Hillhurst Avenue     Los Angeles    CA  90027          35
# 3     1271 North Main Street         Salinas    CA  93906          43
# 9            1214 Indiana Ct        Redlands    CA  92374         231
# 14  700 West Hamilton Avenue        Campbell    CA  95008         123
#
#             COUNTY  COUNTYFIPS COUNTRY  ...   LONGITUDE  NAICS_CODE  \
# 1       Sacramento        6067      US  ... -121.289431      611511
# 2      Los Angeles        6037      US  ... -118.287070      611511
# 3         Monterey        6053      US  ... -121.652662      611511
# 9   San Bernardino        6071      US  ... -117.204959      611519
# 14     Santa Clara        6085      US  ... -121.961475      611519
#
#                            NAICS_DESC STFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 1      Cosmetology and Barber Schools      6          1          6         24
# 2      Cosmetology and Barber Schools      6          1          0         24
# 3      Cosmetology and Barber Schools      6          1         18         16
# 9   Other Technical and Trade Schools      6          1          0        142
# 14  Other Technical and Trade Schools      6          1         20         54
#
#     TOT_ENROLL  TOT_EMPLOY  BINNED_TOT_ENROLL
# 1           30           9                Low
# 2           24          11                Low
# 3           34           9                Low
# 9          142          89                Low
# 14          74          49                Low
#
# [5 rows x 21 columns]

# %%
corr_list = list(['POPULATION', 'TOT_ENROLL'])
corr = df1[corr_list].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds")).figure.savefig('Heatmap1.png')

# %%
plt.scatter(df1['POPULATION'],df1['TOT_ENROLL'])
plt.plot(np.unique(df1['POPULATION']), np.poly1d(np.polyfit(df1['POPULATION'], df1['TOT_ENROLL'], 1))
         (np.unique(df1['POPULATION'])), color='red')
plt.title('Population vs Enrollment').figure.savefig('Population_vs_Enrollment_Regplot_CA.png')

# %% [markdown]
# ### Predictive Question

# %% [markdown]
# **“What is the predicted mean of the total enrolled students in the junior colleges by the end of 2021?”**

# %%
corr = df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds")).figure.savefig('Heatmap2.png')

# %%
corr_with_enroll = df.corr()["TOT_ENROLL"].sort_values(ascending=False)
plt.figure(figsize=(10,10))
corr_with_enroll.drop("TOT_ENROLL").plot.bar().figure.savefig('Correlation_Bar.png')
plt.show()

# %%
df
# Out:
#       IPEDSID                                           NAME  \
# 0      107840                                Shorter College
# 1      112181                  Citrus Heights Beauty College
# 2      116660       Joe Blasco Makeup Artist Training Center
# 3      125310                       Waynes College of Beauty
# 4      164368             Hult International Business School
# ...       ...                                            ...
# 7730   443483  Connecticut Center for Massage Therapy-Groton
# 7731   443492       Pierpont Community and Technical College
# 7732   443517        Universal College of Beauty Inc-Compton
# 7733   443526                 ITT Technical Institute-Duluth
# 7734   443535               ITT Technical Institute-Hilliard
#
#                               ADDRESS            CITY STATE    ZIP  \
# 0                       604 Locust St   N Little Rock    AR  72114
# 1                      7518 Baird Way  Citris Heights    CA  95610
# 2               1670 Hillhurst Avenue     Los Angeles    CA  90027
# 3              1271 North Main Street         Salinas    CA  93906
# 4                  1 Education Street       Cambridge    MA  02141
# ...                               ...             ...   ...    ...
# 7730               1154 Poquonnock Rd          Groton    CT  06340
# 7731                  1201 Locust Ave        Fairmont    WV  26554
# 7732            718 West Compton Blvd         Compton    CA  90220
# 7733  10700 Abbotts Bridge Rd-Ste 190          Duluth    GA  30097
# 7734      3781 Park Mill Run, Suite 1        Hilliard    OH  43026
#
#       POPULATION       COUNTY  COUNTYFIPS COUNTRY  ...   LONGITUDE  \
# 0             70      Pulaski        5119      US  ...  -92.260490
# 1             39   Sacramento        6067      US  ... -121.289431
# 2             35  Los Angeles        6037      US  ... -118.287070
# 3             43     Monterey        6053      US  ... -121.652662
# 4           2386    Middlesex       25017      US  ...  -71.070737
# ...          ...          ...         ...     ...  ...         ...
# 7730         163   New London        9011      US  ...  -72.042638
# 7731        3470       Marion       54049      US  ...  -80.160335
# 7732           0  Los Angeles        6037      US  ... -118.236350
# 7733         752       Fulton       13121      US  ...  -84.176526
# 7734         567     Franklin       39049      US  ...  -83.121729
#
#       NAICS_CODE                                        NAICS_DESC STFIPS  \
# 0         611210                                   Junior Colleges      5
# 1         611511                    Cosmetology and Barber Schools      6
# 2         611511                    Cosmetology and Barber Schools      6
# 3         611511                    Cosmetology and Barber Schools      6
# 4         611310  Colleges, Universities, and Professional Schools     25
# ...          ...                                               ...    ...
# 7730      611519                 Other Technical and Trade Schools      9
# 7731      611210                                   Junior Colleges     54
# 7732      611710               Educational Support Services/Closed      6
# 7733      611310  Colleges, Universities, and Professional Schools     13
# 7734      611210                                   Junior Colleges     39
#
#       COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY
# 0        119          1         24         28          52          18
# 1         67          1          6         24          30           9
# 2         37          1          0         24          24          11
# 3         53          1         18         16          34           9
# 4         17          2          0       2243        2243         143
# ...      ...        ...        ...        ...         ...         ...
# 7730      11          1        119         19         138          25
# 7731      49          2        772       2415        3187         283
# 7732      37          1          0          0           0           0
# 7733     121          1        227        441         668          84
# 7734      49          1        221        263         484          83
#
# [7735 rows x 21 columns]

# %%
df_junior = df_merge.copy()

# %%
filter = df_junior['NAICS_DESC'] == 'Junior Colleges'
df_junior = df_junior[filter]
df_junior
# Out:
#       IPEDSID                                      NAME  \
# 0      107840                           Shorter College
# 16     475352                 Virginia College-Savannah
# 26     475477                    City College-Hollywood
# 37     475583                          Bryan University
# 38     475592                    Virginia College-Tulsa
# ...       ...                                       ...
# 7715   443270         Southeastern College-Jacksonville
# 7723   443377                 Triangle Tech Inc-Sunbury
# 7726   443438        Medvance Institute-Fort Lauderdale
# 7731   443492  Pierpont Community and Technical College
# 7734   443535          ITT Technical Institute-Hilliard
#
#                                     ADDRESS              CITY STATE    ZIP  \
# 0                             604 Locust St     N Little Rock    AR  72114
# 16        14045 Abercorn Street, Suite 1503          Savannah    GA  31419
# 26                         6565 Taft Street         Hollywood    FL  33024
# 37         3215 LeMone Industrial Boulevard          Columbia    MO  65201
# 38                 5124 South Peoria Avenue             Tulsa    OK  74105
# ...                                     ...               ...   ...    ...
# 7715     6700 Southpoint Parkway, Suite 400      Jacksonville    FL  32216
# 7723                   191 Performance Road           Sunbury    PA  17801
# 7726  4850 W. Oakland Park Blvd., Suite 200  Lauderdale Lakes    FL  33313
# 7731                        1201 Locust Ave          Fairmont    WV  26554
# 7734            3781 Park Mill Run, Suite 1          Hilliard    OH  43026
#
#       POPULATION          COUNTY  COUNTYFIPS COUNTRY  ...  NAICS_CODE  \
# 0             70         Pulaski        5119      US  ...      611210
# 16           902         Chatham       13051      US  ...      611210
# 26            82         Broward       12011      US  ...      611210
# 37           154           Boone       29019      US  ...      611210
# 38           231           Tulsa       40143      US  ...      611210
# ...          ...             ...         ...     ...  ...         ...
# 7715         313           Duval       12031      US  ...      611210
# 7723         127  Northumberland       42097      US  ...      611210
# 7726         365         Broward       12011      US  ...      611210
# 7731        3470          Marion       54049      US  ...      611210
# 7734         567        Franklin       39049      US  ...      611210
#
#            NAICS_DESC  STFIPS COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0     Junior Colleges       5    119          1         24         28
# 16    Junior Colleges      13     51          1        177        586
# 26    Junior Colleges      12     11          1         18         47
# 37    Junior Colleges      29     19          1          0        121
# 38    Junior Colleges      40    143          1         17        143
# ...               ...     ...    ...        ...        ...        ...
# 7715  Junior Colleges      12     31          1         45        165
# 7723  Junior Colleges      42     97          1          0        105
# 7726  Junior Colleges      12     11          1          0        331
# 7731  Junior Colleges      54     49          2        772       2415
# 7734  Junior Colleges      39     49          1        221        263
#
#       TOT_ENROLL  TOT_EMPLOY  POPESTIMATE2021
# 0             52          18            28643
# 16           763         139            21335
# 26            65          17           139030
# 37           121          33            13380
# 38           160          71            48445
# ...          ...         ...              ...
# 7715         210         103            71995
# 7723         105          22             6571
# 7726         331          34           139030
# 7731        3187         283             4032
# 7734         484          83            95141
#
# [1998 rows x 22 columns]

# %% [markdown]
# ### Regression

# %% [markdown]
# ### Split train-test dataset

# %%
X = df[['POPULATION']]
Y = df[['TOT_ENROLL']]

# %%
plt.plot(X,Y, linestyle='',marker='o')
plt.title('Population vs Enrollment').figure.savefig('Population_vs_Enrollment.png')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Create Linear Regression model

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([[0.84543691]])

# %%
lm.intercept_
# Out:
# array([22.70442192])

# %%
lm_y_test = lm.predict(X_test)
lm_y_train = lm.predict(X_train)

print('Train r2 score: ', r2_score(lm_y_train, y_train))
print('Test r2 score: ', r2_score(y_test, lm_y_test)) 
print('Train MAE: ', mean_absolute_error(lm_y_train, y_train))
print('Test MAE: ',mean_absolute_error(y_test, lm_y_test))
print('Train MSE: ', mean_squared_error(lm_y_train, y_train))
print('Test MSE: ',mean_squared_error(y_test, lm_y_test))
# Out:
# Train r2 score:  0.9819861144001455
# Test r2 score:  0.9816923218118879
# Train MAE:  231.5494600903543
# Test MAE:  229.86777539443798
# Train MSE:  808259.8912486824
# Test MSE:  757975.4924688424

# %%
sns.regplot(y_test, lm_y_test, data=df).figure.savefig('LR_Regplot.png')

# %% [markdown]
# ### Create Decision Tree Regression model

# %%
dtr1 = DecisionTreeRegressor(max_depth=7)
dtr1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7)

# %%
dtr_y_test = dtr1.predict(X_test)
dtr_y_train = dtr1.predict(X_train)

print('Train r2 score: ', r2_score(dtr_y_train, y_train))
print('Test r2 score: ', r2_score(y_test, dtr_y_test)) 
print('Train MAE: ', mean_absolute_error(dtr_y_train, y_train))
print('Test MAE: ',mean_absolute_error(y_test, dtr_y_test))
print('Train MSE: ', mean_squared_error(dtr_y_train, y_train))
print('Test MSE: ',mean_squared_error(y_test, dtr_y_test))
# Out:
# Train r2 score:  0.9916790160379184
# Test r2 score:  0.9597524325006341
# Train MAE:  167.7700568302921
# Test MAE:  263.48660348367974
# Train MSE:  376940.8531221265
# Test MSE:  1666331.9882809622

# %%
sns.regplot(y_test, dtr_y_test, data=df).figure.savefig('DTR_Regplot.png')

# %%
depth = 30
max_depth = [i for i in range(1,depth+1)] 
dtr_mae = [] 
for i in range(1,depth+1):
    dtr = DecisionTreeRegressor(max_depth=i)
    dtr.fit(X_train, y_train)
    dtr_y_pred = dtr.predict(X_test)
    dtr_mae.append(mean_absolute_error(y_test, dtr_y_pred))
    
plt.plot(max_depth, dtr_mae)
plt.xlabel('max_depth')
plt.ylabel('MAE')
plt.title('max_depth vs MAE').figure.savefig('DTR.png')
plt.show()

# %%
df_le = df.copy()
d = defaultdict(LabelEncoder)
col_list = [col for col in df_le.columns.tolist() if df_le[col].dtype.name == "object"]

df_le[col_list] = df_le[col_list].apply(lambda x: d[x.name].fit_transform(x))
df_le.drop("BINNED_TOT_ENROLL", 1, inplace=True)
df_le
# Out:
#       IPEDSID  NAME  ADDRESS  CITY  STATE   ZIP  POPULATION  COUNTY  \
# 0      107840  5846     5743  1478      2  3459          70     764
# 1      112181  1326     6402   410      5  4638          39     808
# 2      116660  3300     1874  1250      5  4231          35     560
# 3      125310  7324     1083  1941      5  4520          43     640
# 4      164368  2899       28   313     22   151        2386     623
# ...       ...   ...      ...   ...    ...   ...         ...     ...
# 7730   443483  1574      756   890      7   316         163     666
# 7731   443492  5073      908   707     57  1241        3470     588
# 7732   443517  6721     6258   464      5  4255           0     560
# 7733   443526  2947      484   602     12  1489         752     345
# 7734   443535  2964     4305   968     40  2162         567     339
#
#       COUNTYFIPS  COUNTRY  ...   LONGITUDE  NAICS_CODE  NAICS_DESC  STFIPS  \
# 0           5119        7  ...  -92.260490      611210           7       5
# 1           6067        7  ... -121.289431      611511           3       6
# 2           6037        7  ... -118.287070      611511           3       6
# 3           6053        7  ... -121.652662      611511           3       6
# 4          25017        7  ...  -71.070737      611310           1      25
# ...          ...      ...  ...         ...         ...         ...     ...
# 7730        9011        7  ...  -72.042638      611519           8       9
# 7731       54049        7  ...  -80.160335      611210           7      54
# 7732        6037        7  ... -118.236350      611710           4       6
# 7733       13121        7  ...  -84.176526      611310           1      13
# 7734       39049        7  ...  -83.121729      611210           7      39
#
#       COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY
# 0        119          1         24         28          52          18
# 1         67          1          6         24          30           9
# 2         37          1          0         24          24          11
# 3         53          1         18         16          34           9
# 4         17          2          0       2243        2243         143
# ...      ...        ...        ...        ...         ...         ...
# 7730      11          1        119         19         138          25
# 7731      49          2        772       2415        3187         283
# 7732      37          1          0          0           0           0
# 7733     121          1        227        441         668          84
# 7734      49          1        221        263         484          83
#
# [7735 rows x 21 columns]

# %%
X = df_le.drop(columns=['TOT_ENROLL'])
y = df_le['TOT_ENROLL']

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
#create model
model = Sequential()

#get number of columns in training data
n_cols = xTrain.shape[1]
n_cols
# Out:
# 20

# %%
#add model layers
model.add(Dense(100,  input_shape=(n_cols,)))
model.add(Dense(100, activation='relu'))
model.add(Dense(1))

# %%
#compile model using mse as a measure of model performance
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#set early stopping monitor so the model stops training when it won't improve anymore

#train model
history = model.fit(xTrain, yTrain, validation_split=0.2, epochs=200,  verbose=2)
# Out:
# Epoch 1/200
# 155/155 - 1s - loss: 406400192.0000 - val_loss: 11390462.0000 - 873ms/epoch - 6ms/step
# Epoch 2/200
# 155/155 - 0s - loss: 2067718.5000 - val_loss: 2138129.2500 - 289ms/epoch - 2ms/step
# Epoch 3/200
# 155/155 - 0s - loss: 552855.4375 - val_loss: 1454251.8750 - 303ms/epoch - 2ms/step
# Epoch 4/200
# 155/155 - 0s - loss: 430261.9375 - val_loss: 1350521.7500 - 288ms/epoch - 2ms/step
# Epoch 5/200
# 155/155 - 0s - loss: 376968.4688 - val_loss: 1118893.3750 - 275ms/epoch - 2ms/step
# Epoch 6/200
# 155/155 - 0s - loss: 293026.3438 - val_loss: 1107884.7500 - 291ms/epoch - 2ms/step
# Epoch 7/200
# 155/155 - 0s - loss: 228895.8125 - val_loss: 996525.1875 - 283ms/epoch - 2ms/step
# Epoch 8/200
# 155/155 - 0s - loss: 182700.1406 - val_loss: 776462.1875 - 276ms/epoch - 2ms/step
# Epoch 9/200
# 155/155 - 0s - loss: 142799.2812 - val_loss: 693316.9375 - 285ms/epoch - 2ms/step
# Epoch 10/200
# 155/155 - 0s - loss: 111837.7656 - val_loss: 741320.0625 - 301ms/epoch - 2ms/step
# Epoch 11/200
# 155/155 - 0s - loss: 106592.9219 - val_loss: 514266.0938 - 325ms/epoch - 2ms/step
# Epoch 12/200
# 155/155 - 0s - loss: 81177.7969 - val_loss: 428928.3125 - 444ms/epoch - 3ms/step
# Epoch 13/200
# 155/155 - 1s - loss: 77820.6484 - val_loss: 338947.2188 - 518ms/epoch - 3ms/step
# Epoch 14/200
# 155/155 - 0s - loss: 46590.6211 - val_loss: 300417.6875 - 343ms/epoch - 2ms/step
# Epoch 15/200
# 155/155 - 0s - loss: 42540.2969 - val_loss: 245393.8125 - 277ms/epoch - 2ms/step
# Epoch 16/200
# 155/155 - 0s - loss: 34834.8281 - val_loss: 228016.4062 - 304ms/epoch - 2ms/step
# Epoch 17/200
# 155/155 - 0s - loss: 27372.5605 - val_loss: 201020.6875 - 288ms/epoch - 2ms/step
# Epoch 18/200
# 155/155 - 0s - loss: 24790.1348 - val_loss: 188892.5156 - 293ms/epoch - 2ms/step
# Epoch 19/200
# 155/155 - 0s - loss: 21028.2754 - val_loss: 162659.9062 - 283ms/epoch - 2ms/step
# 155/155 - 0s - loss: 263.9199 - val_loss: 140162.2031 - 331ms/epoch - 2ms/step
# Epoch 196/200
# 155/155 - 0s - loss: 445.9934 - val_loss: 127142.5234 - 297ms/epoch - 2ms/step
# Epoch 197/200
# 155/155 - 0s - loss: 179.8886 - val_loss: 126040.1562 - 337ms/epoch - 2ms/step
# Epoch 198/200
# 155/155 - 0s - loss: 4405.6240 - val_loss: 164639.3438 - 277ms/epoch - 2ms/step
# Epoch 199/200
# 155/155 - 0s - loss: 40850.8359 - val_loss: 145859.6094 - 300ms/epoch - 2ms/step
# Epoch 200/200
# 155/155 - 0s - loss: 82263.8047 - val_loss: 243377.3906 - 338ms/epoch - 2ms/step

# %%
nn_y_test = model.predict(xTest)

# %%
nn_y_test
# Out:
# array([[-3.4279442e+01],
#        [-6.1471825e+01],
#        [ 8.1541882e+02],
#        ...,
#        [-1.0898745e+02],
#        [-7.4200687e+00],
#        [ 9.6904775e+03]], dtype=float32)

# %%
print('Test r2 score: ', r2_score(yTest, nn_y_test)) 
print('Test MAE: ',mean_absolute_error(yTest, nn_y_test))
print('Test MSE: ',mean_squared_error(yTest, nn_y_test))
# Out:
# Test r2 score:  0.9777541221336639
# Test MAE:  901.2181818546907
# Test MSE:  921025.0506853948

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %% [markdown]
# ### Data visualization for prediction of regression model

# %%
plt.plot(X_test,lm_y_test, linestyle='',marker='o', label='LR Model')
plt.plot(X_test,dtr_y_test, linestyle='',marker='*', label='DT Model')
plt.plot(X_test,nn_y_test, linestyle='',marker='^', label='NN Model')
plt.plot(X_test,y_test, linestyle='',marker='+', label='y_test')
plt.ticklabel_format(style='plain')
plt.legend().figure.savefig('Predicted_Enrollment.png')

# %%
#population = pd.read_csv('co-est2021-alldata.csv', encoding= 'unicode_escape')
#population = population[['STATE', 'COUNTY', 'POPESTIMATE2021']]
#population.rename(columns={"STATE": "STFIPS", "COUNTY": "COFIPS"}, inplace=True)
#df_new = df_new.merge(population, how='left')
#df_new.dropna(subset=['POPESTIMATE2021'], inplace=True)
#df_new['POPESTIMATE2021'] = (df_new['POPESTIMATE2021'].to_numpy()[:, None] * 0.072)
#df_new['POPESTIMATE2021'] = df_new['POPESTIMATE2021'].astype(int)
#df_new

# %% [markdown]
# ### Model prediction

# %%
real_X = df_junior[['POPESTIMATE2021']]
real_X
# Out:
#       POPESTIMATE2021
# 0               28643
# 16              21335
# 26             139030
# 37              13380
# 38              48445
# ...               ...
# 7715            71995
# 7723             6571
# 7726           139030
# 7731             4032
# 7734            95141
#
# [1998 rows x 1 columns]

# %%
df_nn = df_junior.copy()
df_nn.drop(['POPULATION'], 1, inplace=True)
df_nn.rename(columns ={'POPESTIMATE2021':'POPULATION'}, inplace=True)
df_nn
# Out:
#       IPEDSID                                      NAME  \
# 0      107840                           Shorter College
# 16     475352                 Virginia College-Savannah
# 26     475477                    City College-Hollywood
# 37     475583                          Bryan University
# 38     475592                    Virginia College-Tulsa
# ...       ...                                       ...
# 7715   443270         Southeastern College-Jacksonville
# 7723   443377                 Triangle Tech Inc-Sunbury
# 7726   443438        Medvance Institute-Fort Lauderdale
# 7731   443492  Pierpont Community and Technical College
# 7734   443535          ITT Technical Institute-Hilliard
#
#                                     ADDRESS              CITY STATE    ZIP  \
# 0                             604 Locust St     N Little Rock    AR  72114
# 16        14045 Abercorn Street, Suite 1503          Savannah    GA  31419
# 26                         6565 Taft Street         Hollywood    FL  33024
# 37         3215 LeMone Industrial Boulevard          Columbia    MO  65201
# 38                 5124 South Peoria Avenue             Tulsa    OK  74105
# ...                                     ...               ...   ...    ...
# 7715     6700 Southpoint Parkway, Suite 400      Jacksonville    FL  32216
# 7723                   191 Performance Road           Sunbury    PA  17801
# 7726  4850 W. Oakland Park Blvd., Suite 200  Lauderdale Lakes    FL  33313
# 7731                        1201 Locust Ave          Fairmont    WV  26554
# 7734            3781 Park Mill Run, Suite 1          Hilliard    OH  43026
#
#               COUNTY  COUNTYFIPS COUNTRY   LATITUDE  ...  NAICS_CODE  \
# 0            Pulaski        5119      US  34.759308  ...      611210
# 16           Chatham       13051      US  31.983580  ...      611210
# 26           Broward       12011      US  26.025270  ...      611210
# 37             Boone       29019      US  38.915735  ...      611210
# 38             Tulsa       40143      US  36.088311  ...      611210
# ...              ...         ...     ...        ...  ...         ...
# 7715           Duval       12031      US  30.220468  ...      611210
# 7723  Northumberland       42097      US  40.855276  ...      611210
# 7726         Broward       12011      US  26.162566  ...      611210
# 7731          Marion       54049      US  39.482878  ...      611210
# 7734        Franklin       39049      US  40.030759  ...      611210
#
#            NAICS_DESC STFIPS  COFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  \
# 0     Junior Colleges      5     119          1         24         28
# 16    Junior Colleges     13      51          1        177        586
# 26    Junior Colleges     12      11          1         18         47
# 37    Junior Colleges     29      19          1          0        121
# 38    Junior Colleges     40     143          1         17        143
# ...               ...    ...     ...        ...        ...        ...
# 7715  Junior Colleges     12      31          1         45        165
# 7723  Junior Colleges     42      97          1          0        105
# 7726  Junior Colleges     12      11          1          0        331
# 7731  Junior Colleges     54      49          2        772       2415
# 7734  Junior Colleges     39      49          1        221        263
#
#       TOT_ENROLL  TOT_EMPLOY  POPULATION
# 0             52          18       28643
# 16           763         139       21335
# 26            65          17      139030
# 37           121          33       13380
# 38           160          71       48445
# ...          ...         ...         ...
# 7715         210         103       71995
# 7723         105          22        6571
# 7726         331          34      139030
# 7731        3187         283        4032
# 7734         484          83       95141
#
# [1998 rows x 21 columns]

# %%
col_list = [col for col in df_nn.columns.tolist() if df_nn[col].dtype.name == "object"]

df_nn[col_list] = df_nn[col_list].apply(lambda x: d[x.name].fit_transform(x))
nn_real_X = df_nn.drop('TOT_ENROLL', 1)

# %%
lm_y_pred = lm.predict(real_X)
drt_y_pred = dtr1.predict(real_X)
nn_y_pred = model.predict(nn_real_X)
lm_y_pred = pd.DataFrame(lm_y_pred, columns=['LR'])
drt_y_pred = pd.DataFrame(drt_y_pred, columns=['DT'])
nn_y_pred = pd.DataFrame(nn_y_pred, columns=['NN'])

# %%
lm_y_pred = lm_y_pred.astype(int)
drt_y_pred = drt_y_pred.astype(int)
nn_y_pred = nn_y_pred.astype(int)

# %%
df_new = pd.concat([df_junior.reset_index(drop=True), lm_y_pred, drt_y_pred, nn_y_pred], axis=1) 

df_new
# Out:
#       IPEDSID                                      NAME  \
# 0      107840                           Shorter College
# 1      475352                 Virginia College-Savannah
# 2      475477                    City College-Hollywood
# 3      475583                          Bryan University
# 4      475592                    Virginia College-Tulsa
# ...       ...                                       ...
# 1993   443270         Southeastern College-Jacksonville
# 1994   443377                 Triangle Tech Inc-Sunbury
# 1995   443438        Medvance Institute-Fort Lauderdale
# 1996   443492  Pierpont Community and Technical College
# 1997   443535          ITT Technical Institute-Hilliard
#
#                                     ADDRESS              CITY STATE    ZIP  \
# 0                             604 Locust St     N Little Rock    AR  72114
# 1         14045 Abercorn Street, Suite 1503          Savannah    GA  31419
# 2                          6565 Taft Street         Hollywood    FL  33024
# 3          3215 LeMone Industrial Boulevard          Columbia    MO  65201
# 4                  5124 South Peoria Avenue             Tulsa    OK  74105
# ...                                     ...               ...   ...    ...
# 1993     6700 Southpoint Parkway, Suite 400      Jacksonville    FL  32216
# 1994                   191 Performance Road           Sunbury    PA  17801
# 1995  4850 W. Oakland Park Blvd., Suite 200  Lauderdale Lakes    FL  33313
# 1996                        1201 Locust Ave          Fairmont    WV  26554
# 1997            3781 Park Mill Run, Suite 1          Hilliard    OH  43026
#
#       POPULATION          COUNTY  COUNTYFIPS COUNTRY  ...  COFIPS  INST_SIZE  \
# 0             70         Pulaski        5119      US  ...     119          1
# 1            902         Chatham       13051      US  ...      51          1
# 2             82         Broward       12011      US  ...      11          1
# 3            154           Boone       29019      US  ...      19          1
# 4            231           Tulsa       40143      US  ...     143          1
# ...          ...             ...         ...     ...  ...     ...        ...
# 1993         313           Duval       12031      US  ...      31          1
# 1994         127  Northumberland       42097      US  ...      97          1
# 1995         365         Broward       12011      US  ...      11          1
# 1996        3470          Marion       54049      US  ...      49          2
# 1997         567        Franklin       39049      US  ...      49          1
#
#       PT_ENROLL FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  POPESTIMATE2021      LR  \
# 0            24        28          52          18            28643   24238
# 1           177       586         763         139            21335   18060
# 2            18        47          65          17           139030  117563
# 3             0       121         121          33            13380   11334
# 4            17       143         160          71            48445   40979
# ...         ...       ...         ...         ...              ...     ...
# 1993         45       165         210         103            71995   60889
# 1994          0       105         105          22             6571    5578
# 1995          0       331         331          34           139030  117563
# 1996        772      2415        3187         283             4032    3431
# 1997        221       263         484          83            95141   80458
#
#           DT     NN
# 0      26222  47110
# 1      19147  39432
# 2     102887  39532
# 3      11460  39607
# 4      42109  38872
# ...      ...    ...
# 1993   64514  37650
# 1994    5690  40552
# 1995  102887  39943
# 1996    3568  41222
# 1997   56387  38933
#
# [1998 rows x 25 columns]

# %% [markdown]
# ### Data visualization

# %%
plt.plot(df_new['POPESTIMATE2021'],df_new['LR'], linestyle='',marker='o', label='LR Model')
plt.plot(df_new['POPESTIMATE2021'],df_new['DT'], linestyle='',marker='+', label='DT Model')
plt.plot(df_new['POPESTIMATE2021'],df_new['NN'], linestyle='',marker='*', label='NN Model')
plt.xlabel('Population')
plt.ylabel('Enrollment')
plt.title('Predicted Enrollment in 2021')
plt.ticklabel_format(style='plain')
plt.legend().figure.savefig('Predicted_Enrollment_2021.png')

# %%
print('LR mean: ', df_new['LR'].mean())
print('DT mean: ', df_new['DT'].mean())
print('NN mean: ', df_new['NN'].mean())
# Out:
# DT mean:  50456.331831831834
# LR mean:  64604.514014014014
# NN mean:  51544.706706706704

# %% [markdown]
# ## Classification

# %%
df_FS = df.copy()

# %% [markdown]
# ### Binning for repsonse variable

# %%
bins = np.linspace(min(df_FS['TOT_ENROLL']), max(df_FS['TOT_ENROLL']), 4)

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df_FS['BINNED_TOT_ENROLL'] = pd.cut(df_FS['TOT_ENROLL'], bins, labels=group_names, include_lowest=True )
df_FS.head()
# Out:
#    IPEDSID                                      NAME                 ADDRESS  \
# 0   107840                           Shorter College           604 Locust St
# 1   112181             Citrus Heights Beauty College          7518 Baird Way
# 2   116660  Joe Blasco Makeup Artist Training Center   1670 Hillhurst Avenue
# 3   125310                  Waynes College of Beauty  1271 North Main Street
# 4   164368        Hult International Business School      1 Education Street
#
#              CITY STATE    ZIP  POPULATION       COUNTY  COUNTYFIPS COUNTRY  \
# 0   N Little Rock    AR  72114          70      Pulaski        5119      US
# 1  Citris Heights    CA  95610          39   Sacramento        6067      US
# 2     Los Angeles    CA  90027          35  Los Angeles        6037      US
# 3         Salinas    CA  93906          43     Monterey        6053      US
# 4       Cambridge    MA  02141        2386    Middlesex       25017      US
#
#    ...   LONGITUDE  NAICS_CODE  \
# 0  ...  -92.260490      611210
# 1  ... -121.289431      611511
# 2  ... -118.287070      611511
# 3  ... -121.652662      611511
# 4  ...  -71.070737      611310
#
#                                          NAICS_DESC STFIPS  INST_SIZE  \
# 0                                   Junior Colleges      5          1
# 1                    Cosmetology and Barber Schools      6          1
# 2                    Cosmetology and Barber Schools      6          1
# 3                    Cosmetology and Barber Schools      6          1
# 4  Colleges, Universities, and Professional Schools     25          2
#
#    PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  BINNED_TOT_ENROLL
# 0         24         28          52          18                Low
# 1          6         24          30           9                Low
# 2          0         24          24          11                Low
# 3         18         16          34           9                Low
# 4          0       2243        2243         143                Low
#
# [5 rows x 21 columns]

# %%
df_FS.drop(columns=['TOT_ENROLL'], inplace=True)

# %% [markdown]
# ### Label Encoding

# %%
df_FS.dtypes
# Out:
# IPEDSID                 int64
# NAME                   object
# ADDRESS                object
# CITY                   object
# STATE                  object
# ZIP                    object
# POPULATION              int64
# COUNTY                 object
# COUNTYFIPS              int64
# COUNTRY                object
# LATITUDE              float64
# LONGITUDE             float64
# NAICS_CODE              int64
# NAICS_DESC             object
# STFIPS                  int64
# INST_SIZE               int64
# PT_ENROLL               int64
# FT_ENROLL               int64
# TOT_EMPLOY              int64
# BINNED_TOT_ENROLL    category
# dtype: object

# %%
df_FS['BINNED_TOT_ENROLL'] = df_FS['BINNED_TOT_ENROLL'].astype(str)

# %%
col_list = [col for col in df_FS.columns.tolist() if df_FS[col].dtype.name == "object"]

df_FS[col_list] = df_FS[col_list].apply(lambda x: d[x.name].fit_transform(x))
df_FS
# Out:
#       IPEDSID  NAME  ADDRESS  CITY  STATE   ZIP  POPULATION  COUNTY  \
# 0      107840  5846     5743  1478      2  3459          70     764
# 1      112181  1326     6402   410      5  4638          39     808
# 2      116660  3300     1874  1250      5  4231          35     560
# 3      125310  7324     1083  1941      5  4520          43     640
# 4      164368  2899       28   313     22   151        2386     623
# ...       ...   ...      ...   ...    ...   ...         ...     ...
# 7730   443483  1574      756   890      7   316         163     666
# 7731   443492  5073      908   707     57  1241        3470     588
# 7732   443517  6721     6258   464      5  4255           0     560
# 7733   443526  2947      484   602     12  1489         752     345
# 7734   443535  2964     4305   968     40  2162         567     339
#
#       COUNTYFIPS  COUNTRY   LATITUDE   LONGITUDE  NAICS_CODE  NAICS_DESC  \
# 0           5119        7  34.759308  -92.260490      611210           7
# 1           6067        7  38.713353 -121.289431      611511           3
# 2           6037        7  34.101481 -118.287070      611511           3
# 3           6053        7  36.700631 -121.652662      611511           3
# 4          25017        7  42.369930  -71.070737      611310           1
# ...          ...      ...        ...         ...         ...         ...
# 7730        9011        7  41.347074  -72.042638      611519           8
# 7731       54049        7  39.482878  -80.160335      611210           7
# 7732        6037        7  33.895708 -118.236350      611710           4
# 7733       13121        7  34.042875  -84.176526      611310           1
# 7734       39049        7  40.030759  -83.121729      611210           7
#
#       STFIPS  INST_SIZE  PT_ENROLL  FT_ENROLL  TOT_EMPLOY  BINNED_TOT_ENROLL
# 0          5          1         24         28          18                  1
# 1          6          1          6         24           9                  1
# 2          6          1          0         24          11                  1
# 3          6          1         18         16           9                  1
# 4         25          2          0       2243         143                  1
# ...      ...        ...        ...        ...         ...                ...
# 7730       9          1        119         19          25                  1
# 7731      54          2        772       2415         283                  1
# 7732       6          1          0          0           0                  1
# 7733      13          1        227        441          84                  1
# 7734      39          1        221        263          83                  1
#
# [7735 rows x 20 columns]

# %%
y = df_FS.BINNED_TOT_ENROLL
X = df_FS.drop("BINNED_TOT_ENROLL", 1)
colnames = X.columns

# %% [markdown]
# ### Feature Selection using Boruta

# %%
def ranking(ranks, names, order=1):
    minmax = MinMaxScaler()
    ranks = minmax.fit_transform(order*np.array([ranks]).T).T[0]
    ranks = map(lambda x: round(x,2), ranks)
    return dict(zip(names, ranks))

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight="balanced", max_depth=5)

feat_selector = BorutaPy(rf, n_estimators="auto", random_state=1)

# %%
feat_selector.fit(X.values, y.values.ravel())
# Out:
# BorutaPy(estimator=RandomForestClassifier(class_weight='balanced', max_depth=5,
#                                           n_estimators=69, n_jobs=-1,
#                                           random_state=RandomState(MT19937) at 0x1EB9072EC40),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x1EB9072EC40)

# %%
boruta_score = ranking(list(map(float, feat_selector.ranking_)), colnames, order=-1)
boruta_score = pd.DataFrame(list(boruta_score.items()), columns=['Features', 'Score'])
boruta_score = boruta_score.sort_values("Score", ascending = False)

# %%
print('---------Top 10----------')
display(boruta_score.head(10))

print('---------Bottom 10----------')
boruta_score.tail(10)
# Out:
# ---------Top 10----------
#       Features  Score
# 18  TOT_EMPLOY   1.00
# 6   POPULATION   1.00
# 17   FT_ENROLL   1.00
# 16   PT_ENROLL   1.00
# 15   INST_SIZE   1.00
# 1         NAME   0.93
# 0      IPEDSID   0.86
# 8   COUNTYFIPS   0.79
# 14      STFIPS   0.71
# 4        STATE   0.71
# ---------Bottom 10----------
#       Features  Score
# 4        STATE   0.71
# 11   LONGITUDE   0.57
# 2      ADDRESS   0.50
# 10    LATITUDE   0.43
# 13  NAICS_DESC   0.43
# 7       COUNTY   0.21
# 5          ZIP   0.21
# 3         CITY   0.21
# 12  NAICS_CODE   0.07
# 9      COUNTRY   0.00

# %%
sns_boruta_plot = sns.catplot(x="Score", y="Features", data = boruta_score[:10], kind = "bar", 
               height=14, aspect=1.9, palette='coolwarm')
plt.title("Boruta Top 10 Features").figure.savefig('Boruta.png')

# %%
top_10_features = boruta_score.Features[:10].tolist()

# %%
df_FS['BINNED_TOT_ENROLL'].value_counts()
# Out:
# 1    7730
# 2       4
# 0       1
# Name: BINNED_TOT_ENROLL, dtype: int64

# %% [markdown]
# ### Balance dataset using resample

# %%
#create two different dataframe of majority and minority class 
df_majority = df_FS[(df_FS['BINNED_TOT_ENROLL']==1)] 
df_minority = df_FS[(df_FS['BINNED_TOT_ENROLL']==0)]
df_minority1 = df_FS[(df_FS['BINNED_TOT_ENROLL']==2)] 
# upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,    # sample with replacement
                                 n_samples= 7730, # to match majority class
                                 random_state=42)  # reproducible results
df_minority_upsampled1 = resample(df_minority1, 
                                 replace=True,    # sample with replacement
                                 n_samples= 7730, # to match majority class
                                 random_state=42)  # reproducible results
# Combine majority class with upsampled minority class
df_FS = pd.concat([df_minority_upsampled, df_majority])
df_FS = pd.concat([df_minority_upsampled1, df_FS])

# %%
y = df_FS.BINNED_TOT_ENROLL
X = df_FS[top_10_features]

# %%
X
# Out:
#       TOT_EMPLOY  POPULATION  FT_ENROLL  PT_ENROLL  INST_SIZE  NAME  IPEDSID  \
# 6347        7440       85174      77690         44          5   406   154022
# 6379        9139      112026      37577      65310          5  3256   150987
# 946         8907       82285      59062      14316          5   374   104151
# 6347        7440       85174      77690         44          5   406   154022
# 6347        7440       85174      77690         44          5   406   154022
# ...          ...         ...        ...        ...        ...   ...      ...
# 7730          25         163         19        119          1  1574   443483
# 7731         283        3470       2415        772          2  5073   443492
# 7732           0           0          0          0          1  6721   443517
# 7733          84         752        441        227          1  2947   443526
# 7734          83         567        263        221          1  2964   443535
#
#       COUNTYFIPS  STFIPS  STATE
# 6347       19045      19     15
# 6379       18097      18     18
# 946         4013       4      4
# 6347       19045      19     15
# 6347       19045      19     15
# ...          ...     ...    ...
# 7730        9011       9      7
# 7731       54049      54     57
# 7732        6037       6      5
# 7733       13121      13     12
# 7734       39049      39     40
#
# [23190 rows x 10 columns]

# %% [markdown]
# ### Split train-test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %% [markdown]
# ### Create Naive Bayes Classifier

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
# Calculate the overall accuracy on test set 

print("Accuracy on training set: {:.3f}".format(nb.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(nb.score(X_test, y_test)))

confusion_majority = confusion_matrix(y_test, y_pred)

print('Mjority classifier Confusion Matrix\n', confusion_majority)
    
prob_NB = nb.predict_proba(X_test)

sk_report = classification_report(
    digits=6,
    y_true=y_test, 
    y_pred=nb.predict(X_test))
print(sk_report)
# Out:
# Accuracy on training set: 0.993
# Accuracy on test set: 0.993
# Mjority classifier Confusion Matrix
#  [[1570    0    0]
#  [   0 1525   33]
#  [   0    0 1510]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000      1570
#            1   1.000000  0.978819  0.989296      1558
#            2   0.978613  1.000000  0.989191      1510
#
#     accuracy                       0.992885      4638
#    macro avg   0.992871  0.992940  0.992829      4638
# weighted avg   0.993037  0.992885  0.992885      4638

# %%
fpr = {}
tpr = {}
thresh ={}
n_class = df_FS['BINNED_TOT_ENROLL'].nunique()
classes = nb.classes_
roc_auc_ovr = {}

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, prob_NB[:,i], pos_label=i)
    c = classes[i]
    df_aux = X_test.copy()
    df_aux['class'] = [1 if y == c else 0 for y in y_test]
    df_aux['prob'] = prob_NB[:, i]
    df_aux = df_aux.reset_index(drop = True)
    roc_auc_ovr[c] = roc_auc_score(df_aux['class'], df_aux['prob'])

avg_roc_auc = 0
i = 0
for k in roc_auc_ovr:
    avg_roc_auc += roc_auc_ovr[k]
    i += 1
    print(f"Class {k} ROC AUC OvR: {roc_auc_ovr[k]:.4f}")
print(f"Average ROC AUC OvR: {avg_roc_auc/i:.4f}")
    
# plotting    
plt.plot(fpr[0], tpr[0], color='red', label='Class 0 vs Rest')
plt.plot(fpr[1], tpr[1], color='orange', label='Class 1 vs Rest')
plt.plot(fpr[2], tpr[2], color='blue', label='Class 2 vs Rest')
plt.plot([0, 1], [0, 1], color='green', linestyle='--')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best').figure.savefig('NB.png')
# Out:
# Class 0 ROC AUC OvR: 1.0000
# Class 1 ROC AUC OvR: 1.0000
# Class 2 ROC AUC OvR: 0.9974
# Average ROC AUC OvR: 0.9991

# %% [markdown]
# ### Create Random Forest Classifier

# %%
rf = RandomForestClassifier(random_state=1, n_estimators=1000, max_depth=5)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# Calculate the overall accuracy on test set 

print("Accuracy on training set: {:.3f}".format(rf.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(rf.score(X_test, y_test)))

confusion_majority = confusion_matrix(y_test, y_pred)

print('Mjority classifier Confusion Matrix\n', confusion_majority)
    
prob_RF = rf.predict_proba(X_test)

sk_report = classification_report(
    digits=6,
    y_true=y_test, 
    y_pred=rf.predict(X_test))
print(sk_report)
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# Mjority classifier Confusion Matrix
#  [[1570    0    0]
#  [   0 1558    0]
#  [   0    0 1510]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000      1570
#            1   1.000000  1.000000  1.000000      1558
#            2   1.000000  1.000000  1.000000      1510
#
#     accuracy                       1.000000      4638
#    macro avg   1.000000  1.000000  1.000000      4638
# weighted avg   1.000000  1.000000  1.000000      4638

# %%
fpr = {}
tpr = {}
thresh ={}
n_class = df_FS['BINNED_TOT_ENROLL'].nunique()
classes = rf.classes_
roc_auc_ovr = {}

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, prob_RF[:,i], pos_label=i)
    c = classes[i]
    df_aux = X_test.copy()
    df_aux['class'] = [1 if y == c else 0 for y in y_test]
    df_aux['prob'] = prob_RF[:, i]
    df_aux = df_aux.reset_index(drop = True)
    roc_auc_ovr[c] = roc_auc_score(df_aux['class'], df_aux['prob'])

avg_roc_auc = 0
i = 0
for k in roc_auc_ovr:
    avg_roc_auc += roc_auc_ovr[k]
    i += 1
    print(f"Class {k} ROC AUC OvR: {roc_auc_ovr[k]:.4f}")
print(f"Average ROC AUC OvR: {avg_roc_auc/i:.4f}")

# plotting    
plt.plot(fpr[0], tpr[0], color='red', label='Class 0 vs Rest')
plt.plot(fpr[1], tpr[1], color='orange', label='Class 1 vs Rest')
plt.plot(fpr[2], tpr[2], color='blue', label='Class 2 vs Rest')
plt.plot([0, 1], [0, 1], color='green', linestyle='--')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best').figure.savefig('RF.png')
# Out:
# Class 0 ROC AUC OvR: 1.0000
# Class 1 ROC AUC OvR: 1.0000
# Class 2 ROC AUC OvR: 1.0000
# Average ROC AUC OvR: 1.0000

# %% [markdown]
# ### Create K-Nearest Neighbors Classifier

# %%
KNN = KNeighborsClassifier(n_neighbors=3)
KNN.fit(X_train, y_train)
y_pred = KNN.predict(X_test)

# Calculate the overall accuracy on test set 

print("Accuracy on training set: {:.3f}".format(KNN.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(KNN.score(X_test, y_test)))

confusion_majority = confusion_matrix(y_test, y_pred)

print('Mjority classifier Confusion Matrix\n', confusion_majority)

prob_KNN = KNN.predict_proba(X_test)

sk_report = classification_report(
    digits=6,
    y_true=y_test, 
    y_pred=KNN.predict(X_test))
print(sk_report)
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 1.000
# Mjority classifier Confusion Matrix
#  [[1570    0    0]
#  [   0 1558    0]
#  [   0    0 1510]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000      1570
#            1   1.000000  1.000000  1.000000      1558
#            2   1.000000  1.000000  1.000000      1510
#
#     accuracy                       1.000000      4638
#    macro avg   1.000000  1.000000  1.000000      4638
# weighted avg   1.000000  1.000000  1.000000      4638

# %%
fpr = {}
tpr = {}
thresh ={}
n_class = df_FS['BINNED_TOT_ENROLL'].nunique()
classes = KNN.classes_
roc_auc_ovr = {}

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, prob_KNN[:,i], pos_label=i)
    c = classes[i]
    df_aux = X_test.copy()
    df_aux['class'] = [1 if y == c else 0 for y in y_test]
    df_aux['prob'] = prob_KNN[:, i]
    df_aux = df_aux.reset_index(drop = True)
    roc_auc_ovr[c] = roc_auc_score(df_aux['class'], df_aux['prob'])

avg_roc_auc = 0
i = 0
for k in roc_auc_ovr:
    avg_roc_auc += roc_auc_ovr[k]
    i += 1
    print(f"Class {k} ROC AUC OvR: {roc_auc_ovr[k]:.4f}")
print(f"Average ROC AUC OvR: {avg_roc_auc/i:.4f}")
    
# plotting    
plt.plot(fpr[0], tpr[0], color='red', label='Class 0 vs Rest')
plt.plot(fpr[1], tpr[1], color='orange', label='Class 1 vs Rest')
plt.plot(fpr[2], tpr[2], color='blue', label='Class 2 vs Rest')
plt.plot([0, 1], [0, 1], color='green', linestyle='--')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best').figure.savefig('KNN.png')
# Out:
# Class 0 ROC AUC OvR: 1.0000
# Class 1 ROC AUC OvR: 1.0000
# Class 2 ROC AUC OvR: 1.0000
# Average ROC AUC OvR: 1.0000

# %% [markdown]
# ### Classification models prediction

# %%
newData = pd.DataFrame({
    'TOT_EMPLOY':[83],
    'POPULATION':[567],
    'FT_ENROLL':[263],
    'PT_ENROLL':[221],
    'INST_SIZE':[1],
    'NAME':['ITT Technical Institute-Hilliard'],
    'IPEDSID':[443535],
    'COUNTYFIPS':[39049],
    'STFIPS':[39],
    'STATE':['OH']
})
new_obj = [col for col in newData.columns.tolist() if newData[col].dtype.name == "object"]

newData[new_obj] = newData[new_obj].apply(lambda x: d[x.name].transform(x))
newData
# Out:
#    TOT_EMPLOY  POPULATION  FT_ENROLL  PT_ENROLL  INST_SIZE  NAME  IPEDSID  \
# 0          83         567        263        221          1  2964   443535
#
#    COUNTYFIPS  STFIPS  STATE
# 0       39049      39     40

# %%
d['BINNED_TOT_ENROLL'].inverse_transform(nb.predict(newData))
# Out:
# array(['Low'], dtype=object)

# %%
d['BINNED_TOT_ENROLL'].inverse_transform(rf.predict(newData))
# Out:
# array(['Low'], dtype=object)

# %%
d['BINNED_TOT_ENROLL'].inverse_transform(KNN.predict(newData))
# Out:
# array(['Low'], dtype=object)

# %% [markdown]
# ### Causal Question

# %% [markdown]
# **“Will an increase in the size of institutions increase the total enrollment of students of colleges and universities in the US?”**

# %%
df2 = df.copy()
filter = df2['INST_SIZE'] > 0
df2 = df2[filter]
df2.head()
# Out:
#    IPEDSID                                      NAME                 ADDRESS  \
# 0   107840                           Shorter College           604 Locust St
# 1   112181             Citrus Heights Beauty College          7518 Baird Way
# 2   116660  Joe Blasco Makeup Artist Training Center   1670 Hillhurst Avenue
# 3   125310                  Waynes College of Beauty  1271 North Main Street
# 4   164368        Hult International Business School      1 Education Street
#
#              CITY STATE    ZIP  POPULATION       COUNTY  COUNTYFIPS COUNTRY  \
# 0   N Little Rock    AR  72114          70      Pulaski        5119      US
# 1  Citris Heights    CA  95610          39   Sacramento        6067      US
# 2     Los Angeles    CA  90027          35  Los Angeles        6037      US
# 3         Salinas    CA  93906          43     Monterey        6053      US
# 4       Cambridge    MA  02141        2386    Middlesex       25017      US
#
#    ...   LONGITUDE  NAICS_CODE  \
# 0  ...  -92.260490      611210
# 1  ... -121.289431      611511
# 2  ... -118.287070      611511
# 3  ... -121.652662      611511
# 4  ...  -71.070737      611310
#
#                                          NAICS_DESC STFIPS  INST_SIZE  \
# 0                                   Junior Colleges      5          1
# 1                    Cosmetology and Barber Schools      6          1
# 2                    Cosmetology and Barber Schools      6          1
# 3                    Cosmetology and Barber Schools      6          1
# 4  Colleges, Universities, and Professional Schools     25          2
#
#    PT_ENROLL  FT_ENROLL  TOT_ENROLL  TOT_EMPLOY  BINNED_TOT_ENROLL
# 0         24         28          52          18                Low
# 1          6         24          30           9                Low
# 2          0         24          24          11                Low
# 3         18         16          34           9                Low
# 4          0       2243        2243         143                Low
#
# [5 rows x 21 columns]

# %%
corr_list = list(['INST_SIZE', 'TOT_ENROLL'])
corr = df2[corr_list].corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr , vmax=.8, square=True, annot=True, fmt= '.2f', annot_kws={'size': 15}, cmap=sns.color_palette("Reds")).figure.savefig('Heatmap3.png')

# %%
plt.scatter(df2['INST_SIZE'],df2['TOT_ENROLL'])
plt.plot(np.unique(df2['INST_SIZE']), np.poly1d(np.polyfit(df2['INST_SIZE'], df2['TOT_ENROLL'], 1))
         (np.unique(df2['INST_SIZE'])), color='red')
plt.title('Institution size vs Enrollment').figure.savefig('Inst_vs_Enrollment_Regplot.png')
